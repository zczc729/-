# %%
# Faker 라이브러리 설치 후에는 커널 리스타트 필수
#!pip install Faker

# %%
from faker import Faker

# %%
fake = Faker()

# %%
fake.name()
# Out:
# 'Anita Soto'

# %%
fake = Faker('ko-KR')

# %%
fake.name()
# Out:
# '김현숙'

# %%
fake.address()
# Out:
# '충청북도 성남시 언주027가 (은경고윤마을)'

# %%
test_data = [(fake.name(), fake.address()) for i in range(100)]

# %%
test_data
# Out:
# [('장영숙', '경기도 안양시 만안구 서초대17길 (영철김고면)'),
#  ('배지혜', '경기도 보령시 석촌호수가'),
#  ('배순자', '경기도 수원시 장안구 봉은사4길 (현정이동)'),
#  ('김채원', '세종특별자치시 동대문구 석촌호수길'),
#  ('양지원', '경상북도 동해시 강남대32가'),
#  ('김지아', '충청남도 괴산군 서초대476거리'),
#  ('이시우', '강원도 충주시 선릉길'),
#  ('이영수', '충청남도 양주시 영동대02로 (지은김마을)'),
#  ('백영식', '전라남도 보은군 압구정길 (영호박읍)'),
#  ('이상현', '서울특별시 강동구 논현로'),
#  ('최현준', '강원도 부천시 서초중앙79거리'),
#  ('김지은', '전라남도 용인시 기흥구 가락가'),
#  ('장정식', '서울특별시 마포구 가락길 (혜진박최읍)'),
#  ('장성민', '경상남도 계룡시 영동대길'),
#  ('강정순', '대구광역시 동구 도산대길 (준호윤김면)'),
#  ('이주원', '경기도 시흥시 석촌호수145가'),
#  ('고현지', '부산광역시 서구 학동로'),
#  ('김지현', '강원도 안산시 상록구 서초중앙로 (현우고리)'),
#  ('윤정순', '충청북도 수원시 장안구 선릉40가 (정희백동)'),
#  ('김영순', '전라남도 포천시 도산대77가'),
#  ('최미경', '충청남도 원주시 가락081가 (정남강노동)'),
#  ('김정웅', '울산광역시 영등포구 개포거리 (혜진김마을)'),
#  ('박은경', '인천광역시 용산구 선릉09거리'),
#  ('김현정', '광주광역시 중랑구 영동대10가 (미정김면)'),
#  ('문은주', '세종특별자치시 관악구 봉은사가 (주원김리)'),
#  ('이정식', '강원도 수원시 영통구 오금가 (진호백마을)'),
#  ('윤광수', '경상북도 용인시 수지구 삼성2거리'),
#  ('김은주', '인천광역시 성북구 석촌호수가'),
# ...

# %%
len(test_data)
# Out:
# 100

# %%
people_data = [(fake.name(), fake.country(), fake.phone_number(), fake.user_name()) for i in range(100)]

# %%
people_data
# Out:
# [('권서현', '크로아티아', '043-311-8357', 'ijeongja'),
#  ('박준호', '헝가리', '064-751-1755', 'zson'),
#  ('김현숙', '불가리아', '044-950-6078', 'kgim'),
#  ('이서윤', '스웨덴', '018-104-2356', 'jeongung02'),
#  ('곽아름', '폴란드', '016-705-9946', 'jeongsu95'),
#  ('황옥자', '벨리즈', '054-311-6202', 'jieuni'),
#  ('김명숙', '캄보디아', '018-305-4531', 'jeonjuweon'),
#  ('남성호', '파키스탄', '033-205-1234', 'seoyungim'),
#  ('김정수', '불가리아', '064-768-4017', 'jeongsuggim'),
#  ('지옥순', '바레인', '051-435-1435', 'ugim'),
#  ('송순옥', '코모로', '041-721-1893', 'xgim'),
#  ('이광수', '솔로몬 제도', '052-002-7294', 'minjun19'),
#  ('최정희', '에스토니아', '054-772-5126', 'hi'),
#  ('권명자', '짐바브웨', '052-895-4765', 'sanghohan'),
#  ('김지현', '라오스', '053-260-7523', 'jeongsungim'),
#  ('박수민', '니카라과', '02-3699-9566', 'jeongsubag'),
#  ('이예준', '덴마크', '010-0029-0609', 'xna'),
#  ('강정호', '세네갈', '064-750-0450', 'gimmisug'),
#  ('황건우', '베트남', '02-7390-2512', 'ei'),
#  ('김선영', '앤티가 바부다', '064-745-2851', 'seohyeon29'),
#  ('윤성진', '바레인', '016-499-5518', 'mi'),
# ...
