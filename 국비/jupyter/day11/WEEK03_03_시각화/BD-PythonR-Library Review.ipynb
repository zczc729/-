# %% [markdown]
# # 입문자를 위한, 파이썬/R 데이터 분석

# %% [markdown]
# ## 과정소개
#
# - 대상 : 데이터 분석에 대한 호기심 및 필요성을 가고 데이터 분석을 해 본 적이 없는 비전공자
#
#
# - 구성 : 수학적, 통계적 지식 크게 필요치 않으며, 프로그래밍 언어보다 데이터 분석 다양한 분야 경험할 수 있도록 계획
#
#
# - 주요 커리큘럼 :
#
#     1) 파이썬 Python 문법 (데이터 분석에 필요한 범위까지만... )
#
#     2) R 문법 기초 (데이터 통계적 분석에 필요한 수준까지만 )
#
#     3) 데이터 분석 경험
#     - Kaggle competition
#     - 공공/개방형 데이터 활용 분석
#     - 기업내 마케팅, 영업 분석요청 사례 경험
#     - Web crawling, scraping 경험
#     - Text mining
#     - 시각화 등
#
#   4) 기타 옵션
#     - RDBMS 활용한 SQL 다루기 기초
#     - ML(Machine Learning) 알고리즘 개념

# %% [markdown]
# ### Ice breaking
#
# - 이름 :
# - 소개 :
# - 수강 목적(희망 목표) : 결석없이 끝까지! :-)

# %% [markdown]
# ## `Review` : Anaconda 및 Jupyter notebook (colab 소개)

# %% [markdown]
# ### Anaconda :
#
# > 신규 패키지/라이브러리 설치할 경우,
#   - Anaconda Prompt > conda install {패키지이름}  또는 Jupyter notebook > pip install {패키지이름}

# %% [markdown]
# ### Jupyter notebook :
#
# > **특징**
# - 1) 주피터 노트북은 파이썬 코드를 웹 브라우저에서 실행할 수 있도록 해주는 대화식(Interactive) 환경
# - 2) 코드 작성 뿐만 아니라 메모까지 쉽게 작성 ( 주피터 노트북 만으로 분석 리포트 작성 )
# - 3) 파이썬 뿐만 아니라 R, Java, C 등 수많은 언어를 사용할 수 있음
#
#
# 단축키는 위의 메뉴창에 `Help -> Keyboard Shortcuts`에서 확인할 수 있고, 코드 작성을 위한 필수적인 주요 단축키는 다음과 같음.
#
#
# > **블록 선택 모드 (왼쪽의 표시가 "파란색" )에 작동하는 단축키들**
# - `m` : 블록을 Markdown 블록으로 변환합니다. Markdown 모드는 메모를 작성하기에 적합합니다.
# - `y` : 블록을 Code 블록으로 변환합니다.
# - `a` : 현재 선택되어 있는 블록의 위에 새로운 블록을 추가합니다. (Above)
# - `b` : 현재 선택되어 있는 블록의 아래에 새로운 블록을 추가합니다. (Below); `"+ 아이콘"` 누른 것과 동일
# - `dd` : 현재 선택되어 있는 블록을 지웁니다. (Delete); `"가위모양 아이콘"` 누른 것과 동일
#
# > **작성 모드 (왼쪽의 표시가 "초록색" )에 작동하는 단축키들**
# - `Shift + Enter` : 현재 선택한 블록의 코드를 실행합니다.
# - `Shift + Tab` : 툴팁 도움말
#
# ## Colab 소개 :
#
# > **특징**
# - 1) Google에서 제공하는 인터넷 기반 Python 실습환경 (별도 개인PC 에 설치 필요없음)
# - 2) 64비트 플랫폼 제공, Jupyter notebook 형식의 개발환경 사용
#
# > **접속경로**
# - https://colab.research.google.com/
# - 참고자료 : [Google Colaboratory 시작하기 (TensorFlow 코딩하기)](https://youtu.be/inN8seMm7UI)

# %% [markdown]
# ## 파이썬 패키지 소개

# %% [markdown]
# ### Python 주요 패키지
#
# > **IDE 도구**
#  - Jupyter, PyCharm
#
# > **데이터 가공/조작**
#  - pandas
#
# > **행렬/배열/선형대수/통계**
#  - NumPy, SciPy
#
# > **시각화**
#  - matplotlib
#  - Seaborn
#
# > **ML(머신러닝)**
#  - Scikit-learn
#
# > **기타**
#  - **DL(딥러닝)** : TensorFlow, Keras, Pytorch
#  - **Web Application** : Django, Flask
#
# ![%EC%A3%BC%EC%9A%94%ED%8C%A8%ED%82%A4%EC%A7%801.png](attachment:%EC%A3%BC%EC%9A%94%ED%8C%A8%ED%82%A4%EC%A7%801.png)
# ![%EC%A3%BC%EC%9A%94%ED%8C%A8%ED%82%A4%EC%A7%802.png](attachment:%EC%A3%BC%EC%9A%94%ED%8C%A8%ED%82%A4%EC%A7%802.png)

# %% [markdown]
# ## `Review` : pandas

# %% [markdown]
# ### 판다스(Pandas) ?
#
# [판다스(Pandas)](https://pandas.pydata.org)는 파이썬에서 데이터분석을 위해 사용하는 패키지(Package) 중 하나
# ( "파이썬으로 엑셀과 같은 파일을 다루기에 최적화된 도구" )
#
# 판다스 장점 :
#
#   1. 대용량 데이터를 효율적으로 다룰 수 있다.
#   - 엑셀은 데이터의 용량이 100MB만 넘어가면 정상적으로 작동하지 않는데, 판다스는 최소 1GB, 많으면 100GB가 넘는 데이터도 빠른 속도로 처리
#
#   2. 복잡한 기능을 구현할 때는 엑셀보다 더 쉽습니다.
#   - 엑셀은 복잡한 기능을 엑셀 전용 함수를 사용하는데, 판다스는 파이썬을 기반으로 동작하기 때문에 엑셀보다 더 쉽다
#
#   3. 다른 시스템과 연동하기 쉽습니다.
#   - 엑셀은 분석 결과를 데이터베이스에 집어넣거나 웹 페이지에 띄우는 일을 하기 어렵지만, 판다스는 플라스크([Flask](http://flask.pocoo.org/), 웹 프레임워크)나 SQL알케미([SQL Alchemy](https://www.sqlalchemy.org/), 데이터베이스)를 통해 다른 시스템과 연동하기 편함
#
# 판다스의 기본적인 룰 몇 가지만 숙지하면, 적은 문법 만으로도 굉장히 다양하고 창의적인 방식으로 엑셀(또는 CSV) 파일을 다룰 수 있다
#
# 참고문서 :
# > - [10 minutes to pandas](https://pandas.pydata.org/docs/user_guide/10min.html)
# > - [Pandas_Cheat_Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)

# %%
# pandas 라는 패키지를 파이썬으로 읽어(import)옵니다. 그리고 pd라는 alias축약어를 사용합니다.
import pandas as pd

# %% [markdown]
# ### Series: 1차원 구조

# %%
index = ['apple','banana','orange','kiwi']
data = [10, 9, 5, 3]
index

# %%
data

# %%
#series = pd.Series(index=index, data)  # Error
series = pd.Series(data, index=index)  # OK
series

# %%
## Filtering :
conditions = [True, False, False, True]
series[conditions]

# %%
## Sorting :
series.sort_index()

# %%
series.sort_values(ascending=False)

# %% [markdown]
# ### DataFrame: 2차원 구조

# %%
index = ['apple','banana','orange','kiwi']
data1 = [10, 9, 5, 3]
data2 = [50, 25, 10, 6]
series1 = pd.Series(data1, index=index)
series2 = pd.Series(data2, index=index)

# %%
series1

# %%
series2

# %%
df = pd.DataFrame([series1, series2])
df

# %%
numb = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
df_numb = pd.DataFrame(numb, columns=['col1','col2','col3'])
df_numb

# %%
series

# %%
type(series)

# %%
numb

# %%
type(numb)

# %%
type(df_numb)

# %%
df_numb['col2']

# %%
df_numb.loc[2]      # row행 이름 기준으로

# %%
df_numb.loc[1, 'col2']

# %%
df_numb.iloc[1,1]     # index 기준으로
#df_numb.iloc[0, 'col1']     # Error

# %%
## 파일 읽어오기 :
data = pd.read_csv("data/weight_log.csv", index_col = "회차")  #추가 주요옵션: encoding=utf-8/cp949, header=[0,1]
data

# %%
data.columns

# %%
data.index

# %%
data.head()

# %%
data.tail()

# %%
data.describe()

# %%
data["몸무게"].mean()

# %%
data["지점"].unique()

# %%
data["지점"].value_counts()                 # Unique 갯수 표시

# %%
data["지점"].value_counts(normalize = True)*100 # Unique 비율표시

# %%
data["지점"] = data["지점"].replace("강남구", "강남").replace('서초구','서초')

# %%
data["지점"]

# %%
data['몸무게(fill)'] = data['몸무게'].fillna(data["몸무게"].mean())
data

# %%
data['측정일']

# %%
data['측정일'] = pd.to_datetime(data['측정일'])

# %%
data['측정일']

# %%
data['측정일'].dt.year

# %%
## 여러개 컬럼 기준으로 값 읽어보기 :
data[["이름", "측정일", "몸무게"]]

# %%
data.loc[7, ["이름", "측정일", "몸무게"]]

# %%
## 컬럼값 조건에 따른 값 읽어보기 :
data[data["담당"] == "박길동"]

# %%
data["담당"].isin(["박길동", "김길동"])

# %%
data[data["담당"].isin(["박길동", "김길동"])]

# %%
data[data["담당"].str.contains("김")]

# %%
data[data["몸무게"] > 75]

# %%
data[(data["몸무게"] > 75.5) & (data["담당"] == "김길동")]  # pandas에서 and -> &, or -> | 기호를 사용

# %% [markdown]
# 다른 방식으로도 ```not_null```을 표현할 수 있습니다. 바로 물결 표시(~)입니다.
#
# 물결 표시(~)는 판다스를 색인할 때 True를 False로, False를 True로 뒤집어줍니다.
#
# 이렇게 하면 not_null을 사용해도 물결 표시(~)를 통해 null과 동일한 효과를 낼 수 있습니다.

# %%
data[~data["몸무게"].isnull()]

# %%
data[data["몸무게"].notnull()]

# %%
data.loc[data["담당"] == "김길동", "몸무게"]

# %%
data.loc[data["담당"] == "김길동", ["이름", "측정일", "몸무게"]]

# %%
## pivot_table :
pd.pivot_table(data, index=["지점", "담당"], values="몸무게", aggfunc='sum') #aggfunc 기본값: mean평균

# %%
## Column 추가 예시 :
data["몸무게(gram)"] = data["몸무게"] * 1000
data[["몸무게", "몸무게(gram)"]]

# %%
data.loc[data["몸무게"] > 75.6, "상태"] = "비만"

# %%
data.loc[data["몸무게"] <= 75.6, "상태"] = "정상"

# %%
#data[["몸무게", "비만", "상태"]]
data

# %%
# 데이터프레임을 파일로 저장 :
data.to_csv("data/data_output.csv", encoding='CP949') #맥 또는 리눅스 utf8
