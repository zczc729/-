# %% [markdown]
# # 입문자를 위한, 파이썬/R 데이터 분석

# %% [markdown]
# ## 데이터를 분석할 때 가장 필수적인 스킬:
# * 프로그래밍 언어 파이썬([Python](https://www.python.org/)),
# * 데이터 분석 패키지 판다스([Pandas](https://pandas.pydata.org/)),
# * 데이터 시각화 패키지 [seaborn](https://seaborn.pydata.org)과 [matplotlib](https://matplotlib.org)
#
# 데이터 분석가는 언제나 주변 동료들의 요청(ex: 영업팀, 재무팀, 마케팅팀)에 맞게 데이터를 뽑아내 그 통계치를 제공하고 시각화 결과를 전달해줘야 하는데, 파이썬과 판다스, 시각화 스킬이 부족하면 주어진 시간 내에 이를 전달하는데 어려움이 있게 되는 까닭에,
#
# **Data Scientist 는 데이터를 능숙하게 다룰 수 있는 파이썬과 판다스, 시각화 스킬을 필수적으로 보유하고 있어야 한다고** 일반적으로 언급합니다.

# %% [markdown]
# ## `데이터 시각화 (Data Visualization)` : matplotlib, seaborn
#
# - matplotlib : 시각화 하기 위해 계산하기 위한 전처리(통계적 연산 등) 작업이 많음
#   [Matplotlib: Python plotting — Matplotlib 3.1.3 documentation](https://matplotlib.org/)
#
# - seaborn : 상대적으로 단순하게 동일한 산출결과 표현을 할 수가 있음
#   https://seaborn.pydata.org/
#
# - plotly : R 에서도 사용가능 하고, 인터액티브한 동작기능을 제공함
#   https://plot.ly/python/
#
# - Bokeh :
#   Bokeh 1.4.0 documentation](https://docs.bokeh.org/en/latest/index.html)
#
# - Altair :
#   [Altair: Declarative Visualization in Python — Altair 4.0.0 documentation](https://altair-viz.github.io/)
#
# - Tableu : 유료
#   https://www.tableau.com/
#
# - D3 (Data-driven documents) : Javascript 로 만들어짐, 전처리를 해주어야 D3가 표현할 수 있음
#   https://d3js.org/

# %% [markdown]
# ### 파이썬의 데이터 시각화 패키지인 seaborn, matplotlib을 사용를 사용한 시각화 :
#
# seaborn은 matplotlib을 기반으로 작동하며 matplotlib에 비해 그래프의 스타일이 이쁘고, 약간의 통계 기능과 사용의 편의성 때문에 널리 쓰이고 있습니다. 하지만, seaborn을 호출하는 순간 matplotlib의 기본 스타일을 바꾸기 때문에 그래프의 모양이 바뀌는 것을 염두에 두셔야 합니다.
#
# matplotlib은 그래프에 매우 다양한 옵션을 주어 섬세하게 그릴수 있지만 그만큼 일일이 코드로 옵션을 지정해주어야 하기 때문에 번거로울 수 있습니다.
#
# - countplot
# - barplot
# - distplot
# - boxplot
# - (pointplot)
# - scatterplot

# %%
# 패키지 불러오기 :
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#%matplotlib inline     
# Python 버전에 따라, 화면에 표시되는 여부 차이가 있을 수 있어서, 미리 선언함

# %%
#pd.set_option('display.max_columns', None) ## 모든 열을 출력한다.
data = pd.read_csv('data/health_2016.csv')

print(data.shape)
print(data.columns)
data.head(5)
# Out:
# (1000, 34)
# Index(['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
#        '체중(5Kg단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진 수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상',
#        '치석', '데이터공개일자'],
#       dtype='object')
#    기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  시력(좌)  \
# 0  2016   465969     1            8    41      170.0       70.0  74.0    0.7
# 1  2016   565871     1           10    41      160.0       60.0  81.0    1.2
# 2  2016   115718     2           11    11      160.0       55.0  71.0    1.0
# 3  2016   767524     1            6    28      180.0       70.0  79.0    1.0
# 4  2016   482178     2            9    11      160.0       60.0  85.0    0.8
#
#    시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  치아마모증유무  \
# 0    0.7  ...   96.0   3.0   NaN          1      NaN    NaN      NaN
# 1    1.0  ...   14.0   1.0   NaN          0      NaN    NaN      NaN
# 2    1.0  ...   20.0   1.0   NaN          1      NaN    NaN      NaN
# 3    0.9  ...   16.0   1.0   NaN          0      NaN    NaN      NaN
# 4    1.2  ...   13.0   1.0   NaN          1      NaN    NaN      NaN
#
#    제3대구치(사랑니)이상   치석   데이터공개일자
# 0           NaN  2.0  20171219
# 1           NaN  NaN  20171219
# 2           NaN  0.0  20171219
# 3           NaN  NaN  20171219
# 4           NaN  0.0  20171219
#
# [5 rows x 34 columns]

# %% [markdown]
# ## plot
#
# 기본적인 시각화 방법을 알아봅니다.
# [countplot](https://seaborn.pydata.org/generated/seaborn.countplot.html)은 데이터의 개수를 나타내는 그래프입니다. 자체적으로 여러 옵션을 지정해줄 수 있으며 이는 연결된 링크에서 예시와 같이 확인할 수 있습니다.

# %% [markdown]
# ### Font 깨지는 문제 해결용 :

# %% [markdown]
# font 설정 오류가 발생할 경우,
#
# import matplotlib as plt
#
# matplotlib.rc('font', family='Malgun Gothic')     # for Windows
#
# matplotlib.rc('font', family='AppleGothic')       # for Mac
#
# matplotlib.rc('axes', unicode_minus=False)        # 숫자 마이너스 폰트가 깨지는 문제 대처용

# %% [markdown]
# ### 경고 메시지 출력안되게...

# %%
#import warnings

# 경고메세지 끄기
#warnings.filterwarnings(action='ignore')

# 다시 출력하게 하기
#warnings.filterwarnings(action='default')
# import matplotlib as plt
plt.rc('font', family='AppleGothic') # for Mac

# %%
#import matplotlib as plt
#matplotlib.rc('font', family='Malgun Gothic') # for Windows
# plt.rc('font', family='Malgun Gothic') # for Windows

# %%
sns.countplot(data=data, x='성별코드')
# Out:
# <AxesSubplot:xlabel='성별코드', ylabel='count'>

# %% [markdown]
# ### Font 글자 더 선명하게 표시하는 설정 :

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
# Out:
# /var/folders/2w/p0zgpvps62gb8jlzgy_v7zgh0000gn/T/ipykernel_1739/2106068084.py:2: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina')

# %%
sns.countplot(data=data, x='성별코드')
# Out:
# <AxesSubplot:xlabel='성별코드', ylabel='count'>

# %%
sns.countplot(data=data, x='시도코드')    # 숫자로 정리한 이유 : 한글이면 길이 들쑥날쑥 & 저장 사이즈가 커지므로 숫자화 시키는게 유리
# Out:
# <AxesSubplot:xlabel='시도코드', ylabel='count'>

# %%
plt.figure(figsize=(10,5))               # 그래프 사이즈 조정할 때 (단위 인치)
sns.countplot(data=data, x='시도코드')    # 숫자로 정리한 이유 : 한글이면 길이 들쑥날쑥 & 저장 사이즈가 커지므로 숫자화 시키는게 유리
# Out:
# <AxesSubplot:xlabel='시도코드', ylabel='count'>

# %% [markdown]
# ## subplots
#
# - 1줄에 2개 이상을 표현하는 방법

# %%
plt.subplots()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
plt.subplots()
sns.countplot(data=data, x='성별코드')
sns.countplot(data=data, x='시도코드')
# Out:
# <AxesSubplot:xlabel='시도코드', ylabel='count'>

# %%
figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)     
figure.set_size_inches(18, 3)
sns.countplot(data=data, x='성별코드')
#sns.countplot(data=data, x='시도코드')
# Out:
# <AxesSubplot:xlabel='성별코드', ylabel='count'>

# %%
figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)      # subplot 의 주어진 명령이라 이해하면 됨
figure.set_size_inches(18, 3)
sns.countplot(data=data, x='성별코드', ax=ax1)
sns.countplot(data=data, x='시도코드', ax=ax2)
# Out:
# <AxesSubplot:xlabel='시도코드', ylabel='count'>

# %% [markdown]
# ## Color
#
# 참고 : [Color palette choices](https://seaborn.pydata.org/examples/color_palettes.html)

# %%
sns.countplot(data=data, x='시도코드', color='r')      # r: Red, g: Green, b: Blue
# Out:
# <AxesSubplot:xlabel='시도코드', ylabel='count'>

# %%
sns.palplot(sns.color_palette("deep", 10))            # 숫자 10 은 10개를 표현한 것

# %%
sns.palplot(sns.color_palette("colorblind", 10))

# %%
sns.palplot(sns.color_palette("coolwarm", 10))

# %%
sns.palplot(sns.color_palette("coolwarm"))

# %%
sns.palplot(sns.color_palette("BuGn", 10))

# %%
sns.palplot(sns.color_palette("BuGn_r", 10))        # r 은 Reverse 의 의미임

# %%
palette = sns.color_palette('coolwarm', 10)
sns.countplot(data=data, x='시도코드', palette=palette)        # palette 에서 10 은 여기 경우 의미가 없음
# Out:
# <AxesSubplot:xlabel='시도코드', ylabel='count'>

# %% [markdown]
# ## CountPlot (중요1)

# %%
sns.countplot(data=data, x='성별코드')
# Out:
# <AxesSubplot:xlabel='성별코드', ylabel='count'>

# %%
sns.countplot(data=data, x='성별코드', hue='흡연상태')
# Out:
# <AxesSubplot:xlabel='성별코드', ylabel='count'>

# %%
sns.countplot(data=data, x='시도코드', hue='흡연상태')
# Out:
# <AxesSubplot:xlabel='시도코드', ylabel='count'>

# %%
plt.figure(figsize=(18, 3))
sns.countplot(data=data, x='시도코드', hue='흡연상태')
# Out:
# <AxesSubplot:xlabel='시도코드', ylabel='count'>

# %%
plt.figure(figsize=(4, 9))
sns.countplot(data=data, y='시도코드', hue='흡연상태')
# Out:
# <AxesSubplot:xlabel='count', ylabel='시도코드'>

# %%
plt.figure(figsize=(4, 9))
sns.countplot(data=data, y='시도코드', hue='성별코드')
# Out:
# <AxesSubplot:xlabel='count', ylabel='시도코드'>

# %% [markdown]
# ## BarPlot (중요2)

# %%
plt.figure(figsize=(18, 3))
sns.barplot(data=data, ci=90, x='연령대코드(5세단위)', y='수축기혈압')     # 기본표현 : 수축기혈압의 평균 mean 을 표시한 것
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='수축기혈압'>

# %%
import numpy as np
plt.figure(figsize=(18, 3))
sns.barplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', estimator=np.sum)     # 합산해볼 경우
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='수축기혈압'>

# %%
plt.figure(figsize=(18, 3))
sns.barplot(data=data, y='연령대코드(5세단위)', x='수축기혈압')      # x, y 를 바꿔서 그려볼 경우,
# Out:
# <AxesSubplot:xlabel='수축기혈압', ylabel='연령대코드(5세단위)'>

# %%
plt.figure(figsize=(3, 9))
sns.barplot(data=data, y='연령대코드(5세단위)', x='수축기혈압', orient='h')      # x, y 를 바꿔서 그려볼 경우, 세로로 표현
# Out:
# <AxesSubplot:xlabel='수축기혈압', ylabel='연령대코드(5세단위)'>

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', estimator=np.mean, ci=False)    # False : 신뢰구간 표시안함
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='수축기혈압'>

# %%
plt.figure(figsize=(18, 4))
sns.barplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', estimator=np.sum, ci='sd')      # sd : 표준편차
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='수축기혈압'>

# %%
plt.figure(figsize=(18, 4))
sns.barplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', estimator=np.mean, ci='sd')      # sd : 표준편차
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='수축기혈압'>

# %% [markdown]
# ## DistPlot (중요3)

# %% [markdown]
# [distplot](https://seaborn.pydata.org/generated/seaborn.distplot.html)은 데이터의 분포를 나타냅니다. 지금까지 다뤘던 그래프들은 옵션이 비슷하였지만 distplot은 옵션이 조금 다릅니다.
#
# - Kernel Density Estimation (KDE, 커널 밀도 추정)

# %%
data['허리둘레']
# Out:
# 0      74.0
# 1      81.0
# 2      71.0
# 3      79.0
# 4      85.0
#        ...
# 995    86.0
# 996    66.0
# 997    66.0
# 998    80.0
# 999    85.0
# Name: 허리둘레, Length: 1000, dtype: float64

# %%
sns.distplot(data['허리둘레'])
# Out:
# /Users/shinminseog/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='허리둘레', ylabel='Density'>

# %%
sns.distplot(data['허리둘레'], kde=False)
# Out:
# /Users/shinminseog/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='허리둘레'>

# %%
sns.distplot(data['허리둘레'], hist=False)
# Out:
# /Users/shinminseog/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='허리둘레', ylabel='Density'>

# %%
data['흡연상태'].value_counts()
# Out:
# 1.0    608
# 3.0    211
# 2.0    181
# Name: 흡연상태, dtype: int64

# %%
# data[data['흡연상태'] == 1]
# Out:
#      기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  \
# 1    2016   565871     1           10    41      160.0       60.0  81.0
# 2    2016   115718     2           11    11      160.0       55.0  71.0
# 3    2016   767524     1            6    28      180.0       70.0  79.0
# 4    2016   482178     2            9    11      160.0       60.0  85.0
# 5    2016   893589     2           14    41      145.0       40.0  76.0
# ..    ...      ...   ...          ...   ...        ...        ...   ...
# 994  2016   250945     2           13    29      155.0       75.0  90.0
# 995  2016   206725     2           12    41      150.0       60.0  86.0
# 996  2016   339681     2           12    48      155.0       55.0  66.0
# 997  2016   653494     2           11    11      155.0       45.0  66.0
# 998  2016   190984     2           14    41      145.0       50.0  80.0
#
#      시력(좌)  시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  치아마모증유무  \
# 1      1.2    1.0  ...   14.0   1.0   NaN          0      NaN    NaN      NaN
# 2      1.0    1.0  ...   20.0   1.0   NaN          1      NaN    NaN      NaN
# 3      1.0    0.9  ...   16.0   1.0   NaN          0      NaN    NaN      NaN
# 4      0.8    1.2  ...   13.0   1.0   NaN          1      NaN    NaN      NaN
# 5      0.9    0.9  ...   11.0   1.0   NaN          0      NaN    NaN      NaN
# ..     ...    ...  ...    ...   ...   ...        ...      ...    ...      ...
# 994    1.0    1.0  ...   33.0   1.0   NaN          0      NaN    NaN      NaN
# 995    0.8    0.8  ...   34.0   1.0   NaN          0      NaN    NaN      NaN
# 996    0.8    0.7  ...   21.0   1.0   NaN          0      NaN    NaN      NaN
# 997    1.2    1.0  ...   16.0   1.0   NaN          1      NaN    NaN      NaN
# 998    0.5    0.5  ...   17.0   1.0   NaN          0      NaN    NaN      NaN
#
#      제3대구치(사랑니)이상   치석   데이터공개일자
# 1             NaN  NaN  20171219
# 2             NaN  0.0  20171219
# 3             NaN  NaN  20171219
# 4             NaN  0.0  20171219
# 5             NaN  NaN  20171219
# ..            ...  ...       ...
# 994           NaN  NaN  20171219
# 995           NaN  NaN  20171219
# 996           NaN  NaN  20171219
# 997           NaN  0.0  20171219
# 998           NaN  NaN  20171219
#
# [608 rows x 34 columns]

# %%
one = data[data['흡연상태'] == 1]
two = data[data['흡연상태'] == 2]
three = data[data['흡연상태'] == 3]

# %%
one.head(3)
# Out:
#    기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  시력(좌)  \
# 1  2016   565871     1           10    41      160.0       60.0  81.0    1.2
# 2  2016   115718     2           11    11      160.0       55.0  71.0    1.0
# 3  2016   767524     1            6    28      180.0       70.0  79.0    1.0
#
#    시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  치아마모증유무  \
# 1    1.0  ...   14.0   1.0   NaN          0      NaN    NaN      NaN
# 2    1.0  ...   20.0   1.0   NaN          1      NaN    NaN      NaN
# 3    0.9  ...   16.0   1.0   NaN          0      NaN    NaN      NaN
#
#    제3대구치(사랑니)이상   치석   데이터공개일자
# 1           NaN  NaN  20171219
# 2           NaN  0.0  20171219
# 3           NaN  NaN  20171219
#
# [3 rows x 34 columns]

# %%
plt.figure(figsize=(9, 3))
#sns.distplot(one['허리둘레'], hist=False, label="흡연 안 함")             #파랑 OLD
#sns.distplot(two['허리둘레'], hist=False, label='흡연 했지만 그만 둠')    #주황 OLD
#sns.distplot(three['허리둘레'], hist=False, label='흡연 중')              #녹색 OLD
sns.kdeplot(one['허리둘레'])    #파랑
sns.kdeplot(two['허리둘레'])    #주황
sns.kdeplot(three['허리둘레'])  #녹색
plt.legend(labels=['흡연 안 함', '흡연 했지만 그만 둠', '흡연 중'])

# %% [markdown]
# ## BoxPlot (매우!중요4)
#
# - 최소, 중앙(median), 최대, 1, 3 사분위 수 등을 표현함
# - 점(diamond형) 은 이상치 outlier 의미
#
# 1) 최소값
# 2) 제 1사분위수
# 3) 제 2사분위수, 즉 중앙값
# 4) 제 3사분위수
# 5) 최댓값

# %% [markdown]
# [boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)은 박스 모양의 그래프이며 데이터의 분포를 조금 더 세밀하게 볼 수 있는 plot입니다.

# %% [markdown]
# ### 분위수 (Quantile)

# %% [markdown]
# 중앙값이 데이터를 2개의 동일한 사이즈로 나누었을 때, 그 경계값을 의미한다면, 4분위수는 데이터를 4개의 동일한 사이즈로 나누었을 때 그 경계값들을 의미합니다.
#
# 자료의 1/4 (25%) 지점을 1분위수, 2/4 (50%) 지점을 2분위수 (=중앙값), 3/4 (75%) 지점을 3분위수라고 합니다. 이를 그림으로 나타내면 아래와 같습니다.

# %% [markdown]
# ![image](https://i.imgur.com/tssRkgA.jpg)

# %% [markdown]
# <img src="https://i.imgur.com/CnFsXL9.png" width=450>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(18, 5))
sns.boxplot(data=data, x='연령대코드(5세단위)', y='수축기혈압')
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='수축기혈압'>

# %%
plt.figure(figsize=(18, 5))
sns.boxplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', hue='성별코드')
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='수축기혈압'>

# %% [markdown]
# ## PointPlot (참고)

# %% [markdown]
# [pointplot](https://seaborn.pydata.org/generated/seaborn.pointplot.html)은 점(point)을 찍고 연결하여 나타내는 그래프입니다. pointplot은 추세를 보기 좋으며 옵션은 barplot과 동일합니다.

# %%
plt.figure(figsize=(18, 5))
sns.pointplot(data=data, x='연령대코드(5세단위)', y='수축기혈압')
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='수축기혈압'>

# %%
plt.figure(figsize=(18, 5))
sns.pointplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', hue='성별코드')
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='수축기혈압'>

# %%
# 위에서 오류난다면, 
plt.figure(figsize=(18, 5))
sns.lineplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', hue='성별코드')   # lineplot 으로 그려본다
# Out:
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='수축기혈압'>

# %%
plt.figure(figsize=(18, 5))
sns.pointplot(data=data, x='연령대코드(5세단위)', y='수축기혈압', hue='성별코드', 
             linestyles=[':','--'], markers=['o','x'])
# Out:
# /Users/shinminseog/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((1.0, 0.4980392156862745, 0.054901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,
# <AxesSubplot:xlabel='연령대코드(5세단위)', ylabel='수축기혈압'>

# %% [markdown]
# ## ScatterPlot (중요5)
#
# - x, y 축에 수치형 데이터일 때 표현하기 좋음

# %% [markdown]
# [scatterplot](https://seaborn.pydata.org/generated/seaborn.scatterplot.html?highlight=scatterplot#seaborn.scatterplot)은 산점도를 뜻하며 모든 데이터를 점을 찍어 나타냅니다. 자체적으로 여러 옵션을 지정해줄 수 있으며 이는 연결된 링크에서 예시와 같이 확인할 수 있습니다.
#
# *참고: Scatterplot은 0.9.0 버전 이상의 seaborn에서만 지원하기 때문에 0.9.0 이하의 버전에서는 [lmplot](https://seaborn.pydata.org/generated/seaborn.lmplot.html)을 사용하거나 seaborn의 버전을 업데이트하면 됩니다.

# %%
plt.figure(figsize=(9, 5))
sns.scatterplot(data=data, x='식전혈당(공복혈당)', y='수축기혈압')   # 400 넘는 이상치 값이 확인되어 제거하기로 함
# Out:
# <AxesSubplot:xlabel='식전혈당(공복혈당)', ylabel='수축기혈압'>

# %%
target = data[data['식전혈당(공복혈당)'] < 150]

# %%
plt.figure(figsize=(9, 5))
sns.scatterplot(data=target, x='식전혈당(공복혈당)', y='수축기혈압')
# Out:
# <AxesSubplot:xlabel='식전혈당(공복혈당)', ylabel='수축기혈압'>

# %%
plt.figure(figsize=(10, 9))
sns.scatterplot(data=target, x='식전혈당(공복혈당)', y='수축기혈압',
               hue='허리둘레', size='총콜레스테롤', sizes=(30, 550))
# Out:
# <AxesSubplot:xlabel='식전혈당(공복혈당)', ylabel='수축기혈압'>

# %%
data1 = pd.read_csv("./data/weight_log.csv")
data1
# Out:
#    회차   이름         측정일   몸무게  단위   담당   지점
# 0   1  홍길동  2020-03-01  76.4  kg  박길동  관악구
# 1   2  홍길동  2020-03-02  75.7  kg  김길동  관악구
# 2   3  홍길동  2020-03-03  76.0  kg  고길동  여의도
# 3   4  홍길동  2020-03-04   NaN  kg  고길동  여의도
# 4   5  홍길동  2020-03-05  76.2  kg  김길동  강남구
# 5   6  홍길동  2020-03-06  75.7  kg  고길동  서초구
# 6   7  홍길동  2020-03-07   NaN  kg  고길동  서초구
# 7   8  홍길동  2020-03-08   NaN  kg  김길동  서초구
# 8   9  홍길동  2020-03-09  75.0  kg  김길동  서초구

# %%
data1.shape
# Out:
# (9, 7)

# %%
data1['몸무게'] = data1['몸무게'].ffill()

# %%
data1
# Out:
#    회차   이름         측정일   몸무게  단위   담당   지점
# 0   1  홍길동  2020-03-01  76.4  kg  박길동  관악구
# 1   2  홍길동  2020-03-02  75.7  kg  김길동  관악구
# 2   3  홍길동  2020-03-03  76.0  kg  고길동  여의도
# 3   4  홍길동  2020-03-04  76.0  kg  고길동  여의도
# 4   5  홍길동  2020-03-05  76.2  kg  김길동  강남구
# 5   6  홍길동  2020-03-06  75.7  kg  고길동  서초구
# 6   7  홍길동  2020-03-07  75.7  kg  고길동  서초구
# 7   8  홍길동  2020-03-08  75.7  kg  김길동  서초구
# 8   9  홍길동  2020-03-09  75.0  kg  김길동  서초구

# %%
sns.countplot(data=data1, x='측정일', hue='몸무게')
# Out:
# <AxesSubplot:xlabel='측정일', ylabel='count'>

# %%
plt.figure(figsize=(15, 6))
sns.barplot(data=data1, x='측정일', y='몸무게', hue='담당')
# Out:
# <AxesSubplot:xlabel='측정일', ylabel='몸무게'>

# %%
plt.figure(figsize=(18, 6))
sns.distplot(data1['몸무게'])
# Out:
# /Users/shinminseog/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='몸무게', ylabel='Density'>

# %%
dam_one = data1[data1['담당'] == '박길동']
dam_two = data1[data1['담당'] == '김길동']
dam_thr = data1[data1['담당'] == '고길동']

# %%
plt.figure(figsize=(15, 7))
sns.kdeplot(dam_one['몸무게'])    #파랑
sns.kdeplot(dam_two['몸무게'])    #주황
sns.kdeplot(dam_thr['몸무게'])  #녹색
# plt.legend(labels=['흡연 안 함', '흡연 했지만 그만 둠', '흡연 중'])
# Out:
# /Users/shinminseog/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='몸무게', ylabel='Density'>
