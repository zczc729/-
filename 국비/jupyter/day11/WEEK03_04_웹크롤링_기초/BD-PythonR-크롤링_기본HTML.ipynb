# %% [markdown]
# # 입문자를 위한, 파이썬/R 데이터 분석

# %% [markdown]
# ## Today's mission
#
# - 데이터 수집
#   - 웹 데이터 수집 개념
#   - 웹 데이터 기본 구조
#   - 웹 데이터 HTML
# - Python 파이썬 관련 라이브러리 : Beautiful Soup
# - 실습 (1) HTML 파일 활용
# - 실습 (2) Chrome 브라우저 도구활용
# - 실습 (3) 사이트 크롤링

# %% [markdown]
# ]

# %% [markdown]
# ### 웹 데이터 수집 개념 :
#  - 크롤링(crawling) 과 스크래핑(Scraping)
#  - 웹 크롤러는 웹 페이지를 Chrome, IE 와 같은 브라우저로 접속하지 않고, Python 파이썬같은 프로그래밍 언어로 접속하여, 필요한 내용만 가져옴

# %% [markdown]
# ![%EC%BA%A1%EC%B2%981.JPG](attachment:%EC%BA%A1%EC%B2%981.JPG)

# %% [markdown]
# ### 웹 데이터 기본 구조 :
#  - CSS + HTML + Java

# %% [markdown]
# ![%EC%BA%A1%EC%B2%982.JPG](attachment:%EC%BA%A1%EC%B2%982.JPG)

# %% [markdown]
# ### 웹 데이터 HTML :
#  - HTML코드는 웹페이지를 제공하는 사람(웹사이트 운영자)과 이를 이용하는 사람(ex: 검색엔진, 브라우저)간의 규약
#  - 규약은 규약일 뿐, 너무 복잡하게 생각할 필요는 없음

# %% [markdown]
# ##### 주요 HTML 태그
#
# - h3 - 제목 (header)
# - p - 단락 (paragraph)
# - span - 개행 안 하는 단락
# - div - 구역(divison)
# - dl - 설명 리스트 (description list)
# - dt - 설명 헤더 (description header)
# - dd - 설명 내용
# - img - 이미지(image)
# - a - 링크(anchor)

# %% [markdown]
# ### Python 파이썬 관련 라이브러리 : Beautiful Soup
#  - 1) 뷰티플숩은 Crawling, Scraping 등을 위해 설계된 파이썬 패키지/라이브러리
#
#    (스크린 스크래핑의 대표적인 예로서, 웹 화면에서 데이터를 가져오는 웹 크롤링이라 이해하면 됨)

# %% [markdown]
# ##### 주요 특징
#
# - 1) HTML 구문 분석, 트리 탐색, 검색 및 수정을 위한 간단한 방법과 파이썬 기능을 활용하여 데이터 수집 프로그램 작성이 쉬움
# - 2) 대부분의 문서 Encoding 자동 변환 (Unicode <-> UTF-8)
#      ex) unicode (세계문자 표준 기준코드, 16bit), UTF-8 (3bytes/1자), euc-kr (한글 2bytes/1자)
# - 3) lxml, html5lib 등 기능적 라이브러리를 사용하면, 속도 및 호환성 높은 응용프로그램 제작이 가능
#
# ##### 참고 site :
# - https://www.crummy.com/software/BeautifulSoup/
# - https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# ### 실습 (1) HTML 파일 활용
#  - 자료 다운로드 : https://github.com/PinkWink/DataScience/blob/master/data/03.%20test_first.html

# %%
# 패키지 설치 (일반적으로 Anaconda 에 기본으로 설치되어 있음)
#!pip install beautifulsoup4

# %%
# 패키지 import
from bs4 import BeautifulSoup

# %% [markdown]
# ##### [참고]  import      vs.     from [모듈] import
#
# `import` 모듈 : 해당 모듈 전체를 가져온다.
#
#
#
# `from 모듈 import 메소드 / 변수`  :  해당 모듈 내에 있는 특정 메소드나 모듈 내 정의된 변수를 가져온다.

# %%
# HTML 파일 읽어들이기
page = open("data/test_first.html",'r').read()
page
# Out:
# '<!DOCTYPE html>\n<html>\n    <head>\n        <title>Very Simple HTML Code by PinkWink</title>\n    </head>\n    <body>\n        <div>\n            <p class="inner-text first-item" id="first">\n                Happy PinkWink.\n                <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>\n            </p>\n            <p class="inner-text second-item">\n                Happy Data Science.\n                <a href="https://www.python.org" id="py-link">Python</a>\n            </p>\n        </div>\n        <p class="outer-text first-item" id="second">\n            <b>\n                Data Science is funny.\n            </b>\n        </p>\n        <p class="outer-text">\n            <b>\n                All I need is Love.\n            </b>\n        </p>\n    </body>\n</html>'

# %%
# 읽어들인 HTML 문서 전체를 변수 soup 저장
soup = BeautifulSoup(page, features='html.parser') # lxml 또는 html5lib
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
soup.children

# %%
#html 코드에 포함된 한단계 아래(하위) Tag태그 정보 표시:
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
# soup 문서 전체 저장변수 중, html 태그만 취할 경우,
html = list(soup.children)[2]
html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
#html 코드에 포함된 한단계 아래(하위) Tag태그 정보 표시:
list(html.children)
# Out:
# ['\n',
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>,
#  '\n',
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>,
#  '\n']

# %%
print(list(html.children))
# Out:
# ['\n', <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>, '\n', <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>, '\n']

# %%
# html 문서 전체 저장변수 중, body 태그만 취할 경우,
body = list(html.children)[3]
body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
# soup 저장변수에서 head, body 찾는 다른 방법
soup.head
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
# body 저장변수 하위에 태그tag 확인방법 :
list(body.children)[1]
# Out:
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>

# %%
# 유용한 명령/함수 : find, find_all
soup.find('p')                           # 1개 , 첫번째 것을 찾을 때
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.find_all('p')                       # p 태그 전체 찾을 때
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>,
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>,
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(class_="outer-text")       # class 가 outer-text 찾을 때
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(id="first")                # id 가 first인 태그 찾을 때
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
soup.find_all('p', class_="outer-text")  # p 태그의 class가 outer-text 것 찾을 때
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all('b')
# Out:
# [<b>
#                  Data Science is funny.
#              </b>,
#  <b>
#                  All I need is Love.
#              </b>]

# %%
soup.find_all('a')#, link='http://www.pinkwink.kr')
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
soup.find_all('a', href='http://www.pinkwink.kr')
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>]

# %% [markdown]
# ####  예시 :  href 속성으로 링크주소 찾아보기

# %%
soup.find_all('a')      # 클릭링크에 해당하는 a 테그를 먼저 찾음
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
link = soup.find_all('a')
link
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
type(link)
# Out:
# bs4.element.ResultSet

# %%
link[1]['href']
# Out:
# 'https://www.python.org'

# %%
link[0].string #.text
# Out:
# 'PinkWink'

# %%
for each in link:
    print(each)
    href = each['href']
    text = each.string
    print(text, href)
    print(text + ' => ', href)
    print()
# Out:
# <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# PinkWink http://www.pinkwink.kr
# PinkWink =>  http://www.pinkwink.kr
#
# <a href="https://www.python.org" id="py-link">Python</a>
# Python https://www.python.org
# Python =>  https://www.python.org

# %% [markdown]
# ### 실습 (2) Chrome 브라우저 도구활용

# %% [markdown]
# ##### 예시) naver 환율정보
#
# - url = 'https://finance.naver.com/marketindex/?tabSel=exchange#tab_section'

# %% [markdown]
# - requests 모듈 설치:
#
# !pip install requests
#
# - 파이썬에서 HTTP 요청을 만들기 위한 표준으로서, 간단한 API로 요청처리를 할 수 있도록 해주는 패키지/라이브러리/모듈

# %%
#!pip install requests

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 환율정보 url GET 방식으로 요청
url = 'https://finance.naver.com/marketindex'
market_index = requests.get(url)

# %%
market_index#.content           # 200 : 응답코드 200 은 서버의 응답이 정상,   404 : url 이 잘못되거나 오
# Out:
# <Response [200]>

# %%
# HTML parser 이용해 soup 객체 생성
soup = BeautifulSoup(market_index.content, 'html.parser')
soup
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindo.1.5.3.element-text-patch.js" type="text/javascript"></script>
# <div id="container" style="padding-bottom:0px;">
# <div class="market_include">
# <div class="market_data">
# <div class="market1">
# <div class="title">
# <h2 class="h_market1"><span>환전 고시 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="exchangeList">
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_up">
# <span class="value">1,378.10</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change">2.10</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.11 15:21</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">259</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head jpy" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyt', '', '', event);">
# <h3 class="h_lst"><span class="blind">일본 JPY(100엔)</span></h3>
# <div class="head_info point_up">
# <span class="value">876.24</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change">0.06</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_JPYKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.11 15:21</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">259</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head eur" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurt', '', '', event);">
# <h3 class="h_lst"><span class="blind">유럽연합 EUR</span></h3>
# <div class="head_info point_up">
# <span class="value">1,484.28</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change">3.15</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_EURKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.11 15:21</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">259</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head cny" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyt', '', '', event);">
# <h3 class="h_lst"><span class="blind">중국 CNY</span></h3>
# <div class="head_info point_up">
# <span class="value">189.66</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change">0.27</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_CNYKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.11 15:21</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">259</span>회</span>
# </div>
# </li>
# </ul>
# </div>
# <!-- //data -->
# </div>
# <div class="market2">
# <div class="title">
# <h2 class="h_market2"><span>국제 시장 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="worldExchangeList">
# <li class="on">
# <a class="head jpy_usd" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_USDJPY" onclick="clickcr(this, 'fr2.jpyut', '', '', event);">
# <h3 class="h_lst"><span class="blind">달러/일본 엔</span></h3>
# <div class="head_info point_up">
# <span class="value">156.9000</span>
# <span class="txt_jpy"><span class="blind">엔</span></span>
# <span class="change">0.2200</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_USDJPY" onclick="clickcr(this, 'fr2.jpyuc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDJPY.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.10</span>
# <span class="source">모닝스타 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head usd_eur" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_EURUSD" onclick="clickcr(this, 'fr2.eurdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">유로/달러</span></h3>
# <div class="head_info point_dn">
# <span class="value">1.0734</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change"> 0.0082</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_EURUSD" onclick="clickcr(this, 'fr2.eurdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_EURUSD.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.10</span>
# <span class="source">모닝스타 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head usd_gbp" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_GBPUSD" onclick="clickcr(this, 'fr2.gbpdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">영국 파운드/달러</span></h3>
# <div class="head_info point_dn">
# <span class="value">1.2717</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change"> 0.0011</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_GBPUSD" onclick="clickcr(this, 'fr2.gbpdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_GBPUSD.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.10</span>
# <span class="source">모닝스타 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head usd_idx" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_USDX" onclick="clickcr(this, 'fr2.indt', '', '', event);">
# <h3 class="h_lst"><span class="blind">달러인덱스</span></h3>
# <div class="head_info point_up">
# <span class="value">105.1100</span>
# <span class="change">0.2600</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_USDX" onclick="clickcr(this, 'fr2.indc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDX.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.10</span>
# <span class="source">ICE 기준</span>
# </div>
# </li>
# </ul>
# </div>
# <!-- //data -->
# </div>
# <div class="market3">
# <div class="title">
# <h2 class="h_market3"><span>유가·금시세</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="oilGoldList">
# <li class="on">
# <a class="head wti" href="/marketindex/worldOilDetail.naver?marketindexCd=OIL_CL&amp;fdtc=2" onclick="clickcr(this, 'fr3.wtit', '', '', event);">
# <h3 class="h_lst"><span class="blind">WTI</span></h3>
# <div class="head_info point_up">
# <span class="value">77.74</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change">2.21</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldOilDetail.naver?marketindexCd=OIL_CL&amp;fdtc=2" onclick="clickcr(this, 'fr3.wtic', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/OIL_CL.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.10</span>
# <span class="source">NYMEX(뉴욕상업거래소) 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head gasoline" href="/marketindex/oilDetail.naver?marketindexCd=OIL_GSL" onclick="clickcr(this, 'fr3.oilt', '', '', event);">
# <h3 class="h_lst"><span class="blind">휘발유</span></h3>
# <div class="head_info point_dn">
# <span class="value">1655.1</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 1.92</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/oilDetail.naver?marketindexCd=OIL_GSL" onclick="clickcr(this, 'fr3.oilc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/OIL_GSL.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.11</span>
# <span class="source">한국석유공사 Opinet 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head gold_inter" href="/marketindex/worldGoldDetail.naver?marketindexCd=CMDT_GC&amp;fdtc=2" onclick="clickcr(this, 'fr3.agoldt', '', '', event);">
# <h3 class="h_lst"><span class="blind">국제 금</span></h3>
# <div class="head_info point_up">
# <span class="value">2327.0</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change">2.00</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldGoldDetail.naver?marketindexCd=CMDT_GC&amp;fdtc=2" onclick="clickcr(this, 'fr3.agoldc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/CMDT_GC.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.10</span>
# <span class="source">COMEX(뉴욕상품거래소) 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head gold_domestic" href="/marketindex/goldDetail.naver" onclick="clickcr(this, 'fr3.kgoldt', '', '', event);">
# <h3 class="h_lst"><span class="blind">국내 금</span></h3>
# <div class="head_info point_dn">
# <span class="value">101956.96</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 358.27</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/goldDetail.naver" onclick="clickcr(this, 'fr3.kgoldc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/CMDT_GD.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2024.06.11 15:18</span>
# <span class="source">신한은행 기준</span>
# 							(<span class="num">155</span>회차)
# 					</div>
# </li>
# </ul>
# </div>
# <!-- //data -->
# </div>
# </div>
# </div>
# <div class="marketindex_content _replaceNewsLink" id="content">
# <div class="section_news">
# <h3 class="h_market"><span>환율 주요뉴스</span></h3>
# <div class="list_area">
# <ul>
# <li>
# <p><a href="/news/news_read.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429&amp;office_id=001&amp;article_id=0014738909" onclick="clickcr(this, 'mhn.list', '001_0014738909', '0', event);">원/달러 환율, 1,370원대 중반 보합권</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>06.11 09:12</span>
# </li>
# <li>
# <p><a href="/news/news_read.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429&amp;office_id=001&amp;article_id=0014738710" onclick="clickcr(this, 'mhn.list', '001_0014738710', '1', event);">힘 붙은 멕시코 '슈퍼 집권당'…힘 빠진 </a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>06.11 04:25</span>
# </li>
# <li>
# <p><a href="/news/news_read.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429&amp;office_id=001&amp;article_id=0014737989" onclick="clickcr(this, 'mhn.list', '001_0014737989', '2', event);">유럽 극우약진·佛조기총선에 불확실성↑…유로</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>06.10 16:52</span>
# </li>
# <li>
# <p><a href="/news/news_read.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429&amp;office_id=015&amp;article_id=0004995000" onclick="clickcr(this, 'mhn.list', '015_0004995000', '3', event);">美 고용 탄탄했네…원·달러 환율 10원 넘</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>06.10 16:28</span>
# </li>
# <li>
# <p><a href="/news/news_read.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429&amp;office_id=001&amp;article_id=0014737763" onclick="clickcr(this, 'mhn.list', '001_0014737763', '4', event);">원/달러 환율, 미국 고용 서프라이즈에 1</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>06.10 15:43</span>
# </li>
# <li>
# <p><a href="/news/news_read.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429&amp;office_id=001&amp;article_id=0014736569" onclick="clickcr(this, 'mhn.list', '001_0014736569', '5', event);">원/달러 환율, 美 고용 서프라이즈에 장초</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>06.10 09:32</span>
# </li>
# <li>
# <p><a href="/news/news_read.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429&amp;office_id=001&amp;article_id=0014736567" onclick="clickcr(this, 'mhn.list', '001_0014736567', '6', event);">원/달러 15원 이상 올라</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>06.10 09:31</span>
# </li>
# <li>
# <p><a href="/news/news_read.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429&amp;office_id=001&amp;article_id=0014736566" onclick="clickcr(this, 'mhn.list', '001_0014736566', '7', event);">원/달러 15원 이상 올라</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>06.10 09:30</span>
# </li>
# <li>
# <p><a href="/news/news_read.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429&amp;office_id=001&amp;article_id=0014736564" onclick="clickcr(this, 'mhn.list', '001_0014736564', '8', event);">코스피 장 초반 2,690대로 밀려, 코스</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>06.10 09:30</span>
# </li>
# <li>
# <p><a href="/news/news_read.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429&amp;office_id=001&amp;article_id=0014736563" onclick="clickcr(this, 'mhn.list', '001_0014736563', '9', event);">코스피 장 초반 2,690대로 밀려, 코스</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>06.10 09:30</span>
# </li>
# </ul>
# </div>
# <a class="btn_more" href="/news/news_list.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429" onclick="clickcr(this, 'mhn.more', '', '', event);"><img alt="더보기" height="18" src="https://ssl.pstatic.net/static/nfinance/btn_more.gif" width="34"/></a>
# </div>
# <div class="tab_default1" id="tab_section">
# <ul>
# <li class="on"><a href="./?tabSel=exchange#tab_section" onclick="clickcr(this, 'mtb.exnoti', '', '', event);"><span class="tab1">환전고시 환율</span></a></li>
# <li class=""><a href="./?tabSel=worldExchange#tab_section" onclick="clickcr(this, 'mtb.interex', '', '', event);"><span class="tab2">국제시장 환율</span></a></li>
# <li class=""><a href="./?tabSel=gold#tab_section" onclick="clickcr(this, 'mtb.oilgold', '', '', event);"><span class="tab3">유가 금시세</span></a></li>
# <li class=""><a href="./?tabSel=materials#tab_section" onclick="clickcr(this, 'mtb.material', '', '', event);"><span class="tab4">원자재</span></a></li>
# </ul>
# <h2 class="blind">환전고시 환율</h2>
# </div>
# <div class="section_calculator">
# <h3 class="h_calculator"><span>환율계산기 (매매기준율 기준)</span></h3>
# <div class="calculator">
# <div class="inner">
# <div class="input">
# <div class="selectbox-noscript" id="sInput">
# <select class="selectbox-source" id="select_from">
# <option label="1" value="1">대한민국 원 KRW</option>
# <option class="selectbox-default" label="1" selected="selected" value="1378.1"> 미국 달러 USD</option>
# <option label="1" value="1378.1"> 미국 달러 USD</option>
# <option label="1" value="1484.28"> 유럽연합 유로 EUR</option>
# <option label="100" value="8.7624"> 일본 엔 JPY</option>
# <option label="1" value="189.66"> 중국 위안 CNY</option>
# <option label="1" value="176.49"> 홍콩 달러 HKD</option>
# <option label="1" value="42.56"> 대만 달러 TWD</option>
# <option label="1" value="1753.63"> 영국 파운드 GBP</option>
# <option label="1" value="3579.48"> 오만 리알 OMR</option>
# <option label="1" value="1001.71"> 캐나다 달러 CAD</option>
# <option label="1" value="1537.2"> 스위스 프랑 CHF</option>
# <option label="1" value="131.59"> 스웨덴 크로나 SEK</option>
# <option label="1" value="910.51"> 호주 달러 AUD</option>
# <option label="1" value="844.43"> 뉴질랜드 달러 NZD</option>
# <option label="1" value="60.22"> 체코 코루나 CZK</option>
# <option label="1" value="1.5"> 칠레 페소 CLP</option>
# <option label="1" value="42.53"> 튀르키예 뉴리라 TRY</option>
# <option label="1" value="0.41"> 몽골 투그릭 MNT</option>
# <option label="1" value="367.59"> 이스라엘 세켈 ILS</option>
# <option label="1" value="198.97"> 덴마크 크로네 DKK</option>
# <option label="1" value="129.51"> 노르웨이 크로네 NOK</option>
# <option label="1" value="367.47"> 사우디아라비아 리얄 SAR</option>
# <option label="1" value="4493.02"> 쿠웨이트 디나르 KWD</option>
# <option label="1" value="3655.53"> 바레인 디나르 BHD</option>
# <option label="1" value="375.19"> 아랍에미리트 디르함 AED</option>
# <option label="1" value="1943.72"> 요르단 디나르 JOD</option>
# <option label="1" value="28.89"> 이집트 파운드 EGP</option>
# <option label="1" value="37.49"> 태국 바트 THB</option>
# <option label="1" value="1019.19"> 싱가포르 달러 SGD</option>
# <option label="1" value="291.88"> 말레이시아 링깃 MYR</option>
# <option label="100" value="0.0848"> 인도네시아 루피아 IDR</option>
# <option label="1" value="377.98"> 카타르 리얄 QAR</option>
# <option label="1" value="3.06"> 카자흐스탄 텡게 KZT</option>
# <option label="1" value="1019.19"> 브루나이 달러 BND</option>
# <option label="1" value="16.5"> 인도 루피 INR</option>
# <option label="1" value="4.94"> 파키스탄 루피 PKR</option>
# <option label="1" value="11.73"> 방글라데시 타카 BDT</option>
# <option label="1" value="23.49"> 필리핀 페소 PHP</option>
# <option label="1" value="75.0"> 멕시코 페소 MXN</option>
# <option label="1" value="257.36"> 브라질 레알 BRL</option>
# <option label="100" value="0.0542"> 베트남 동 VND</option>
# <option label="1" value="73.57"> 남아프리카 공화국 랜드 ZAR</option>
# <option label="1" value="15.54"> 러시아 루블 RUB</option>
# <option label="1" value="3.77"> 헝가리 포린트 HUF</option>
# <option label="1" value="343.45"> 폴란드 즈워티 PLN</option>
# <option label="1" value="4.54"> 스리랑카 루피 LKR</option>
# <option label="1" value="10.23"> 알제리 알제리 디나르 DZD</option>
# <option label="1" value="10.64"> 케냐 실링 KES</option>
# <option label="1" value="0.35"> 콜롬비아 페소 COP</option>
# <option label="1" value="0.53"> 탄자니아 실링 TZS</option>
# <option label="1" value="10.32"> 네팔 루피 NPR</option>
# <option label="1" value="298.25"> 루마니아 레우 RON</option>
# <option label="1" value="283.02"> 리비아 리비아 디나르 LYD</option>
# <option label="1" value="171.26"> 마카오 파타카 MOP</option>
# <option label="1" value="0.66"> 미얀마 짯 MMK</option>
# <option label="1" value="23.91"> 에티오피아 비르 ETB</option>
# <option label="1" value="0.11"> 우즈베키스탄 숨 UZS</option>
# <option label="1" value="0.33"> 캄보디아 리엘 KHR</option>
# <option label="1" value="615.32"> 피지 피지 달러 FJD</option>
# </select>
# <div class="selectbox-box" onclick="clickcr(this, 'exl*c.clist1', '', '', event);">
# <div class="selectbox-label"></div>
# </div>
# <div class="selectbox-layer ly_calculator">
# <div class="selectbox-list"></div>
# </div>
# </div>
# <div class="input_area" id="input_from">
# <input id="input_from_money" maxlength="10" onclick="clickcr(this, 'exl*c.unit1', '', '', event);" onfocus="changeActiveInput('from', 'to'); return false;" onkeyup="calcExchange('from', 'to', 'on', event);" type="text" value="1"/>
# <img alt="" height="13" id="img_from_monetary" src="https://ssl.pstatic.net/static/nfinance/img_money_USD.gif" width="26"/>
# </div>
# </div>
# <div class="same"><img alt="" height="15" src="https://ssl.pstatic.net/static/nfinance/ico_same.gif" width="28"/></div>
# <div class="view">
# <div class="selectbox-noscript" id="sView">
# <select class="selectbox-source" id="select_to">
# <option class="selectbox-default" label="1" value="1">대한민국 원 KRW</option>
# <option label="1" value="1">대한민국 원 KRW</option>
# <option label="1" value="1378.1">미국 달러 USD</option>
# <option label="1" value="1484.28">유럽연합 유로 EUR</option>
# <option label="100" value="8.7624">일본 엔 JPY</option>
# <option label="1" value="189.66">중국 위안 CNY</option>
# <option label="1" value="176.49">홍콩 달러 HKD</option>
# <option label="1" value="42.56">대만 달러 TWD</option>
# <option label="1" value="1753.63">영국 파운드 GBP</option>
# <option label="1" value="3579.48">오만 리알 OMR</option>
# <option label="1" value="1001.71">캐나다 달러 CAD</option>
# <option label="1" value="1537.2">스위스 프랑 CHF</option>
# <option label="1" value="131.59">스웨덴 크로나 SEK</option>
# <option label="1" value="910.51">호주 달러 AUD</option>
# <option label="1" value="844.43">뉴질랜드 달러 NZD</option>
# <option label="1" value="60.22">체코 코루나 CZK</option>
# <option label="1" value="1.5">칠레 페소 CLP</option>
# <option label="1" value="42.53">튀르키예 뉴리라 TRY</option>
# <option label="1" value="0.41">몽골 투그릭 MNT</option>
# <option label="1" value="367.59">이스라엘 세켈 ILS</option>
# <option label="1" value="198.97">덴마크 크로네 DKK</option>
# <option label="1" value="129.51">노르웨이 크로네 NOK</option>
# <option label="1" value="367.47">사우디아라비아 리얄 SAR</option>
# <option label="1" value="4493.02">쿠웨이트 디나르 KWD</option>
# <option label="1" value="3655.53">바레인 디나르 BHD</option>
# <option label="1" value="375.19">아랍에미리트 디르함 AED</option>
# <option label="1" value="1943.72">요르단 디나르 JOD</option>
# <option label="1" value="28.89">이집트 파운드 EGP</option>
# <option label="1" value="37.49">태국 바트 THB</option>
# <option label="1" value="1019.19">싱가포르 달러 SGD</option>
# <option label="1" value="291.88">말레이시아 링깃 MYR</option>
# <option label="100" value="0.0848">인도네시아 루피아 IDR</option>
# <option label="1" value="377.98">카타르 리얄 QAR</option>
# <option label="1" value="3.06">카자흐스탄 텡게 KZT</option>
# <option label="1" value="1019.19">브루나이 달러 BND</option>
# <option label="1" value="16.5">인도 루피 INR</option>
# <option label="1" value="4.94">파키스탄 루피 PKR</option>
# <option label="1" value="11.73">방글라데시 타카 BDT</option>
# <option label="1" value="23.49">필리핀 페소 PHP</option>
# <option label="1" value="75.0">멕시코 페소 MXN</option>
# <option label="1" value="257.36">브라질 레알 BRL</option>
# <option label="100" value="0.0542">베트남 동 VND</option>
# <option label="1" value="73.57">남아프리카 공화국 랜드 ZAR</option>
# <option label="1" value="15.54">러시아 루블 RUB</option>
# <option label="1" value="3.77">헝가리 포린트 HUF</option>
# <option label="1" value="343.45">폴란드 즈워티 PLN</option>
# <option label="1" value="4.54">스리랑카 루피 LKR</option>
# <option label="1" value="10.23">알제리 알제리 디나르 DZD</option>
# <option label="1" value="10.64">케냐 실링 KES</option>
# <option label="1" value="0.35">콜롬비아 페소 COP</option>
# <option label="1" value="0.53">탄자니아 실링 TZS</option>
# <option label="1" value="10.32">네팔 루피 NPR</option>
# <option label="1" value="298.25">루마니아 레우 RON</option>
# <option label="1" value="283.02">리비아 리비아 디나르 LYD</option>
# <option label="1" value="171.26">마카오 파타카 MOP</option>
# <option label="1" value="0.66">미얀마 짯 MMK</option>
# <option label="1" value="23.91">에티오피아 비르 ETB</option>
# <option label="1" value="0.11">우즈베키스탄 숨 UZS</option>
# <option label="1" value="0.33">캄보디아 리엘 KHR</option>
# <option label="1" value="615.32">피지 피지 달러 FJD</option>
# </select>
# <div class="selectbox-box" onclick="clickcr(this, 'exl*c.clist2', '', '', event);">
# <div class="selectbox-label"></div>
# </div>
# <div class="selectbox-layer ly_calculator">
# <div class="selectbox-list"></div>
# </div>
# </div>
# <div class="input_area" id="input_to">
# <input id="input_to_money" maxlength="10" onclick="clickcr(this, 'exl*c.unit2', '', '', event);" onfocus="changeActiveInput('to', 'from'); return false;" onkeyup="calcExchange('to', 'from', 'on', event);" type="text"/>
# <img alt="" height="13" id="img_to_monetary" src="https://ssl.pstatic.net/static/nfinance/img_money_KRW.gif" width="26"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section_exchange">
# <div id="section_ex1">
# <h3 class="blind" id="exchange1">환전 고시 환율</h3>
# <div class="exchange_info">
# <span class="date">2024.06.11 15:21</span>
# <span class="standard">하나은행 기준</span>
# <span class="round">고시회차 <em>259</em>회</span>
# </div>
# <iframe frameborder="0" height="1800px" id="frame_ex1" marginheight="0" marginwidth="0" scrolling="no" src="/marketindex/exchangeList.naver" title="환전 고시 환율" width="100%"></iframe>
# </div>
# <ul class="tbl_info">
# <li>통화명과 심볼은 앞에 위치한 통화에 1이 생략된 형태로, 달러/일본 엔(심볼: USDJPY)인 경우 1 USD(달러)가 JPY(일본 엔)으로 얼마인가를 의미합니다.</li>
# </ul>
# </div>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.Component.1.0.3.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.UIComponent.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.HTMLComponent.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.Timer.1.0.3.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.LayerManager.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.LayerPosition.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.RolloverArea.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.RolloverClick.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.SelectBox.1.0.1.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.TextRange.1.0.1.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.WatchInput.1.0.1.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.Formatter.1.1.0.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindoComponent/jindo.NumberFormatter.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/exchange.js" type="text/javascript"></script>
# <script type="text/javascript">
# // exchangeDetail.jsp에도 동일 스크립트 있음 - 로딩시 디자인이 0.5초간 디자인이 안뜬다는 이슈로 include하지 않고 같은 스크립트를 두벌로 관리함
#
# //환율 계산
# function calcExchange(str1, str2, cssOn, event) {
# 	var oEvent = event || window.event;
#     var sKeyCode = (undefined === oEvent) ? undefined : jindo.$Event(oEvent).key().keyCode;
#
# 	if (sKeyCode != 13 && sKeyCode != 27 && sKeyCode != 37 && sKeyCode != 38 && sKeyCode != 110 && sKeyCode != 229) {
# 		if (str1 == '' && str2 == '') {
# 			if (jindo.$('input_to').className == 'input_area') {
# 				str1 = 'from';
# 				str2 = 'to';
# 			} else {
# 				str1 = 'to';
# 				str2 = 'from';
# 			}
# 		}
#
# 		var regExp = new RegExp("[^0-9\.\,]");
# 	    var sInputValue = jindo.$('input_' + str1 + '_money').value;
#
# 	    if(regExp.test(sInputValue)){
# 			alert('숫자, 소수점(.)만 입력하실 수 있습니다.');
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		// 사용자가 입력한 콤마(,) 제거
# 	    if (sInputValue.substr(sInputValue.length - 1, 1) == ',') {
# 	    	jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 	    	return false;
# 	    }
#
# 		// 맨 앞에 있는 숫자 0 없애기
# 		if (sInputValue == '0' || sInputValue == '.' || sInputValue == ',') {
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		// 소수점 2개가 없도록
# 		var match = sInputValue.match(/\./g);
# 		if (match != null && match.length >= 2) {
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		// 소수점을 입력한 경우, 일단 대기
# 		var pointPosIndex = sInputValue.indexOf('.');
# 		if (pointPosIndex != -1 && pointPosIndex == sInputValue.length - 1) {
# 			return false;
# 		}
#
# 		// 소수점 2자리 유지
# 		if (pointPosIndex != -1 && sInputValue.substring(pointPosIndex + 1, sInputValue.length).length > 2) {
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		var e_select_from	= jindo.$('select_'+str1);
# 		var e_select_to	= jindo.$('select_'+str2);
#
# 		var input_from_money	= jindo.$('input_'+str1+'_money').value ;
# 		var input_from		= e_select_from.options[e_select_from.selectedIndex].value ;
# 		var input_to		= e_select_to.options[e_select_to.selectedIndex].value ;
# 		var unit_from	= e_select_from.options[e_select_from.selectedIndex].text ;
# 		var unit_to		= e_select_to.options[e_select_to.selectedIndex].text ;
# 		input_from_money = input_from_money.replace(/ |,|\t/g, "") ;
# 		input_from	= input_from.replace(/ |,|\t/g, "") ;
# 		input_to	= input_to.replace(/ |,|\t/g, "") ;
# 		unit_from = unit_from.substr(unit_from.length-3, 3);
# 		unit_to = unit_to.substr(unit_to.length-3, 3);
#
# 		var str1_result = input_from_money * 1 ;
# 		var str1_str	= str1_result.toFixed(0) ;
# 		var str1_len = str1_str.length ;
# 		var str1_result_str = new String("") ;
#
# 		if(str1_str > str1_result)
# 			str1_str = new String(str1_str-1) ;
#
# 		if (str1_len >= 3) {
# 			for (i = str1_len - 3; i > 0; i-=3)
# 				str1_result_str = "," + str1_str.substr(i, 3) + str1_result_str ;
#
# 			str1_result_str = str1_str.substr(0, 3+i) + str1_result_str ;
#
# 			for (var i=0; i<input_from_money.length; i++) {
# 				if (input_from_money.substr(i,1) != '0') {
# 					input_from_money = input_from_money.substring(i,input_from_money.length) ;
# 					break;
# 				}
# 			}
#
# 			if (str1_str != input_from_money) {
# 				str1_result_str += str1_result.toFixed(input_from_money.split(".")[1].length).substr(str1_len, input_from_money.split(".")[1].length + 1) ;
# 			}
# 		} else
# 			str1_result_str = input_from_money ;
#
# 		var str2_result = input_from_money * input_from / input_to ;
# 		var str2_str	= str2_result.toFixed(0) ;
# 		var str2_len = str2_str.length ;
# 		var str2_result_str = new String("") ;
#
# 		if (str2_str > str2_result)
# 			str2_str = new String(str2_str-1) ;
#
# 		if (str2_len >= 3) {
# 			for (i = str2_len - 3; i > 0; i-=3)
# 				str2_result_str = "," + str2_str.substr(i, 3) + str2_result_str ;
#
# 			str2_result_str = str2_str.substr(0, 3+i) + str2_result_str ;
# 			str2_result_str += str2_result.toFixed(2).substr(str2_len, 3) ;
# 		} else
# 			str2_result_str = str2_result.toFixed(2) ;
#
# 		jindo.$('input_'+str1+'_money').value = str1_result_str;
# 		jindo.$('input_'+str2+'_money').value = str2_result_str;
# 		jindo.$('img_'+str1+'_monetary').src = "https://ssl.pstatic.net/static/nfinance/img_money_"+unit_from+".gif";
# 		jindo.$('img_'+str2+'_monetary').src = "https://ssl.pstatic.net/static/nfinance/img_money_"+unit_to+".gif";
# 		jindo.$Element(jindo.$('input_'+str1)).addClass("on");
# 		jindo.$Element(jindo.$('input_'+str2)).removeClass("on");
# 		if (cssOn == "off"){
# 			jindo.$Element(jindo.$('input_'+str1)).removeClass("on");
# 		}
# 	}
# }
#
# function revertInputText(sOrgText) {
# 	var sResult = sOrgText;
#
# 	if (sOrgText != '') {
# 		sResult = sOrgText.substr(0, sOrgText.length - 1);
# 	}
#
# 	return sResult;
# }
#
# jindo.$Fn(function(){
# 	chartMouseOverEvent('exchangeList');
#    }).attach(document, "domready");
# </script>
# </div>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/jindo_ellipse.js"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/util.js"></script>
# <script type="text/javascript">
#
# function ellipseTopNewsTitle() {
# 	jindo.EllipseText.factory(jindo.$$(".news_list ul li"), {nAssistWidth: 10});
# }
#
# var basicDates;
#
# function initDate() {
# 	basicDates = jindo.$H();
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# }
#
# var basicDescriptions;
#
# function initDescription() {
# 	basicDescriptions = jindo.$H();
# 	basicDescriptions.add('CMDT_CDY','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_PDY','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_NG','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_S','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_C','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_SB','<em></em>  기준<span>단위:</span>');
# }
#
# function setEvent(num, imgChartUrl){
# 	var parentElemnt = jindo.$$('.tbl_market')[num];
# 	var elementList = jindo.$$('tr',parentElemnt);
#
# 	jindo.$Fn(function(e){
# 		var elementListSize = elementList.length;
#
# 		for(var i = 0 ; i < elementListSize ; i ++)
# 		{
# 			var selectedElement = jindo.$Element(elementList[i]);
# 			var selectedClassName = selectedElement.className();
# 			if (selectedClassName != "") {
# 				selectedElement.removeClass(selectedClassName);
# 				selectedElement.addClass(selectedClassName.replace("on",""));
# 			}
# 		}
#
# 		var ele = jindo.$Element(jindo.$Event(e).currentElement);
# 		var linkUrl = jindo.$$.getSingle('a' , ele.$value()).href;
# 		var marketindexCd = linkUrl.split('=')[1];
# 		var className = ele.className();
# 		ele.removeClass(className);
# 		ele.addClass(className+" on");
# 		var graphElement = jindo.$Element(jindo.$$('.thum')[num]);
# 		graphElement.html('<a href=\"'+linkUrl+'\"><img src=\"https://ssl.pstatic.net/imgfinance/chart/marketindex/' + marketindexCd + '.png\" width=\"295\" height=\"153\" alt=""></a>');
#
# 		if (basicDates.hasKey(marketindexCd)) {
# 			jindo.$Element("basicDate").text(basicDates.$(marketindexCd));
# 		}
# 		if (basicDescriptions.hasKey(marketindexCd)) {
# 			jindo.$Element("basicDescription").html(basicDescriptions.$(marketindexCd));
# 		}
#
# 	}).attach(elementList, "mouseover");
# }
#
# jindo.$Fn(function(){
# 		initDate();
# 		initDescription();
# 		chartMouseOverEvent('exchangeList');
# 		chartMouseOverEvent('worldExchangeList');
# 		chartMouseOverEvent('oilGoldList');
# 		jindo.$$('title')[0].innerHTML = "시장지표 : 네이버페이 증권";
# }).attach(document, "domready");
#
# </script>
# <div class="aside" id="marketindex_aside">
# <div class="section_aside">
# <h3 class="h_interest"><span>국내시장금리</span></h3>
# <table class="tbl_exchange market" summary="국제시장 환율 리스트">
# <caption>국내시장금리</caption>
# <colgroup>
# <col width="94"/>
# <col width="50"/>
# <col width="75"/>
# </colgroup>
# <thead>
# <tr>
# <th>구분</th>
# <th>금리</th>
# <th>등락율</th>
# </tr>
# </thead>
# <tbody>
# <tr class="same">
# <th class="th_inter4"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_CD91" onclick="clickcr(this, 'rid.local', 'IRR_CD91', '1', event);"><span>CD금리(91일)</span></a></th>
# <td>3.60</td>
# <td><img alt="보합" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_same2.gif" width="7"/> 0.00</td>
# </tr>
# <tr class="up">
# <th class="th_inter1"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_CALL" onclick="clickcr(this, 'met.8', 'IRR_CALL', '2', event);"><span>콜 금리</span></a></th>
# <td>3.59</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.01</td>
# </tr>
# <tr class="up">
# <th class="th_inter2"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_GOVT03Y" onclick="clickcr(this, 'met.8', 'IRR_GOVT03Y', '3', event);"><span>국고채 (3년)</span></a></th>
# <td>3.35</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.05</td>
# </tr>
# <tr class="up">
# <th class="th_inter3"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_CORP03Y" onclick="clickcr(this, 'met.8', 'IRR_CORP03Y', '4', event);"><span>회사채 (3년)</span></a></th>
# <td>3.78</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.05</td>
# </tr>
# <tr class="down">
# <th class="th_inter5"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_COFIXBAL" onclick="clickcr(this, 'met.8', 'IRR_COFIXBAL', '5', event);"><span>COFIX 잔액</span></a></th>
# <td>3.76</td>
# <td><img alt="하락" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_down.gif" width="7"/> 0.02</td>
# </tr>
# <tr class="down">
# <th class="th_inter6"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_COFIXNEW" onclick="clickcr(this, 'met.8', 'IRR_COFIXNEW', '6', event);"><span>COFIX 신규취급액</span></a></th>
# <td>3.54</td>
# <td><img alt="하락" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_down.gif" width="7"/> 0.05</td>
# </tr>
# </tbody>
# </table>
# <table class="tbl_exchange tbl_exchange_v1 market" style="margin-top:10px;" summary="달러 인덱스">
# <caption>달러 인덱스</caption>
# <colgroup>
# <col width="88"/>
# <col width="46"/>
# <col width="66"/>
# </colgroup>
# <thead>
# <tr>
# <th>구분</th>
# <th>금리</th>
# <th>등락율</th>
# </tr>
# </thead>
# <tbody>
# <tr class="other_t1 up">
# <th class="th_inter7"><a href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_USDX&amp;fdtc=4" onclick="clickcr(this, 'rid.dollar', 'FX_USDX', '', event);"><span>달러 인덱스</span></a></th>
# <td>105.1100</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.2600</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="section_aside">
# <div class="tab_search search3">
# <a href="#" onclick="clickcr(this, 'rch.1', '', '', event); return false;"><span>최근조회</span></a>
# <a href="#" onclick="clickcr(this, 'rch.3', '', '', event); return false;"><span>MY STOCK</span></a>
# </div>
# <h3 class="blind">최근조회</h3>
# <table class="tbl_search" summary="최근조회 리스트">
# <caption>최근조회</caption>
# <colgroup>
# <col/>
# <col width="55"/>
# <col width="87"/>
# </colgroup>
# <thead>
# <tr>
# <th>업체명</th>
# <th>거래량</th>
# <th>전일비</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <div class="more_info">
# <span>
# <a href="#" onclick="clickcr(this, 'rch.5', '', '', event); return false;"><img alt="이전" height="15" src="https://ssl.pstatic.net/static/nfinance/btn_prev2.gif" width="17"/></a>
# <a href="#" onclick="clickcr(this, 'rch.6', '', '', event); return false;"><img alt="다음" height="15" src="https://ssl.pstatic.net/static/nfinance/btn_next2.gif" width="17"/></a>
# </span>
# <a class="btn_more _mystock_more_info" href="#" onclick="javascript:openMyitemNew('https://' + window.location.hostname); clickcr(this, 'rch.7', '', '', event);"><img alt="더보기" height="10" src="https://ssl.pstatic.net/static/nfinance/btn_more5.gif" width="33"/></a>
# </div>
# </div>
# <div class="section_aside">
# <h3 class="h_report"><span>경제분석 리포트 </span></h3>
# <ul class="list_report">
# <li><a href="/research/economy_read.naver?nid=10376" onclick="clickcr(this, 'rer.list', '', '', event);">06/11 Kiwoom Morni...</a></li>
# <li><a href="/research/economy_read.naver?nid=10375" onclick="clickcr(this, 'rer.list', '', '', event);">정치 리스크를 맞이한 유로</a></li>
# <li><a href="/research/economy_read.naver?nid=10374" onclick="clickcr(this, 'rer.list', '', '', event);">고용과 FOMC에 임하는 자세</a></li>
# <li><a href="/research/economy_read.naver?nid=10373" onclick="clickcr(this, 'rer.list', '', '', event);">아직 초읽기가 남아있다: 인하가 ...</a></li>
# <li><a href="/research/economy_read.naver?nid=10372" onclick="clickcr(this, 'rer.list', '', '', event);">미국 5월 비농업 고용: 여전히 ...</a></li>
# </ul>
# <a class="btn_more" href="/research/economy_list.naver" onclick="clickcr(this, 'rer.more', '', '', event);"><img alt="경제분석 리포트 더보기" height="18" src="https://ssl.pstatic.net/static/nfinance/btn_more.gif" width="34"/></a>
# </div>
# </div>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/info/myStock.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20240604222219/js/util.js" type="text/javascript"></script>
# <script language="javascript">
#
# function toggleTabSearch(e){
# 	var currentElement = jindo.$Element(jindo.$Event(e).currentElement);
# 	var parentElement = currentElement.parent();
# 	var id = currentElement.className();
# 	var order = parentElement.indexOf(currentElement) + 3;
# 	parentElement.className("tab_search search"+ order);
#
# 	// 페이징을 위해서 order값에 따라 최근조회인지 mystock인지 type을 저장
# 	if (order == 3) {
# 		currentType = "recent";
# 	} else {
# 		currentType = "mystock";
# 	}
# }
#
# jindo.$Fn(function(){
# 	if ('true' == 'true') {
# 		getStockRightMenuData('000000', 'recent', 1, 'https://' + window.location.hostname, 'https://ssl.pstatic.net/static/nfinance');
#
# 		var tabSearchArea = jindo.$$.getSingle('.tab_search');
# 		var moreInfoArea = jindo.$Element(jindo.$$.getSingle('.tbl_search')).next().$value();
#
# 		jindo.$Fn(function(e) {toggleTabSearch(e); getStockRightMenuData('000000', 'recent', 1, 'https://' + window.location.hostname, 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$.getSingle('a' ,tabSearchArea), 'click');
# 		jindo.$Fn(function(e) {toggleTabSearch(e); getStockRightMenuData('000000', 'mystock', 1, 'https://' + window.location.hostname, 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$('a' ,tabSearchArea)[1], 'click');
# 		jindo.$Fn(function(e) {updatePageForPaging (currentType, 'up', 'https://' + window.location.hostname, 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$.getSingle('a', moreInfoArea), 'click');
# 		jindo.$Fn(function(e) {updatePageForPaging (currentType, 'down', 'https://' + window.location.hostname, 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$('a', moreInfoArea)[1], 'click');
# 	}
#
# }).attach(document,"domready");
#
# function openMyitemNew(stockHost) {
# 	var selectedElement = jindo.$Element(jindo.$$.getSingle(".tab_search"));
# 	if (selectedElement != null) {
# 		if (selectedElement.hasClass("search1")) {
# 			document.location.href = stockHost + '/mystock/recentSearchItemList.naver';
# 		} else {
# 			document.location.href = stockHost + '/mystock/itemList.naver';
# 		}
# 	}
# }
#
# </script>
# </div>
# <div id="footer">
# <ul>
# <li class="first">
# <a href="https://new-m.pay.naver.com/member/terms-policy/naver-financial-service" onclick="clickcr(this, 'fot.service', '', '', event);" target="_blank">이용약관</a>
# </li>
# <li>
# <a href="https://new-m.pay.naver.com/member/terms-policy/privacy" onclick="clickcr(this, 'fot.privacy', '', '', event);" target="_blank"><strong>개인정보처리방침</strong></a>
# </li>
# <li>
# <a href="/rules.naver" onclick="clickcr(this, 'fot.policy', '', '', event);" target="_blank">게시판 운영원칙</a>
# </li>
# <li>
# <a href="https://help.naver.com/alias/contents2/finance/finance_1.naver" onclick="clickcr(this, 'fot.help', '', '', event);" target="_blank">증권 고객센터</a>
# </li>
# </ul>
# <p class="desc">
# 		네이버파이낸셜(주)이 제공하는 금융 정보는 <a class="desc_help" href="javascript:;" onclick="togglePanelFooter('footerPanel0');">콘텐츠 제공업체</a>로부터 받는 투자 참고사항이며, 오류가 발생하거나 지연될 수 있습니다.<br/>
# 		네이버파이낸셜(주)과 콘텐츠 제공업체는 제공된 정보에 의한 투자 결과에 법적인 책임을 지지 않습니다. 게시된 정보는 무단으로 배포할 수 없습니다.
# 	</p>
# <div class="provider_layer" id="footerPanel0" onblur="hidePannel('footerPanel0')" style="display:none" tabindex="0">
# <strong class="provider_layer__tit">네이버파이낸셜에 콘텐츠 제공</strong>
# <div class="provider_layer__txt">
# <strong>에프앤가이드</strong> 기업 및 재무정보<br/>
# <strong>KG제로인</strong> 해외 시세, 시장지표 정보<br/>
# <strong>한국예탁결제원</strong> 주주총회일, 전자투표 정보<br/>
# <strong>인포스탁</strong> 국내 테마 정보
# 		</div>
# <div class="provider_layer__info">
# <strong class="provider_layer__tit">네이버에 콘텐츠 제공</strong>
# <div class="provider_layer__txt">
# <strong>코스콤</strong> 국내 시세 정보
# 			</div>
# </div>
# <button class="button_close" onclick="hidePannel('footerPanel0')" type="button">
# <img alt="닫기" height="20" src="https://ssl.pstatic.net/static/nfinance/2022/footer_close.png" width="20"/>
# </button>
# </div>
# <address>
# <a class="logo" href="https://www.naverfincorp.com/" onclick="clickcr(this, 'fot.nhn', '', '', event);" target="_blank"><img alt="NAVER FINANCIAL" height="12" src="https://ssl.pstatic.net/static/nfinance/img/logo_financial.png" width="160"/></a>
# </address>
# </div>
# <script type="text/javascript">
# function isVisible(obj) {
#     if (obj == document) return true
#
#     if (!obj) return false
#     if (!obj.parentNode) return false
#     if (obj.style) {
#         if (obj.style.display == 'none') return false
#         if (obj.style.visibility == 'hidden') return false
#     }
#
#     if (window.getComputedStyle) {
#         var style = window.getComputedStyle(obj, "")
#         if (style.display == 'none') return false
#         if (style.visibility == 'hidden') return false
#     }
#
#     var style = obj.currentStyle
#     if (style) {
#         if (style['display'] == 'none') return false
#         if (style['visibility'] == 'hidden') return false
#     }
#
#     return isVisible(obj.parentNode)
# }
#
# function isChildOf(myobj, containerObj) {
# 	while(myobj != undefined) {
# 		if (myobj == document.body) {
# 			break;
# 		}
# 		if (myobj == containerObj) {
# 			return true;
# 		}
# 		myobj = myobj.parentElement;
# 	}
# 	return false;
# }
#
# function gnbLayerClose(e){
# 	var target = e.target ? e.target : e.srcElement;
# 	if (isVisible(document.getElementById('gnb_service_lyr')) || isVisible(document.getElementById('gnb_notice_lyr')) ||isVisible(document.getElementById('gnb_my_lyr')) ) {
# 		if (!isChildOf(target, document.getElementById('gnb'))) {
# 			gnbAllLayerClose();
# 		}
# 	}
# }
#
# function showPannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='block';
#
# 	if (layerId == "summary_lyr") {
# 		var layerHeight = jindo.$Element(layer).height();
# 		jindo.$Element("summary_ifr").height(layerHeight);
# 	}
# }
#
# function hidePannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='none';
# }
#
# function togglePanelFooter(layerId) {
# 	var elTargetLayer = jindo.$Element(jindo.$$.getSingle("#" + layerId));
#
# 	if (elTargetLayer != null) {
# 		if (elTargetLayer.visible()) {
# 			hidePannel(layerId);
# 		} else {
# 			showPannel(layerId);
# 		}
# 	}
# }
#
# var isIE = (navigator.userAgent.toLowerCase().indexOf("msie")!=-1 && window.document.all) ? true:false;
# if (isIE) {
# 	document.attachEvent('onmousedown', gnbLayerClose);
# } else {
# 	window.addEventListener('mousedown', gnbLayerClose);
# }
#
# // _replaceNewsLink class 하위의 a 태그 조회 후 redirect
# jindo.$Fn(function () {
# 	jindo.$$("._replaceNewsLink a").forEach(function(ele){
# 		var urls = ele.href.split("?");
# 		if (urls[0].indexOf("/news_read.naver") > 0 || urls[0].indexOf("/newsRead.naver") > 0) {
# 			var param = jindo.$S(urls[1]).parseString();
# 			var oid = param.office_id ? param.office_id : param.officeId;
# 			var aid = param.article_id ? param.article_id : param.articleId;
#
# 			ele.target = "_blank";
# 			ele.href = jindo.$S("https://n.news.naver.com/mnews/article/%s/%s").format(oid, aid);
# 		}
# 	});
# }).attach(document, "domready");
# </script>

# %%
# CSS 이용해 찾습니다 :  <복사> - <selector 복사>
#exchangeList > li.on > a.head.usd > div > span.value
#exchangeList > li.on > a.head.usd > div > span.value
price = soup.select_one('div > span.value')
print(price)
# Out:
# <span class="value">1,378.10</span>

# %%
#worldExchangeList > li.on > a.head.jpy_usd > div > span.value
price = soup.select_one('li.on > a.head.jpy_usd > div > span.value')
print(price)
# Out:
# <span class="value">156.9000</span>

# %%
#worldExchangeList > li.on > a.head.jpy_usd > div > span.value
price_all = soup.select('div > span.value')
# print(price_all)
# prices = [i.text for i in price_all]
# prices

for i in price_all:
    print(i.text)
# Out:
# 1,378.10
# 876.24
# 1,484.28
# 189.66
# 156.9000
# 1.0734
# 1.2717
# 105.1100
# 77.74
# 1655.1
# 2327.0
# 101956.96

# %%
price_all

# %%
# 결과에서 원하는 요소(element) 내용은 text 또는 string 통해 확인합니다
price.text
# Out:
# '156.9000'

# %%
price.string
# Out:
# '156.9000'

# %%
print('USD/KRW = ', price.text, price.string)
# Out:
# USD/KRW =  156.9000 156.9000

# %%
import pandas as pd
exch_rate = pd.read_html(url, encoding='euc-kr')

# %%
exch_rate
# Out:
# [            구분    금리   등락율
#  0    CD금리(91일)  3.60  0.00
#  1         콜 금리  3.59  0.01
#  2     국고채 (3년)  3.35  0.05
#  3     회사채 (3년)  3.78  0.05
#  4     COFIX 잔액  3.76  0.02
#  5  COFIX 신규취급액  3.54  0.05,
#         구분      금리   등락율
#  0  달러 인덱스  105.11  0.26,
#  Empty DataFrame
#  Columns: [업체명, 거래량, 전일비]
#  Index: []]

# %% [markdown]
# ##### 예시) naver 영화 순위
#
# - url = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn'

# %% [markdown]
# - requests 모듈 설치:
#
# !pip install requests
#
# - 파이썬에서 HTTP 요청을 만들기 위한 표준으로서, 간단한 API로 요청처리를 할 수 있도록 해주는 패키지/라이브러리/모듈

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 영화 랭킹 정보 url을 GET 방식으로 요청
url = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn'
movie_ranking = requests.get(url)
movie_ranking
# Out:
# <Response [200]>

# %%
# HTML parser 이용해 soup 객체 생성
soup = BeautifulSoup(movie_ranking.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <title>영화 end - 주요정보</title>
# <link href="/css/movie_tablet.css" rel="stylesheet" type="text/css"/>
# <link href="/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="/css/layout.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <!-- [D] 영화 리뷰 백업 서비스 안내페이지의 경우 wrap 에 backup 클래스 추가 부탁드립니다. -->
# <div class="basic backup" id="wrap">
# <!-- header -->
# <div id="header">
# <h1 class="svc_name">
# <span class="ci_logo" title="naver로 바로가기"><img alt="NAVER" height="13" src="/img/logo_ci.png" width="62"/></span>
# <span class="svc_logo" title="영화서비스홈으로 바로가기"><img alt="영화" height="19" src="/img/logo_svc.png" width="34"/></span>
# </h1>
# <!-- [D] 각 항목 활성화는 on으로 표기 -->
# <div class="scrollbar scrollbar-noscript" id="scrollbar" style="width:148px">
# <div class="scrollbar-box" style="width:148px">
# <div class="scrollbar-content" style="width:148px">
# <div class="in_scroll">
# <ul class="navi">
# <li>
# <span class="menu_tit" title="서비스 종료 안내"><strong>서비스 종료 안내</strong></span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="scrollbar-v" style="display:none">
# <div class="scrollbar-button-up"></div>
# <div class="scrollbar-track">
# <div class="scrollbar-thumb"></div>
# </div>
# <div class="scrollbar-button-down"></div>
# </div>
# </div>
# </div>
# <!-- //header -->
# <!-- container -->
# <div id="container">
# <!-- content -->
# <div id="content">
# <div class="backup_area">
# <strong class="tit">네이버 영화 PC 서비스 페이지 운영 종료</strong>
# <em class="guide_tit">네이버 영화 서비스 종료 안내 드립니다.</em>
# <div class="period_area">
# <span class="txt">
#                         네이버 영화 PC 서비스 페이지는<br/>
# <strong style="color:#03aa5a">2023년 3월 31일부로</strong> 운영이 종료되었습니다.
#                     </span>
# </div>
# <p class="txt">
#                     그동안 이용하시던 서비스는 네이버 통합 검색 결과 내<br/>
#                     '영화 지식베이스' 영역을 통해 제공 중이니 이용에 참고 부탁드립니다.
#                 </p>
# <p class="txt">감사합니다.</p>
# <a class="download_btn" href="https://help.naver.com/notice/noticeView.help?noticeNo=9323&amp;serviceNo=5612&amp;lang=ko">
# <span class="btn_txt">종료 안내 자세히 보기</span>
# </a>
# </div>
# </div>
# <!-- //content -->
# </div>
# <!-- //container -->
# <!-- footer -->
# <div id="footer">
# <div class="in_footer">
# <div class="foot_con">
# <ul>
# <li class="first"><a href="https://www.naver.com/rules/service.html" target="_blank">이용약관</a><!-- N=a:fot.agreement --></li>
# <li><a href="https://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a><!-- N=a:fot.privacy --></li>
# <li><a href="https://www.naver.com/rules/disclaimer.html" target="_blank">책임의 한계와 법적고지</a><!-- N=a:fot.disclaimer --></li>
# <li><a href="https://help.naver.com/support/service/main.nhn?serviceNo=800" target="_blank">영화 고객센터</a><!-- N=a:fot.help --></li>
# </ul>
# <p class="info">본 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <p class="info">
#                     사업자등록번호 : 220-81-62517<span>통신판매업 신고번호</span> : 경기성남 제 2006 - 692호<span>대표이사 : 최수연</span><span><a href="http://www.ftc.go.kr/info/bizinfo/communicationList.jsp">사업자등록정보 확인</a></span><br/>
#                     주소 : 경기도 성남시 분당구 정자일로 95, NAVER 1784, 13561 <span>대표전화 : 1588-3820</span>
# </p>
# <address>
# <a class="logo" href="https://www.navercorp.com/" target="_blank"><img alt="NAVER" height="11" src="https://ssl.pstatic.net/static/movie/2013/07/logo_naver.png" width="63"/></a>
# <em>Copyright ©</em>
# <a href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# </div>
# </div>
# </div>
# <!-- //footer -->
# </div>
# </body>
# </html>

# %%
soup.find('div')
# Out:
# <div class="basic backup" id="wrap">
# <!-- header -->
# <div id="header">
# <h1 class="svc_name">
# <span class="ci_logo" title="naver로 바로가기"><img alt="NAVER" height="13" src="/img/logo_ci.png" width="62"/></span>
# <span class="svc_logo" title="영화서비스홈으로 바로가기"><img alt="영화" height="19" src="/img/logo_svc.png" width="34"/></span>
# </h1>
# <!-- [D] 각 항목 활성화는 on으로 표기 -->
# <div class="scrollbar scrollbar-noscript" id="scrollbar" style="width:148px">
# <div class="scrollbar-box" style="width:148px">
# <div class="scrollbar-content" style="width:148px">
# <div class="in_scroll">
# <ul class="navi">
# <li>
# <span class="menu_tit" title="서비스 종료 안내"><strong>서비스 종료 안내</strong></span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="scrollbar-v" style="display:none">
# <div class="scrollbar-button-up"></div>
# <div class="scrollbar-track">
# <div class="scrollbar-thumb"></div>
# </div>
# <div class="scrollbar-button-down"></div>
# </div>
# </div>
# </div>
# <!-- //header -->
# <!-- container -->
# <div id="container">
# <!-- content -->
# <div id="content">
# <div class="backup_area">
# <strong class="tit">네이버 영화 PC 서비스 페이지 운영 종료</strong>
# <em class="guide_tit">네이버 영화 서비스 종료 안내 드립니다.</em>
# <div class="period_area">
# <span class="txt">
#                         네이버 영화 PC 서비스 페이지는<br/>
# <strong style="color:#03aa5a">2023년 3월 31일부로</strong> 운영이 종료되었습니다.
#                     </span>
# </div>
# <p class="txt">
#                     그동안 이용하시던 서비스는 네이버 통합 검색 결과 내<br/>
#                     '영화 지식베이스' 영역을 통해 제공 중이니 이용에 참고 부탁드립니다.
#                 </p>
# <p class="txt">감사합니다.</p>
# <a class="download_btn" href="https://help.naver.com/notice/noticeView.help?noticeNo=9323&amp;serviceNo=5612&amp;lang=ko">
# <span class="btn_txt">종료 안내 자세히 보기</span>
# </a>
# </div>
# </div>
# <!-- //content -->
# </div>
# <!-- //container -->
# <!-- footer -->
# <div id="footer">
# <div class="in_footer">
# <div class="foot_con">
# <ul>
# <li class="first"><a href="https://www.naver.com/rules/service.html" target="_blank">이용약관</a><!-- N=a:fot.agreement --></li>
# <li><a href="https://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a><!-- N=a:fot.privacy --></li>
# <li><a href="https://www.naver.com/rules/disclaimer.html" target="_blank">책임의 한계와 법적고지</a><!-- N=a:fot.disclaimer --></li>
# <li><a href="https://help.naver.com/support/service/main.nhn?serviceNo=800" target="_blank">영화 고객센터</a><!-- N=a:fot.help --></li>
# </ul>
# <p class="info">본 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <p class="info">
#                     사업자등록번호 : 220-81-62517<span>통신판매업 신고번호</span> : 경기성남 제 2006 - 692호<span>대표이사 : 최수연</span><span><a href="http://www.ftc.go.kr/info/bizinfo/communicationList.jsp">사업자등록정보 확인</a></span><br/>
#                     주소 : 경기도 성남시 분당구 정자일로 95, NAVER 1784, 13561 <span>대표전화 : 1588-3820</span>
# </p>
# <address>
# <a class="logo" href="https://www.navercorp.com/" target="_blank"><img alt="NAVER" height="11" src="https://ssl.pstatic.net/static/movie/2013/07/logo_naver.png" width="63"/></a>
# <em>Copyright ©</em>
# <a href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# </div>
# </div>
# </div>
# <!-- //footer -->
# </div>

# %% [markdown]
# ### 실습 (3) 네이버지식인
#  - 참고 링크 : https://wikidocs.net/85739
#  - 사이트 정보 : https://kin.naver.com/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://kin.naver.com/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

# %%
url
# Out:
# 'https://kin.naver.com/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
print(response.status_code)
# Out:
# 200

# %%
html = response.text
#html

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta contents="always" name="referrer"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="파이썬의 지식iN Q&amp;A 검색결과입니다. 궁금증을 해결하지 못했다면 지식iN '질문하기'를 해보세요." name="description">
# <meta content="width=1024" name="viewport"/>
# <meta content="none" name="msapplication-config">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20240529105836/css/min/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20240529105836/css/min/components.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20240529105836/css/min/other.css" rel="stylesheet" type="text/css"/>
# <script>
#
# 	var pcDomain = "kin.naver.com";
# 	var pcDomainWithProtocol = "https://kin.naver.com";
# 	var pcKinServiceProtocol = "https";
#
# 	var mobileDomain = "m.kin.naver.com";
# 	var mobileDomainWithProtocol = "https://m.kin.naver.com";
# 	var mobileKinServiceProtocol = "https";
#
# 	var uploadDomain = "upload.kin.naver.com";
# 	var uploadDomainWithProtocol = "https://upload.kin.naver.com";
# 	var uploadKinServiceProtocol = "https";
# </script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20240529105836/js/min/kin.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="noindex,nofollow" name="robots">
# <meta content="파이썬 검색결과 : 네이버 지식iN" property="og:title">
# <meta content="https://kin.naver.com/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static/kin/common/kin_thumbnail_new_w1000.png" property="og:image"/>
# <meta content="파이썬의 지식iN Q&amp;A 검색결과입니다. 궁금증을 해결하지 못했다면 지식iN '질문하기'를 해보세요." property="og:description"/>
# <meta content="네이버 지식iN" property="og:article:author"/>
# <meta content="https://kin.naver.com" property="og:article:author:url"/>
# <link href="/favicon.ico?v=2.4" rel="shortcut icon" type="image/x-icon"/>
# <title>
# 	파이썬 검색결과 : 지식iN
# </title>
# <script type="text/javascript">
#
# if ( typeof window.nhn  == "undefined" ) window.nhn = {};
# if ( typeof window.naver  == "undefined" ) window.naver = {};
# nhn.isLogin = false;
# nhn.isJunior = ("N"=="Y");
# nhn.isKinUser = false;
# nhn.isPortableDevice = false;
# nhn.jsDir = 'https://ssl.pstatic.net/static.kin/static/pc/20240529105836/js/min';
#
# var g_ssc = ("kin.search" == "") ? "kin.temp" : "kin.search";
# var ccsrv="cc.naver.com";
#
#
# var kinRos = {
# 	bIsNoticeDisplay : ("false" == "" || "false" == "false") ? false : true,
# 	bIsActionNoticeDisplay : ("false" == "" || "false" == "false") ? false : true
#
# };
#
#
#
#
#
# var standardReportPopupUrl = "https://srp2.naver.com/report";
#
#
# var baUserKey = "__UNKNOWN__";
# var baLogEndpoint = "https://scv-kin.io.naver.com/jackpotlog/v1/logs";
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="loadingIndicator" style="display:none;width:100%;height:100%;position:fixed;top:0px;left:0px;background-color:transparent;z-index:10000;">
# <img alt="데이터 요청 응답 대기중" height="21" src="https://ssl.pstatic.net/static/kin/m/ico_lod2.gif" style="position:absolute;top:49%;left:49%;" width="21"/>
# </div>
# <div class="wrap wrap_search" id="wrap">
# <div class="skip_nav header_gnb_inner">
# <a class="skip" href="#gnb" onclick="nhn.Kin.Utility.skipNavigation('au_lnb_home');return false;">메인 메뉴 바로가기</a>
# <a class="skip" href="#s_content" onclick="nhn.Kin.Utility.skipNavigation('s_content');return false;">본문 바로가기</a>
# </div>
# <div class="header_wrap">
# <div aria-labelledby="ieUpdateBannerTitle" class="popup popup--header_notice" id="ieUpdateBanner" role="dialog" style="display: none;">
# <h1 class="blind" id="ieUpdateBannerTitle" tabindex="0">권장 브라우저 업데이트 안내</h1>
# <div class="popup__content">
# <div class="popup__title">
# <p class="popup__title_text"><span class="ico_alert sp_common"></span>권장 브라우저 안내</p>
# </div>
# <div class="popup__maintext">
# <p class="popup__text">혹시 아직 인터넷 익스플로러 9.0 미만 버전을 사용하고 계신가요?</p>
# <p class="popup__subtext">새롭게 바뀐 지식iN Q&amp;A 페이지는 IE 9.0 이상의 브라우저에 최적화되어 있습니다. 원활한 이용을 위해 꼭 업데이트 해주세요! <a class="popup__link" href="https://support.microsoft.com/ko-kr/help/17621/internet-explorer-downloads" target="_blank">업데이트하기 <span class="sp_common ico_arr_lnk"></span></a></p>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	// IE8 이하이면 브라우저 버전을 올려달라는 배너를 노출한다.
# 	$Fn(function() {
# 		var oAgent = jindo.$Agent().navigator();
# 		if (oAgent.ie && (oAgent.version >= 6 && oAgent.version < 9)) {
# 			if (typeof naver.kin.SimpleBanner !== "undefined") {
# 				var oIeUpdateBanner = new naver.kin.SimpleBanner({
# 					sBannerId: "ieUpdateBannerArea"
# 				});
# 			}
# 		}
# 	}, this).attach(document, 'domready');
# </script>
# <div class="header_gnb">
# <div class="header_gnb_inner">
# <div class="header_gnb__cell">
# <h1 class="header_logo">
# <a class="logo_naver" href="http://www.naver.com" onclick="nhn.Kin.Utility.nClicks('STA.naverlogo', '', '', event);" title="나의 경쟁력, 네이버"><span class="blind">NAVER</span></a>
# </h1>
# <div class="header_search">
# <h2 class="logo_wrap">
# <a class="icon_logo_kin" href="/" onclick="nhn.Kin.Utility.nClicks('STA.kin', '', '', event);"><span class="blind">지식iN</span></a>
# </h2>
# <h3 class="blind">검색영역</h3>
# <form action="/search/list.naver" id="topSearch" method="get" name="topSearch" onsubmit="return checkQuery();">
# <fieldset>
# <legend>지식인 검색</legend>
# <div class="search_area">
# <input accesskey="s" aria-autocomplete="list" aria-controls="atcmpList" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="search_input" id="nx_query" maxlength="255" name="query" onclick="nhn.Kin.Utility.nClicks('STA.search', '', '', event);return false;" role="combobox" title="검색어 입력" type="text" value="파이썬"/>
# <a class="search_auto" href="#">
# <span class="sp_gnb icon_arrow" id="triangleBtn">자동완성 열기</span>
# </a>
# <div>
# <iframe class="auto_complete_box" frameborder="0" height="193px" id="autoFrame" marginheight="0" marginwidth="0" scrolling="no" title="검색어 자동완성" width="290"></iframe>
# </div>
# <a class="search_btn" href="#" onclick="return checkQuery();"><span class="sp_gnb icon_search">지식iN 검색</span></a>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="header_gnb__cell">
# <div class="gnb_wrap">
# <div class="gnb_eXpertLogo">
# <a aria-controls="bannerExpert" aria-expanded="true" aria-haspopup="true" class="link" href="https://expert.naver.com" id="bannerLink" target="_blank">
# <span class="logo"><span class="blind">eXpert</span></span>
# </a>
# </div>
# <div class="gnb_common_area">
# <div id="gnb">
# <script type="text/javascript">
#
# 								var gnb_service = "kin";
#
# 								var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 								var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 								var gnb_template = "gnb_utf8";
#
# 								var gnb_item_hide_option = 0;
#
#
#
#
# 							</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?2024061115" type="text/javascript"></script>
# </div>
# </div>
# </div>
# <div class="header__rolling rolling-notice">
# <i class="icon_speaker"><span class="blind">실시간 공지사항</span></i>
# <ul class="rolling-notice__list _rolling_banner" id="listNotice">
# <li class="rolling-notice__item _rollingItem" data-start-time="2023-07-03 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://m.expert.naver.com/mobile/expert/account/join/hub" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# <span class="text-color--secondary">지식iN은 누구나 엑스퍼트</span><br/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- nav -->
# <div class="nav" role="navigation">
# <div class="nav_inner">
# <h3 class="blind">메인 메뉴</h3>
# <ul class="nav_list" id="au_lnb" role="menubar">
# <li class="menu" role="presentation">
# <a class="item" href="/index.naver" id="au_lnb_home" onclick="nhn.Kin.Utility.nClicks('LNB.home', '', '', event);" role="menuitem" tabindex="0"><em>홈</em></a>
# </li>
# <li class="menu" role="presentation">
# <a aria-expanded="false" aria-haspopup="true" class="item" href="/qna/list.naver" onclick="nhn.Kin.Utility.nClicks('LNB.qna', '', '', event);" role="menuitem" tabindex="-1"><em>Q&amp;A</em></a>
# <ul class="nav_sub_list _lnbSubMenu" role="menu">
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=11" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '11', '1', event);" role="menuitem" tabindex="-1">교육, 학문</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=1" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '1', '2', event);" role="menuitem" tabindex="-1">컴퓨터통신</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=2" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '2', '3', event);" role="menuitem" tabindex="-1">게임</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=3" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '3', '4', event);" role="menuitem" tabindex="-1">엔터테인먼트, 예술</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=8" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '8', '5', event);" role="menuitem" tabindex="-1">생활</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=7" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '7', '6', event);" role="menuitem" tabindex="-1">건강</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=6" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '6', '7', event);" role="menuitem" tabindex="-1">사회, 정치</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=4" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '4', '8', event);" role="menuitem" tabindex="-1">경제</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=9" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '9', '9', event);" role="menuitem" tabindex="-1">여행</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=10" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '10', '10', event);" role="menuitem" tabindex="-1">스포츠, 레저</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=5" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '5', '11', event);" role="menuitem" tabindex="-1">쇼핑</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=13" onclick="nhn.Kin.Utility.nClicks('LNB.jun', '', '', event);" role="menuitem" tabindex="-1">쥬니버Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=12" onclick="nhn.Kin.Utility.nClicks('LNB.loc', '', '', event);" role="menuitem" tabindex="-1">지역&amp;플레이스</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=20" onclick="nhn.Kin.Utility.nClicks('LNB.talk', '', '', event);" role="menuitem" tabindex="-1">고민Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/opendic/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.open', '', '', event);" role="menuitem" tabindex="-1">오픈사전</a></li>
# </ul>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/qna/questionList.naver" onclick="nhn.Kin.Utility.nClicks('LNB.answer', '', '', event);" role="menuitem" tabindex="-1"><em>답변하기</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/volunteer/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.donation', '', '', event);" role="menuitem" tabindex="-1"><em>지식기부</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/people/elite/index.naver?from=lnb" id="peopleLnbBtn" onclick="nhn.Kin.Utility.nClicks('LNB.people', '', '', event);" role="menuitem" tabindex="-1"><em>사람들</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/best/listaha.naver" onclick="nhn.Kin.Utility.nClicks('LNB.best', '', '', event);" role="menuitem" tabindex="-1"><em>베스트</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/hall/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.honor', '', '', event);" role="menuitem" tabindex="-1"><em>명예의전당</em></a>
# </li>
# <li class="menu" role="presentation">
# <span class="lnb_bar">|</span>
# <a class="item" href="/myinfo/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.profile', '', '', event);" role="menuitem" tabindex="-1"><em>프로필</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/partnercenter/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.partner', '', '', event);" role="menuitem" tabindex="-1"><em>파트너센터</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/roulette/home.naver" onclick="nhn.Kin.Utility.nClicks('LNB.roulette', '', '', event);" role="menuitem" tabindex="-1"><em>룰렛</em></a>
# </li>
# </ul>
# <a class="nav__button_question _clickcode:LNB.q" href="#" onclick="nhn.Kin.checkRosAndGoUrl(event, '/qna/question.naver', '');sendBaLog(BaPcEventType.KIN_HOME_5048)" role="button"><span class="btn_inner"><i class="sp_gnb icon_pencil"></i>질문하기</span></a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# 	$Fn(function() {
# 		new naver.kin.LNB({
# 			'questionType' : ''
# 		});
# 	}).attach(window, 'load');
#
# 	var GNB_BRIGHTNESS_VALUE = {
# 		DARK_ICON : 0,
# 		DARK_ICON_AND_TRANSPARENCY : 1,
# 		BRIGHT_ICON_AND_TRANSPARENCY : 2,
# 		BRIGHT_ICON : 3
# 	};
#
# 	var GNB_ITEM_HIDE_OPTION_BIT_VALUE = {
# 		DEFAULT : 0,
# 		HIDE_LOGIN_BTN : 1,
# 		HIDE_USER_LAYER : 2,
# 		HIDE_NAVER_ME_AREA : 4,
# 		HIDE_MAIL_ALARM_AREA : 8,
# 		HIDE_PROFILE_IMAGE : 16,
# 		SHOW_BENEFIT_FOR_STAFF_MEMBER : 32
# 	};
#
#
# 	var smartSearch = "";
#
# 	var gnb_service = "kin";
#
# 	var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 	var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 	var gnb_template = "gnb_utf8";
#
# 	var gnb_item_hide_option = GNB_ITEM_HIDE_OPTION_BIT_VALUE.DEFAULT;
#
#
#
#
#
# 	$Fn(function() {
#
# 		getGNB();
#
# 		var bIsGnbClicked = false;
#
#
# 		$Fn(function (we) {
# 			if (!bIsGnbClicked) {
# 				gnbAllLayerClose();
# 			}
#
# 			bIsGnbClicked = false;
# 		}, this).attach(document.body, 'click');
#
# 		$Fn(function(we) {
# 			bIsGnbClicked = true;
# 		}, this).attach($('gnb'), 'click');
#
#
# 		try {
# 			$('autoFrame').src = '/static/reatcmp.html?v=4.1';
# 		} catch(e) {
# 		}
#
# 		smartSearch = new nhn.AjaxSuggestUS('nx_query', 'autoFrame', {
# 			url : 'https://ac.search.naver.com/nx/ac',
# 			cookieName : 'NaverSuggestUse',
# 			listbox : '_resultBox',
# 			sFromName : 'topSearch',
# 			triangleBtn : 'triangleBtn',
# 			sListMaxLength : 55,
# 			listMaxCount : 15,
# 			request_type : 'jsonp',
# 			request_data : {
# 				q : '{query}',
# 				st : '100',
# 				r_format : 'json',
# 				t_koreng : '1',
# 				q_enc : 'UTF-8',
# 				r_enc : 'UTF-8',
# 				r_unicode : '0',
# 				r_escape : '1',
# 				frm : 'kin'
# 			},
# 			sTriangleUpOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_up.gif',
# 			sTriangleUpOff : 'https://ssl.pstatic.net/sstatic/search/mypocket/v3/btn_atcmp_off_op2.gif',
# 			sTriangleDownOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down.gif',
# 			sTriangleDownOff : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down3.gif'
# 		}).attach({
# 			actSubmit : function() {
# 				try {
# 					top.selectAction(this._elForm);
# 				} catch(e) {
# 					try {
# 						selectAction(this._elForm);
# 					} catch(e) {
# 					}
# 				}
#
# 				this._elForm.submit();
# 			}
# 		});
#
# 		var expertEntryBanner = $$.getSingle("div.gnb_eXpertLogo div.banner");
# 		if (!!expertEntryBanner) {
# 			var cookie = new $Cookie();
#
# 			$Fn(function () {
# 				$Element(expertEntryBanner).hide();
#
# 				var newDisabledUntil = new Date().getTime() + (3 * 1000 * 24 * 60 * 60);
# 				cookie.set("kin_expert_entry_banner_disabled_until", newDisabledUntil, 5);
# 			}).attach($$.getSingle("div.gnb_eXpertLogo div.banner button.buttonCancel"), 'click');
#
# 			var disabledUntilTimestamp = new Number(cookie.get("kin_expert_entry_banner_disabled_until"));
# 			if (!isNaN(disabledUntilTimestamp)) {
# 				if (new Date().getTime() > disabledUntilTimestamp) {
# 					cookie.remove("kin_expert_entry_banner_disabled_until");
# 					$Element(expertEntryBanner).show();
# 				}
# 			} else {
# 				$Element(expertEntryBanner).show();
# 			}
# 		}
#
#
# 		if (typeof nhn.Kin.ChatMenu !== "undefined") {
# 			window.oChatMenu = new nhn.Kin.ChatMenu();
# 		}
# 	}).attach(window, 'load');
# </script>
# <div class="container-fluid" id="container">
# <div class="container-fluid-content">
# <div class="container-fluid-content-inner">
# <div id="search_result">
# <strong>'파이썬'</strong> 에 대한 검색결과입니다.
#
#
#
# </div>
# <script type="text/javascript">
# function checkAdultAuth() {
# 	var url = "https://" + top.location.hostname + "/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&cs=utf8&section=kin&excludeAdultDoc=false";
# 	var surl = "https://" + top.location.hostname + "/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&cs=utf8&section=kin";
#
# 	try{
#
#
# 			top.location.href = "https://nid.naver.com/nidlogin.login?svctype=128&a_version=2&viewtype=2&url=" + encodeURIComponent(url + "&from=search") + "&surl=" + encodeURIComponent(surl);
#
# 	} catch (e){
# 		history.back();
# 	}
# }
# </script>
# <div class="container-fluid-content__left" id="content">
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20240529105836/js/min/nhn.Kin.Search.Terms.js" type="text/javascript"></script>
# <div id="s_content">
# <div id="scl">
# <ul>
# <li class="tx_depth1"><strong><a class="_nclicks:tab.kin" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=kin" title="전체"><span>전체</span></a></strong></li>
# <li class="tx_depth2"><a class="_nclicks:tab.qna" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna" title="Q&amp;A"><span>Q&amp;A</span></a></li>
# <li class="tx_depth3"><a class="_nclicks:tab.ency" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=ency" title="오픈백과"><span>오픈백과</span></a></li>
# <li>
# </li></ul>
# </div>
# <div class="banner_suicide_stop" id="suicidalPreventionBanner" style="display:none;">
# <div class="content_suicide_stop">
# <h3 class="tit_suicide_stop">
# <span class="blind">생명은 소중합니다.! 지금,희망을 클릭하세요.</span>
# </h3>
# <ul class="info_suicide_stop">
# <li class="counsel_list v1">
# <strong class="tit_counsel_list">전화상담</strong>
# <ul class="counsel_info_list">
# <li>자살예방상담전화 <em>109</em></li>
# <li>정신건강상담전화 <em>1577-0199</em></li>
# <li><a href="https://www.cyber1388.kr:447" target="_blank">청소년 HelpCall</a> <em>1388</em></li>
# <li><a href="https://www.lifeline.or.kr" target="_blank">한국생명의전화</a> <em>1588-9191</em></li>
# <li>한마음한몸자살예방센터 <em>1577-0199</em></li>
# </ul>
# </li>
# <li class="counsel_list v2">
# <strong class="tit_counsel_list">온라인상담</strong>
# <ul class="counsel_info_list">
# <li><a href="https://www.lifeline.or.kr" id="btn_suicide_stop" target="_blank">한국생명의전화</a></li>
# <li><a href="https://www.cyber1388.kr:447" target="_blank">청소년사이버상담센터</a></li>
# </ul>
# </li>
# <li class="counsel_list v3">
# <strong class="tit_counsel_list">지식iN도 여러분을 돕습니다.</strong>
# <ul class="counsel_info_list">
# <li><a href="/qna/question.naver?expertType=doctor&amp;dirId=70109" target="_blank">의사에게질문하기</a></li>
# <li><a href="/profile/index.naver?u=6oCfeacJKVQGwsBB7OHEIS4miiPixwQ%2FoueervNeYrg%3D" target="_blank">여성가족부. 한국청소년상담복지개발원</a></li>
# <li><a href="/profile/index.naver?u=9xhBJX%2Fe3worDHM4Tp9d%2F4jUxoIMOWjkBn9VK4u3x8M%3D" target="_blank">경기도청소년상담복지센터</a></li>
# <li class="list_aside"><a href="/profile/index.naver?u=m61fd7AyyTNGzdSXnfIARZMD2YrqU0TvSai8n3aIfHk%3D" target="_blank">마음상담</a></li>
# <li><span class="counsel_vt">|</span><a href="/profile/index.naver?u=9AFcqSNT5xcmX%2BDwjqumdFA11U6ypJgxKXiNTqx%2FenU%3D" target="_blank">허그맘</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <script type="text/javascript">
# 	jindo.$Fn(function() {
#
#
# 		if(nhn.Kin.Utility.containSuicideKeywords('\uD30C\uC774\uC36C')) {
#
# 			jindo.$Element('suicidalPreventionBanner').show();
# 		}
# 	},this).attach(window,"load");
# 	</script>
# <div class="section">
# <h2>
# <img alt="전체 지식iN" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/h_search_kin_all.gif" width="67"/>
# <span class="number">(<em>1-10/276,360</em>)</span>
# </h2>
# <div class="option_search">
# <ul class="option_sort">
# <li class="sp_sort1"><strong><a aria-current="true" class="_nclicks:kin.relavant" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=kin&amp;sort=none" title="정확도"><span>정확도</span></a></strong></li>
# <li class="sp_sort2"><a class="_nclicks:kin.recent" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=kin&amp;sort=date" title="최신순"><span>최신순</span></a></li>
# <li class="sp_sort3"><a class="_nclicks:kin.vcount" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=kin&amp;sort=vcount" title="추천순"><span>추천순</span></a></li>
# </ul>
# <form name="date_search">
# <input name="sort" type="hidden" value="none">
# <input name="section" type="hidden" value="kin"/>
# <input name="query" type="hidden" value="파이썬"/>
# <input id="au_period" name="period" type="hidden" value=""/>
# </input></form>
# <ul class="option_term">
# <li>
# <div class="selectbox-noscript" id="au_date_select">
# <select class="selectbox-source" id="au_date_result" name="date" title="기간 전체">
# <option class="_nclicks:kin.dateall" selected="" value="0">기간 전체</option>
# <option class="_nclicks:kin.date1w" value="1">최근 1주</option>
# <option class="_nclicks:kin.date1m" value="2">최근 1달</option>
# <option class="selectbox-notclose _nclicks:kin.dateinput" value="2002.01.01.2024.06.11.">기간 입력</option>
# </select>
# <div class="selectbox-box">
# <div class="selectbox-label"></div>
# </div>
# <div class="selectbox-layer">
# <div class="selectbox-list"></div>
# </div>
# </div>
# </li>
# </ul>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20240529105836/js/min/nhn.Kin.Search.DateSelectBox.js" type="text/javascript"></script>
# <script type="text/javascript">
# 			$Fn(function() {
# 				nhn.Kin.Search.DateSelectBox.initialize('PC');
# 			},this).attach(window,"load");
#
# 			</script>
# </div>
# <!-- Search List -->
# <strong class="blind">검색결과</strong>
# <ul class="basic1">
# <li>
# <div class="thumb">
# <a class="_nclicks:kin.img" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=469201467&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=1&amp;search_sort=0&amp;spq=0" target="_blank"><img alt="파이썬 질문" onerror="this.parentNode.parentNode.style.display='none';" src="https://kin-phinf.pstatic.net/20240506_156/1714962124487dc8ph_JPEG/1714962124440.jpeg?type=m100"/></a>
# </div>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=469201467&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=1&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 질문</a>
# </dt>
# <dd class="txt_inline">2024.05.06.</dd>
# <dd><b>파이썬</b> 문제 답 좀 알려주시면 감사하겠습니다! 1) 3,4 - 리스트 인덱스 순서는 자동으로 지정 됨 2) 6 - len() 함수는 리스트의 요소의 수를 리턴해줌. 3) 3... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 1</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
#
# 										<img alt="TOP 100" class="ico_top5" height="11" src="https://ssl.pstatic.net/static/kin/09renewal/ico_badge_top100.gif" width="32">
#
#
#
#
#
#
#
#
# 									tk****
#
#
# 							</img></dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=470084065&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=2&amp;search_sort=0&amp;spq=0" target="_blank">고등학생 <b>파이썬</b> 책</a>
# </dt>
# <dd class="txt_inline">2024.05.25.</dd>
# <dd>... 학교에서 <b>파이썬</b>을 배우고 관련 책을 읽으려 합니다. 이미 <b>파이썬</b>을 배워서 너무 쉬운 거 말고, 심화된 활동을 할 수 있는 고등학교 수준 책 추천해주세요! 그리고 <b>파이썬</b>... </dd>
# <dd class="tag_area">
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EA%B3%A02&amp;listType=answer">#고2</a>
# <a class="em _nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;listType=answer">#파이썬</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D&amp;listType=answer">#프로그래밍</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%B1%85%EC%B6%94%EC%B2%9C&amp;listType=answer">#책추천</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%84%B8%ED%8A%B9&amp;listType=answer">#세특</a>
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 2</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
#
#
# 										<img alt="TOP 50" class="ico_top5" height="11" src="https://ssl.pstatic.net/static/kin/09renewal/ico_badge_top50.gif" width="30">
#
#
#
#
#
#
# 									오렌지팜(i_****)
#
#
#
# 							</img></dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=470117251&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=3&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> pip 설치가 안됨</a>
# </dt>
# <dd class="txt_inline">2024.05.26.</dd>
# <dd>... 서치해보면 <b>파이썬</b> 3.4 이상 버전이면 기본... AppData에 <b>파이썬</b> 자체가 안보여요 이게 진짜 뭐죠... 분명... 그냥 <b>파이썬</b> 관련된 걸 싹 지우고 처음부터 다시 하는... </dd>
# <dd class="tag_area">
# <a class="em _nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;listType=answer">#파이썬</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=pip&amp;listType=answer">#pip</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=pip%EC%84%A4%EC%B9%98&amp;listType=answer">#pip설치</a>
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 2</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									푸른하늘(so****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=461494098&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=4&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 책 추천</a>
# </dt>
# <dd class="txt_inline">2024.06.10.</dd>
# <dd>지금 라즈베리파이로 웹서버 개발중인데 언어를 <b>파이썬</b>으로 개발할려고 해요 하지만... 공부하는 <b>파이썬</b>, 점프 투 <b>파이썬</b> 이런 책들이 있더라구요. 혹시 추천해주실 책이... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 7</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									IT천재가될거얀(py****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=468850324&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=5&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 문법 질문</a>
# </dt>
# <dd class="txt_inline">2024.04.29.</dd>
# <dd><b>파이썬</b>에서 () 와 {} 와 : 와 .:.와 '는 어떨때 사용하는... <b>파이썬</b> 표준 문법에 .:.는 존재하지 않습니다.... 일반적인 <b>파이썬</b> 코드에서는 없습니다. 작은따옴표... </dd>
# <dd class="tag_area">
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%8C%8C%EC%9D%B4%EC%8D%AC%EB%AC%B8%EB%B2%95&amp;listType=answer">#파이썬문법</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%A0%95%EB%B3%B4&amp;listType=answer">#정보</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%A4%91%EA%B0%84%EA%B3%A0%EC%82%AC&amp;listType=answer">#중간고사</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EA%B3%A0%EB%93%B1%ED%95%99%EA%B5%90&amp;listType=answer">#고등학교</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%95%99%EA%B5%90%EC%8B%9C%ED%97%98&amp;listType=answer">#학교시험</a>
# <a class="em _nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;listType=answer">#파이썬</a>
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 1</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									지식공장(sjra****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a class="_nclicks:kin.img" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=468749890&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=6&amp;search_sort=0&amp;spq=0" target="_blank"><img alt="파이썬 문제 풀어주세요" onerror="this.parentNode.parentNode.style.display='none';" src="https://kin-phinf.pstatic.net/20240426_2/17141383442607pBRT_PNG/1.png?type=m100"/></a>
# </div>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=468749890&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=6&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 문제 풀어주세요</a>
# </dt>
# <dd class="txt_inline">2024.04.26.</dd>
# <dd><b>파이썬</b> 처음이라 잘 모르겠네요 "" isalnum() 함수는 주어진 문자열이 알파벳과 숫자로 이루어져 있으면 True 를 반환합니다.</dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 2</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
#
#
# 										<img alt="TOP 50" class="ico_top5" height="11" src="https://ssl.pstatic.net/static/kin/09renewal/ico_badge_top50.gif" width="30">
#
#
#
#
#
#
# 									ncode(xtel****)
#
#
#
# 							</img></dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a class="_nclicks:kin.img" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=469950105&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=7&amp;search_sort=0&amp;spq=0" target="_blank"><img alt="파이썬 입력과 변수 질문" onerror="this.parentNode.parentNode.style.display='none';" src="https://kin-phinf.pstatic.net/20240521_86/1716298162354xxhfM_PNG/%BD%BA%C5%A9%B8%B0%BC%A6_2024-05-21_222754.png?type=m100"/></a>
# </div>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=469950105&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=7&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 입력과 변수 질문</a>
# </dt>
# <dd class="txt_inline">2024.05.21.</dd>
# <dd><b>파이썬</b> 코들에서 하고있는데 너무 불친절하게 나와서요 어떻게 해야하는지 풀이와 정답좀 알려주세요,,, (아래가 문제입니다) .을 기준으로 나눠서 마지막 부분과 .을 합치면... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 2</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									엑플하나하나(7edi****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=11&amp;dirId=110704&amp;docId=469733497&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=8&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b>독학 어떻게들 하고 계신가요?</a>
# </dt>
# <dd class="txt_inline">2024.05.17.</dd>
# <dd><b>파이썬</b>독학하고자 합니다. 코딩 공부를 하고 싶은데 C언어보다... <b>파이썬</b>독학 어떻게들 하고 계신지 공유 부탁드립니다. <b>파이썬</b>독학 어떻게들 하고 계신가요? <b>파이썬</b>독학하고자... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=110704">직업교육</a>
# <span class="bar">|</span>
# <span class="">답변수 3</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=467785974&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=9&amp;search_sort=0&amp;spq=0" target="_blank">중1 <b>파이썬</b> 독학</a>
# </dt>
# <dd class="txt_inline">2024.04.10.</dd>
# <dd>... 중1이고 코딩은 처음인데 <b>파이썬</b>부터 시작하면 좋다고 해서 <b>파이썬</b> 독학을 할 생각인데 <b>파이썬</b> 독학 교재는 뭐가 좋을까요? 그리고 <b>파이썬</b>을 배우면 어디에 쓸 수 있나요?... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 1</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									으뜸아빠(obon****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=467972762&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=10&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 해커 되는법 <b>파이썬</b> 해킹에 관해서</a>
# </dt>
# <dd class="txt_inline">2024.04.15.</dd>
# <dd>... <b>파이썬</b>으로 해커가 될수 있나요? 2. <b>파이썬</b>으로 해킹 공부하려면 어떤 공부를 해야되나요? 3.<b>파이썬</b>으로 해킹 할수있는게 몇개정도 되나요? 4.<b>파이썬</b> 심화 과정까지 공부... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 3</span>
# </dd>
# </dl>
# </li>
# </ul>
# <div class="s_paging">
# <strong>1</strong>
# <a href="/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;page=2" onclick="nhn.Kin.Utility.nClicks('kin.page','','2',event);">2</a>
# <a href="/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;page=3" onclick="nhn.Kin.Utility.nClicks('kin.page','','3',event);">3</a>
# <a href="/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;page=4" onclick="nhn.Kin.Utility.nClicks('kin.page','','4',event);">4</a>
# <a href="/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;page=5" onclick="nhn.Kin.Utility.nClicks('kin.page','','5',event);">5</a>
# <a href="/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;page=6" onclick="nhn.Kin.Utility.nClicks('kin.page','','6',event);">6</a>
# <a href="/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;page=7" onclick="nhn.Kin.Utility.nClicks('kin.page','','7',event);">7</a>
# <a href="/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;page=8" onclick="nhn.Kin.Utility.nClicks('kin.page','','8',event);">8</a>
# <a href="/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;page=9" onclick="nhn.Kin.Utility.nClicks('kin.page','','9',event);">9</a>
# <a href="/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;page=10" onclick="nhn.Kin.Utility.nClicks('kin.page','','10',event);">10</a>
# <a class="next _nclicks:kin.next" href="/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;page=11">다음페이지</a>
# </div><!--kin:navigation maxPage="50" /-->
# <script type="text/javascript">
# 				var kinSearchTerms = new nhn.Kin.Search.Terms();
# 				if (kinSearchTerms) {
#
# 					kinSearchTerms.addTerm('\uD30C\uC774\uC36C');
#
# 					kinSearchTerms.addQueryToTerm('\uD30C\uC774\uC36C');
# 					var kin_terms = kinSearchTerms.makeTermArray();
# 				}
# 			</script>
# <div class="this_questions" id="bottomQuestionButton">
# <p>
# <b class="keyword">'파이썬'</b> 에 대한 궁금증을 해결하지 못하셨다면 직접 질문해보세요!<br/>
# 				내 궁금증에 맞는 더 정확한 답변을 받을 수 있습니다.
# 			</p>
# <a class="btn_go_question _nclicks:ask.question" href="/qna/question.naver" target="_blank" title="질문하러 가기"><img alt="질문하러 가기" height="33" src="https://ssl.pstatic.net/static/kin/09renewal/btn_go_question.gif" width="121"/></a>
# </div>
# <script type="text/javascript">
#
# 		$Fn(function() {
# 			if(nhn.Kin.Utility.containSuicideKeywords('\uD30C\uC774\uC36C')) {
# 				$Element('bottomQuestionButton').hide();
# 			}
# 		},this).attach(window,"load");
# 		</script>
# </div>
# </div>
# </div>
# <div class="container-fluid-content__right">
# <div id="aside">
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20240529105836/js/min/nhn.Kin.Search.RelatedKeyword.js" type="text/javascript"></script>
# <div class="aside relate aside_type1" id="au_related_keyword">
# <h4 class="h_side_title">
# <strong class="tit">연관검색어</strong>
# </h4>
# <div class="aside_list aside_word">
# <ul>
# <li><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EA%B8%B0%EC%B4%88">파이썬 기초</a></li>
# <li><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%9E%90%EA%B2%A9%EC%A6%9D">파이썬 자격증</a></li>
# <li><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%84%A4%EC%B9%98">파이썬 설치</a></li>
# <li><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EB%8F%85%ED%95%99">파이썬 독학</a></li>
# <li><a href="/search/list.naver?query=%EC%A0%90%ED%94%84%20%ED%88%AC%20%ED%8C%8C%EC%9D%B4%EC%8D%AC">점프 투 파이썬</a></li>
# <li><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%BD%94%EB%93%9C">파이썬 코드</a></li>
# <li><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%ED%95%A8%EC%88%98">파이썬 함수</a></li>
# <li><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%B1%85">파이썬 책</a></li>
# <li><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EB%A6%AC%EC%8A%A4%ED%8A%B8">파이썬 리스트</a></li>
# <li><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8">파이썬 프로그램</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%BD%94%EB%94%A9">파이썬 코딩</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%97%B0%EC%82%B0%EC%9E%90">파이썬 연산자</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%8B%A4%ED%96%89">파이썬 실행</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%ED%95%99%EC%9B%90">파이썬 학원</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C">파이썬 다운로드</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9D%B4%EB%9E%80">파이썬이란</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EB%9C%BB">파이썬 뜻</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EC%BD%94%EB%93%9C%20%EC%8B%A4%ED%96%89">파이썬 코드 실행</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EB%AC%B4%EB%A3%8C">파이썬 무료</a></li>
# <li class="_related_keyword" style="display:none;"><a href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC%20%EB%B1%80">파이썬 뱀</a></li>
# </ul>
# </div>
# <div class="aside_help"><a class="cs" href="https://help.naver.com/service/5627/contents/4956" target="_blank"><span class="blind">연관검색어 </span>도움말</a><a class="cs2 _cs2" href="#"><span class="blind">연관검색어</span> <span>더보기 열기</span></a></div>
# </div>
# <div class="aside relate aside_type1" style="z-index:10">
# <h4 class="h_side_title">
# <strong class="tit">관련 분야</strong>
# </h4>
# <div class="aside_list" id="au_directory_list">
# <ul>
# <li><!-- 마우스 오버시 layer_on 클래스가 추가되어야 함 -->
# <a href="/qna/list.naver?dirId=10402" target="_blank">웹프로그래밍</a>
# <div class="layer_base layer_popcate" style="top:15px; left:9px; display:none;">
# <p>Q&amp;A&gt;컴퓨터통신&gt;프로그래밍&gt;웹프로그래밍</p>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <script type="text/javascript">
# 	nhn.Kin.Search.RelatedKeyword.initialize();
# </script>
# <div class="tag_area aside aside_type1">
# <h4 class="h_side_title">관련태그</h4>
# <div class="word_relate">
# <ul class="relate_list">
# <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;listType=answer">#파이썬</a></li>
# <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EC%9E%90%EB%B0%94&amp;listType=answer">#자바</a></li>
# <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=html&amp;listType=answer">#html</a></li>
# <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EC%9E%90%EB%B0%94%EC%8A%A4%ED%81%AC%EB%A6%BD%ED%8A%B8&amp;listType=answer">#자바스크립트</a></li>
# <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=java&amp;listType=answer">#java</a></li>
# <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EC%98%A4%EB%A5%98&amp;listType=answer">#오류</a></li>
# <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=%EA%B2%80%EC%83%89%EC%A7%88%EB%AC%B8&amp;listType=answer">#검색질문</a></li>
# <li><a class="_nclicks:src.tag" href="/tag/tagDetail.naver?tag=javascript&amp;listType=answer">#javascript</a></li>
# </ul>
# </div>
# </div>
# <div class="aside aside_type1 noline">
# <h4 class="h_side_title type_default">
# <strong class="tit">아하!그렇구나</strong>
# </h4>
# <div class="aside_list">
# <ul>
# <li><a href="/qna/detail.naver?d1id=11&amp;dirId=1129&amp;docId=448207097" target="_blank">지금 태양 흑점</a></li>
# <li><a href="/qna/detail.naver?d1id=8&amp;dirId=80901&amp;docId=464867849" target="_blank">분리수거 방법</a></li>
# <li><a href="/qna/detail.naver?d1id=1&amp;dirId=1060109&amp;docId=458881910" target="_blank">쿠키영상을 왜 쿠키라고 부...</a></li>
# <li><a href="/qna/detail.naver?d1id=9&amp;dirId=90101&amp;docId=458604032" target="_blank">바다 색깔 차이</a></li>
# <li><a href="/qna/detail.naver?d1id=6&amp;dirId=6130203&amp;docId=446014550" target="_blank">질문	 각궁에서 화살이 닿...</a></li>
# </ul>
# </div>
# <span class="more"><a href="/best/listaha.naver">더보기</a></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
# 	var query = '\uD30C\uC774\uC36C';
# 	if (query) {
# 		sendBaLog(BaPcEventType.KIN_SEARCH_5064, {keyword: query});
# 	}
# </script>
# </div>
# <footer class="footerArea">
# <div class="footerList">
# <a class="footerItem _nclicks:fot.agreement" href="http://www.naver.com/rules/service.html" target="_blank">이용약관</a>
# <a class="footerItem _nclicks:fot.policy" href="/common/guide.naver?query=p1" target="_blank">지식iN 서비스 운영정책</a>
# <a class="footerItem _nclicks:fot.privacy" href="http://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a>
# <a class="footerItem _nclicks:fot.claim" href="https://right.naver.com" target="_blank">권리보호센터</a>
# <a class="footerItem _nclicks:fot.help" href="https://help.naver.com/alias/kin/kinmain.naver" target="_faqhelp">지식iN 고객센터</a>
# <address class="copyright">Copyright <a class="highlight _nclicks:fot.nhncorp" href="https://www.navercorp.com" target="_openNHNWindow">© NAVER Corp.</a> All Rights Reserved.</address>
# </div>
# </footer>
# <script type="text/javascript">
#
#
# 	lcs_do();
#
# </script>
# </body>
# </html>

# %% [markdown]
# - <F12> 사용 및 CSS Selector

# %%
#s_content > div.section > ul > li:nth-child(1) > dl > dt > a
title = soup.select_one('#s_content > div.section > ul > li:nth-child(1) > dl > dt > a')
print(title)
# Out:
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=469201467&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=1&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 질문</a>

# %%
print(title.get_text())
# Out:
# 파이썬 질문

# %% [markdown]
# - 네이버 지식인 크롤링 :: 제목 여러개 뽑기

# %%
#s_content > div.section > ul
ul = soup.select_one('ul.basic1')
print(ul)
# Out:
# <ul class="basic1">
# <li>
# <div class="thumb">
# <a class="_nclicks:kin.img" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=469201467&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=1&amp;search_sort=0&amp;spq=0" target="_blank"><img alt="파이썬 질문" onerror="this.parentNode.parentNode.style.display='none';" src="https://kin-phinf.pstatic.net/20240506_156/1714962124487dc8ph_JPEG/1714962124440.jpeg?type=m100"/></a>
# </div>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=469201467&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=1&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 질문</a>
# </dt>
# <dd class="txt_inline">2024.05.06.</dd>
# <dd><b>파이썬</b> 문제 답 좀 알려주시면 감사하겠습니다! 1) 3,4 - 리스트 인덱스 순서는 자동으로 지정 됨 2) 6 - len() 함수는 리스트의 요소의 수를 리턴해줌. 3) 3... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 1</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
#
# 										<img alt="TOP 100" class="ico_top5" height="11" src="https://ssl.pstatic.net/static/kin/09renewal/ico_badge_top100.gif" width="32">
#
#
#
#
#
#
#
#
# 									tk****
#
#
# 							</img></dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=470084065&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=2&amp;search_sort=0&amp;spq=0" target="_blank">고등학생 <b>파이썬</b> 책</a>
# </dt>
# <dd class="txt_inline">2024.05.25.</dd>
# <dd>... 학교에서 <b>파이썬</b>을 배우고 관련 책을 읽으려 합니다. 이미 <b>파이썬</b>을 배워서 너무 쉬운 거 말고, 심화된 활동을 할 수 있는 고등학교 수준 책 추천해주세요! 그리고 <b>파이썬</b>... </dd>
# <dd class="tag_area">
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EA%B3%A02&amp;listType=answer">#고2</a>
# <a class="em _nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;listType=answer">#파이썬</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D&amp;listType=answer">#프로그래밍</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%B1%85%EC%B6%94%EC%B2%9C&amp;listType=answer">#책추천</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%84%B8%ED%8A%B9&amp;listType=answer">#세특</a>
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 2</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
#
#
# 										<img alt="TOP 50" class="ico_top5" height="11" src="https://ssl.pstatic.net/static/kin/09renewal/ico_badge_top50.gif" width="30">
#
#
#
#
#
#
# 									오렌지팜(i_****)
#
#
#
# 							</img></dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=470117251&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=3&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> pip 설치가 안됨</a>
# </dt>
# <dd class="txt_inline">2024.05.26.</dd>
# <dd>... 서치해보면 <b>파이썬</b> 3.4 이상 버전이면 기본... AppData에 <b>파이썬</b> 자체가 안보여요 이게 진짜 뭐죠... 분명... 그냥 <b>파이썬</b> 관련된 걸 싹 지우고 처음부터 다시 하는... </dd>
# <dd class="tag_area">
# <a class="em _nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;listType=answer">#파이썬</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=pip&amp;listType=answer">#pip</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=pip%EC%84%A4%EC%B9%98&amp;listType=answer">#pip설치</a>
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 2</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									푸른하늘(so****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=461494098&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=4&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 책 추천</a>
# </dt>
# <dd class="txt_inline">2024.06.10.</dd>
# <dd>지금 라즈베리파이로 웹서버 개발중인데 언어를 <b>파이썬</b>으로 개발할려고 해요 하지만... 공부하는 <b>파이썬</b>, 점프 투 <b>파이썬</b> 이런 책들이 있더라구요. 혹시 추천해주실 책이... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 7</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									IT천재가될거얀(py****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=468850324&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=5&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 문법 질문</a>
# </dt>
# <dd class="txt_inline">2024.04.29.</dd>
# <dd><b>파이썬</b>에서 () 와 {} 와 : 와 .:.와 '는 어떨때 사용하는... <b>파이썬</b> 표준 문법에 .:.는 존재하지 않습니다.... 일반적인 <b>파이썬</b> 코드에서는 없습니다. 작은따옴표... </dd>
# <dd class="tag_area">
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%8C%8C%EC%9D%B4%EC%8D%AC%EB%AC%B8%EB%B2%95&amp;listType=answer">#파이썬문법</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%A0%95%EB%B3%B4&amp;listType=answer">#정보</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EC%A4%91%EA%B0%84%EA%B3%A0%EC%82%AC&amp;listType=answer">#중간고사</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%EA%B3%A0%EB%93%B1%ED%95%99%EA%B5%90&amp;listType=answer">#고등학교</a>
# <a class="_nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%95%99%EA%B5%90%EC%8B%9C%ED%97%98&amp;listType=answer">#학교시험</a>
# <a class="em _nclicks:kin.tag" href="/tag/tagDetail.naver?tag=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;listType=answer">#파이썬</a>
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 1</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									지식공장(sjra****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a class="_nclicks:kin.img" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=468749890&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=6&amp;search_sort=0&amp;spq=0" target="_blank"><img alt="파이썬 문제 풀어주세요" onerror="this.parentNode.parentNode.style.display='none';" src="https://kin-phinf.pstatic.net/20240426_2/17141383442607pBRT_PNG/1.png?type=m100"/></a>
# </div>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=468749890&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=6&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 문제 풀어주세요</a>
# </dt>
# <dd class="txt_inline">2024.04.26.</dd>
# <dd><b>파이썬</b> 처음이라 잘 모르겠네요 "" isalnum() 함수는 주어진 문자열이 알파벳과 숫자로 이루어져 있으면 True 를 반환합니다.</dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 2</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
#
#
# 										<img alt="TOP 50" class="ico_top5" height="11" src="https://ssl.pstatic.net/static/kin/09renewal/ico_badge_top50.gif" width="30">
#
#
#
#
#
#
# 									ncode(xtel****)
#
#
#
# 							</img></dd>
# </dl>
# </li>
# <li>
# <div class="thumb">
# <a class="_nclicks:kin.img" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=469950105&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=7&amp;search_sort=0&amp;spq=0" target="_blank"><img alt="파이썬 입력과 변수 질문" onerror="this.parentNode.parentNode.style.display='none';" src="https://kin-phinf.pstatic.net/20240521_86/1716298162354xxhfM_PNG/%BD%BA%C5%A9%B8%B0%BC%A6_2024-05-21_222754.png?type=m100"/></a>
# </div>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=469950105&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=7&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 입력과 변수 질문</a>
# </dt>
# <dd class="txt_inline">2024.05.21.</dd>
# <dd><b>파이썬</b> 코들에서 하고있는데 너무 불친절하게 나와서요 어떻게 해야하는지 풀이와 정답좀 알려주세요,,, (아래가 문제입니다) .을 기준으로 나눠서 마지막 부분과 .을 합치면... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 2</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									엑플하나하나(7edi****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=11&amp;dirId=110704&amp;docId=469733497&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=8&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b>독학 어떻게들 하고 계신가요?</a>
# </dt>
# <dd class="txt_inline">2024.05.17.</dd>
# <dd><b>파이썬</b>독학하고자 합니다. 코딩 공부를 하고 싶은데 C언어보다... <b>파이썬</b>독학 어떻게들 하고 계신지 공유 부탁드립니다. <b>파이썬</b>독학 어떻게들 하고 계신가요? <b>파이썬</b>독학하고자... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=110704">직업교육</a>
# <span class="bar">|</span>
# <span class="">답변수 3</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=467785974&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=9&amp;search_sort=0&amp;spq=0" target="_blank">중1 <b>파이썬</b> 독학</a>
# </dt>
# <dd class="txt_inline">2024.04.10.</dd>
# <dd>... 중1이고 코딩은 처음인데 <b>파이썬</b>부터 시작하면 좋다고 해서 <b>파이썬</b> 독학을 할 생각인데 <b>파이썬</b> 독학 교재는 뭐가 좋을까요? 그리고 <b>파이썬</b>을 배우면 어디에 쓸 수 있나요?... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 1</span>
# <span class="bar">|</span>
#
#
# 									답변
#
#
#
# 									으뜸아빠(obon****)
#
#
#
# 							</dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=467972762&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=10&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 해커 되는법 <b>파이썬</b> 해킹에 관해서</a>
# </dt>
# <dd class="txt_inline">2024.04.15.</dd>
# <dd>... <b>파이썬</b>으로 해커가 될수 있나요? 2. <b>파이썬</b>으로 해킹 공부하려면 어떤 공부를 해야되나요? 3.<b>파이썬</b>으로 해킹 할수있는게 몇개정도 되나요? 4.<b>파이썬</b> 심화 과정까지 공부... </dd>
# <dd class="tag_area">
# </dd>
# <dd class="txt_block">
# <a class="txt_g1 _nclicks:kin.cat1" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna">Q&amp;A</a>
#
# 									 &gt; <a class="txt_g1 _nclicks:kin.cat2" href="/search/list.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC§ion=qna&amp;dirId=10402">웹프로그래밍</a>
# <span class="bar">|</span>
# <span class="">답변수 3</span>
# </dd>
# </dl>
# </li>
# </ul>

# %%
#s_content > div.section > ul > li:nth-child(1) > dl > dt > a
#s_content > div.section > ul > li:nth-child(2) > dl > dt > a
#s_content > div.section > ul > li:nth-child(3) > dl > dt > a
titles = ul.select('li > dl > dt > a')
titles
# Out:
# [<a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=469201467&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=1&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 질문</a>,
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=470084065&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=2&amp;search_sort=0&amp;spq=0" target="_blank">고등학생 <b>파이썬</b> 책</a>,
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=470117251&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=3&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> pip 설치가 안됨</a>,
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=461494098&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=4&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 책 추천</a>,
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=468850324&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=5&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 문법 질문</a>,
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=468749890&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=6&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 문제 풀어주세요</a>,
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=469950105&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=7&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 입력과 변수 질문</a>,
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=11&amp;dirId=110704&amp;docId=469733497&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=8&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b>독학 어떻게들 하고 계신가요?</a>,
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=467785974&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=9&amp;search_sort=0&amp;spq=0" target="_blank">중1 <b>파이썬</b> 독학</a>,
#  <a class="_nclicks:kin.txt _searchListTitleAnchor" href="https://kin.naver.com/qna/detail.naver?d1id=1&amp;dirId=10402&amp;docId=467972762&amp;qb=7YyM7J207I2s&amp;enc=utf8§ion=kin.qna_ency&amp;rank=10&amp;search_sort=0&amp;spq=0" target="_blank"><b>파이썬</b> 해커 되는법 <b>파이썬</b> 해킹에 관해서</a>]

# %%
for title in titles:
    print(title.get_text())
# Out:
# 파이썬 질문
# 고등학생 파이썬 책
# 파이썬 pip 설치가 안됨
# 파이썬 책 추천
# 파이썬 문법 질문
# 파이썬 문제 풀어주세요
# 파이썬 입력과 변수 질문
# 파이썬독학 어떻게들 하고 계신가요?
# 중1 파이썬 독학
# 파이썬 해커 되는법 파이썬 해킹에 관해서

# %% [markdown]
# - select_one 은 찾은 html 중 가장 첫번째 html 을 가져오고
# - select 는 찾은 모든 html 을 리스트 형태로 반환 합니다.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://kin.naver.com/search/list.nhn?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    ul = soup.select_one('ul.basic1')
    titles = ul.select('li > dl > dt > a')
    for title in titles:
        print(title.get_text())
else : 
    print(response.status_code)
# Out:
# 파이썬 질문
# 고등학생 파이썬 책
# 파이썬 pip 설치가 안됨
# 파이썬 책 추천
# 파이썬 문법 질문
# 파이썬 문제 풀어주세요
# 파이썬 입력과 변수 질문
# 파이썬독학 어떻게들 하고 계신가요?
# 중1 파이썬 독학
# 파이썬 해커 되는법 파이썬 해킹에 관해서
