# %%
import pandas as pd
import math
train = pd.read_csv('./data_titanic/train.csv')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# train.info

# %%
acc = train['Survived'].mean()
print('{:.2f}%'.format(acc * 100))
# Out:
# 38.38%

# %%
sur = train['Survived'].value_counts()
print('승객수 :' ,sur[1]+ sur[0],'명')
print('사망자 :' ,sur[0],'명')
# Out:
# 승객수 : 891 명
# 사망자 : 549 명

# %%
# 2

train.loc[train['Survived'] == 0, 'Survived(Status)'] = 'Perish(사망)'
train.loc[train['Survived'] == 1, 'Survived(Status)'] = 'Survived(생존)'
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train["객실 등급"] = ""


for index, row in train.iterrows():
    if row['Pclass'] == 1:
        train.at[index,'객실 등급'] = '1등석'
    elif row['Pclass'] == 2:
        train.at[index,'객실 등급'] = '비즈니스'
    else:
        train.at[index,'객실 등급'] ='이코노미'
        
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a = train['객실 등급'].value_counts()
a
# Out:
# 이코노미    491
# 1등석     216
# 비즈니스    184
# Name: 객실 등급, dtype: int64

# %%
gp = train.groupby('객실 등급')
gps = gp['Survived'].mean()
gpp = pd.pivot_table(data = train , index = '객실 등급', values= 'Survived')

gpp
# Out:
#        Survived
# 객실 등급
# 1등석    0.629630
# 비즈니스   0.472826
# 이코노미   0.242363

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train["탑승 위치"] = ""


for index, row in train.iterrows():
    if row['Embarked'] == 'S':
        train.at[index,'탑승 위치'] = 'Southampton'
    elif row['Embarked'] == 'C':
        train.at[index,'탑승 위치'] = 'Cherbourg'
    else:
        train.at[index,'탑승 위치'] ='Queenstown'
        
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
abord = train.groupby('탑승 위치')
aborded = abord['Survived'].mean()
abordedp = pd.pivot_table(data = train , index = '탑승 위치', values= 'Survived')
abordedp
# Out:
#              Survived
# 탑승 위치
# Cherbourg    0.553571
# Queenstown   0.405063
# Southampton  0.336957

# %%
train["Embarked(C)"] = train["Embarked"] == "C"
train["Embarked(S)"] = train["Embarked"] == "S"
train["Embarked(Q)"] = train["Embarked"] == "Q"

train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train["Pcalss(F)"] = train["객실 등급"] == "1등석"
train["Pcalss(B)"] = train["객실 등급"] == "비즈니스"
train["Pcalss(E)"] = train["객실 등급"] == "이코노미"
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 나이분석

# %%
train['Age'].mean()
# Out:
# 29.69911764705882

# %%
train['Age'].std()
# Out:
# 14.526497332334044

# %%
train['Age'].min()
# Out:
# 0.42

# %%
train['Age'].max()
# Out:
# 80.0

# %%
train['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
byclassage = gp['Age'].mean()
byclassage
# Out:
# 객실 등급
# 1등석     38.233441
# 비즈니스    29.877630
# 이코노미    25.140620
# Name: Age, dtype: float64

# %%
train["Age Type"] = ""


for index, row in train.iterrows():
    if row['Age'] < 15:
        train.at[index,'Age Type'] = 'Young'
    elif row['Age'] >= 15 and row['Age'] < 30 :
        train.at[index,'Age Type'] = 'Medium'
    else:
        train.at[index,'Age Type'] ='Old'
        
train['Age Type'].head()
# Out:
# 0    Medium
# 1       Old
# 2    Medium
# 3       Old
# 4       Old
# Name: Age Type, dtype: object

# %%
agegroup = train.groupby('Age Type')
agegroupmean = abord['Survived'].mean()
agegroupmeanp = pd.pivot_table(data = train , index = 'Age Type', values= 'Survived')
agegroupmeanp
# Out:
#           Survived
# Age Type
# Medium    0.362745
# Old       0.366864
# Young     0.576923

# %%
train['AgeBlank'] = train['Age'].apply(lambda x: 'Blank' if pd.isnull(x) else 'Not Blank')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ageblank = train.groupby('AgeBlank')
ageblankmean = abord['Survived'].mean()
ageblankmeanp = pd.pivot_table(data = train , index = 'AgeBlank', values= 'Survived')
ageblankmeanp
# Out:
#            Survived
# AgeBlank
# Blank      0.293785
# Not Blank  0.406162

# %%
byclassage
# Out:
# 객실 등급
# 1등석     38.233441
# 비즈니스    29.877630
# 이코노미    25.140620
# Name: Age, dtype: float64

# %%
train['Age(fill)'] = train['Age']
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
byclassage
# Out:
# 객실 등급
# 1등석     38.233441
# 비즈니스    29.877630
# 이코노미    25.140620
# Name: Age, dtype: float64

# %%
train.loc[(train['Age'].isnull()) & (train['Pclass']==1), 'Age(fill)'] = byclassage[0]
train.loc[(train['Age'].isnull()) & (train['Pclass']==2), 'Age(fill)'] = byclassage[1]
train.loc[(train['Age'].isnull()) & (train['Pclass']==3), 'Age(fill)'] = byclassage[2]

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train["Single"] = (train["SibSp"] == 0) & (train["Parch"] == 0)
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
single = train.groupby('Single')
singlemean = single['Survived'].mean()
singlemeanp = pd.pivot_table(data = train , index = 'Single', values= 'Survived')
singlemeanp
# Out:
#         Survived
# Single
# False   0.505650
# True    0.303538

# %%
train['FamilySize'] = train['SibSp'] + train['Parch'] + 1
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Famsizesur = pd.pivot_table(data=train, index="FamilySize", values="Survived")
Famsizesur
# Out:
#             Survived
# FamilySize
# 1           0.303538
# 2           0.552795
# 3           0.578431
# 4           0.724138
# 5           0.200000
# 6           0.136364
# 7           0.333333
# 8           0.000000
# 11          0.000000

# %%
train["FamilyType"] = ""


for index, row in train.iterrows():
    if row['FamilySize'] == 1:
        train.at[index,'FamilyType'] = 'Single'
    elif row['FamilySize'] >= 2 and row['FamilySize'] < 5 :
        train.at[index,'FamilyType'] = 'Nuclear'
    else:
        train.at[index,'FamilyType'] ='Big'
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked(Q) Pcalss(F) Pcalss(B)  \
# 0      0         A/5 21171   7.2500  ...       False     False     False
# 1      0          PC 17599  71.2833  ...       False      True     False
# 2      0  STON/O2. 3101282   7.9250  ...       False     False     False
# ...

# %%
FamilyTypeSur = pd.pivot_table(data=train, index="FamilyType", values="Survived")

# %%
train["FamilyType(Single)"] = train["FamilyType"] == "Single"
train["FamilyType(Nuclear)"] = train["FamilyType"] == "Nuclear"
train["FamilyType(Big)"] = train["FamilyType"] == "Big"
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Age(fill) Single FamilySize  \
# 0      0         A/5 21171   7.2500  ...      22.0  False          2
# 1      0          PC 17599  71.2833  ...      38.0  False          2
# 2      0  STON/O2. 3101282   7.9250  ...      26.0   True          1
# ...

# %%
def get_title(name):
    return name.split(',')[1].split('.')[0].strip()

train["Title"] = train["Name"].apply(get_title)
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(train["Title"], train["Survived"])
# Out:
# Survived        0    1
# Title
# Capt            1    0
# Col             1    1
# Don             1    0
# Dr              4    3
# Jonkheer        1    0
# Lady            0    1
# Major           1    1
# Master         17   23
# Miss           55  127
# Mlle            0    2
# Mme             0    1
# Mr            436   81
# Mrs            26   99
# Ms              0    1
# Rev             6    0
# Sir             0    1
# the Countess    0    1

# %%
train.groupby(["Title",'Survived'])['Survived'].agg(['count']).unstack()
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def get_title_status(title):
    title = title.strip()
    if title == "Mr" or title == "Miss" or title == "Mrs" or title == "Master":
        return title
    else: 
        return "Others"

# %%
train["Title(Status)"] = train["Title"].apply(get_title_status)
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare  ... Age(fill) Single  \
# 886    male  27.0      0      0      211536  13.00  ...  27.00000   True
# 887  female  19.0      0      0      112053  30.00  ...  19.00000   True
# 888  female   NaN      1      2  W./C. 6607  23.45  ...  25.14062  False
# 889    male  26.0      0      0      111369  30.00  ...  26.00000   True
# 890    male  32.0      0      0      370376   7.75  ...  32.00000   True
#
# ...

# %%
titlesur = pd.pivot_table(train, index="Title(Status)", values="Survived")
titlesur
# Out:
#                Survived
# Title(Status)
# Master         0.575000
# Miss           0.697802
# Mr             0.156673
# Mrs            0.792000
# Others         0.444444

# %%
train["Title"] = train["Title"].str.strip()
train.loc[train["Title"] == "Mr", "Married"] = True
train.loc[train["Title"] == "Master", "Married"] = False
train.loc[train["Title"] == "Mrs", "Married"] = True
train.loc[train["Title"] == "Miss", "Married"] = False

train[["Name", "Title", "Married"]].head()
# Out:
#                                                 Name Title Married
# 0                            Braund, Mr. Owen Harris    Mr    True
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Mrs    True
# 2                             Heikkinen, Miss. Laina  Miss   False
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Mrs    True
# 4                           Allen, Mr. William Henry    Mr    True

# %%
train.loc[train["Title(Status)"].isin(["Mr", "Mrs"]), "Married"] = True
train.loc[train["Title(Status)"].isin(["Master", "Miss"]), "Married"] = False
train.loc[train["Title(Status)"].isin(["Others"]), "Married"] = False
train[["Name", "Title", "Married"]].head()
# Out:
#                                                 Name Title Married
# 0                            Braund, Mr. Owen Harris    Mr    True
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Mrs    True
# 2                             Heikkinen, Miss. Laina  Miss   False
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Mrs    True
# 4                           Allen, Mr. William Henry    Mr    True

# %%
marriedsur = pd.pivot_table(train, index="Married", values="Survived")
marriedsur
# Out:
#          Survived
# Married
# False    0.650602
# True     0.280374

# %%
train.to_csv('data_titanic/train_one_hot.csv')
