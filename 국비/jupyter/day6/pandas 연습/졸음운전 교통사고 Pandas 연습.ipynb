# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import matplotlib
from datetime import datetime 
from pandas_datareader import data

# %%
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
data1 = pd.read_csv("./data/2014년 졸음운전 교통사고.csv", encoding="euc-kr")
data2 = pd.read_csv("./data/2015년 졸음운전 교통사고.csv", encoding="euc-kr")
data3 = pd.read_csv("./data/2016년 졸음운전 교통사고.csv", encoding="euc-kr")

# %%
data1
# Out:
#           구분  사고(건)  사망(명)  부상(명)
# 0    2014년1월    169      7    347
# 1    2014년2월    145      3    268
# 2    2014년3월    206     12    358
# 3    2014년4월    182      4    360
# 4    2014년5월    218     17    474
# 5    2014년6월    233     13    457
# 6    2014년7월    229     14    431
# 7    2014년8월    222      9    447
# 8    2014년9월    225     15    430
# 9   2014년10월    210     14    392
# 10  2014년11월    209     10    386
# 11  2014년12월    178     12    329

# %%
data2
# Out:
#           구분  사고(건)  사망(명)  부상(명)
# 0    2015년1월    205      8    375
# 1    2015년2월    175      8    375
# 2    2015년3월    237      4    492
# 3    2015년4월    227     10    486
# 4    2015년5월    231      9    504
# 5    2015년6월    207      8    401
# 6    2015년7월    273      7    556
# 7    2015년8월    268     19    534
# 8    2015년9월    252     10    501
# 9   2015년10월    214     14    475
# 10  2015년11월    199      3    398
# 11  2015년12월    213      8    428

# %%
data3
# Out:
#           구분  사고(건)  사망(명)  부상(명)
# 0    2016년1월    192      5    387
# 1    2016년2월    174      6    328
# 2    2016년3월    217      7    435
# 3    2016년4월    216      7    419
# 4    2016년5월    239     13    522
# 5    2016년6월    200     12    362
# 6    2016년7월    227      9    460
# 7    2016년8월    230      7    490
# 8    2016년9월    187     13    347
# 9   2016년10월    183     10    367
# 10  2016년11월    200      5    418
# 11  2016년12월    168      4    364

# %%
## 1. 3개의 데이터를 병합하시오

# %%
data_merge = pd.concat([data1, data2, data3])

# %%
data_merge
# Out:
#           구분  사고(건)  사망(명)  부상(명)
# 0    2014년1월    169      7    347
# 1    2014년2월    145      3    268
# 2    2014년3월    206     12    358
# 3    2014년4월    182      4    360
# 4    2014년5월    218     17    474
# 5    2014년6월    233     13    457
# 6    2014년7월    229     14    431
# 7    2014년8월    222      9    447
# 8    2014년9월    225     15    430
# 9   2014년10월    210     14    392
# 10  2014년11월    209     10    386
# 11  2014년12월    178     12    329
# 0    2015년1월    205      8    375
# 1    2015년2월    175      8    375
# 2    2015년3월    237      4    492
# 3    2015년4월    227     10    486
# 4    2015년5월    231      9    504
# 5    2015년6월    207      8    401
# 6    2015년7월    273      7    556
# 7    2015년8월    268     19    534
# 8    2015년9월    252     10    501
# 9   2015년10월    214     14    475
# 10  2015년11월    199      3    398
# 11  2015년12월    213      8    428
# 0    2016년1월    192      5    387
# 1    2016년2월    174      6    328
# ...

# %%
## 2. 년도, 월별로 인덱스를 설정(멀티인덱스) 하고 데이터를 보여 주시오

# %%
ans2 = data_merge.copy()
ans2
# Out:
#           구분  사고(건)  사망(명)  부상(명)
# 0    2014년1월    169      7    347
# 1    2014년2월    145      3    268
# 2    2014년3월    206     12    358
# 3    2014년4월    182      4    360
# 4    2014년5월    218     17    474
# 5    2014년6월    233     13    457
# 6    2014년7월    229     14    431
# 7    2014년8월    222      9    447
# 8    2014년9월    225     15    430
# 9   2014년10월    210     14    392
# 10  2014년11월    209     10    386
# 11  2014년12월    178     12    329
# 0    2015년1월    205      8    375
# 1    2015년2월    175      8    375
# 2    2015년3월    237      4    492
# 3    2015년4월    227     10    486
# 4    2015년5월    231      9    504
# 5    2015년6월    207      8    401
# 6    2015년7월    273      7    556
# 7    2015년8월    268     19    534
# 8    2015년9월    252     10    501
# 9   2015년10월    214     14    475
# 10  2015년11월    199      3    398
# 11  2015년12월    213      8    428
# 0    2016년1월    192      5    387
# 1    2016년2월    174      6    328
# ...

# %%
ans2.index = pd.to_datetime(ans2.index, format='%Y년%m월')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:510, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509 try:
# --> 510     values, tz = conversion.datetime_to_datetime64(arg)
#     511     dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [103], in <cell line: 1>()
# ----> 1 ans2.index = pd.to_datetime(ans2.index, format='%Y년%m월')
#
# ...

# %%
merged_data
# Out:
#           구분  사고(건)  사망(명)  부상(명)     년도
# 0    2014년1월    169      7    347  2014년
# 1    2014년2월    145      3    268  2014년
# 2    2014년3월    206     12    358  2014년
# 3    2014년4월    182      4    360  2014년
# 4    2014년5월    218     17    474  2014년
# 5    2014년6월    233     13    457  2014년
# 6    2014년7월    229     14    431  2014년
# 7    2014년8월    222      9    447  2014년
# 8    2014년9월    225     15    430  2014년
# 9   2014년10월    210     14    392  2014년
# 10  2014년11월    209     10    386  2014년
# 11  2014년12월    178     12    329  2014년
# 12   2015년1월    205      8    375  2015년
# 13   2015년2월    175      8    375  2015년
# 14   2015년3월    237      4    492  2015년
# 15   2015년4월    227     10    486  2015년
# 16   2015년5월    231      9    504  2015년
# 17   2015년6월    207      8    401  2015년
# 18   2015년7월    273      7    556  2015년
# 19   2015년8월    268     19    534  2015년
# 20   2015년9월    252     10    501  2015년
# 21  2015년10월    214     14    475  2015년
# ...

# %%
merged_data["월별"] = merged_data["구분"].str[5:]

# %%
merged_data
# Out:
#           구분  사고(건)  사망(명)  부상(명)     년도   월별
# 0    2014년1월    169      7    347  2014년   1월
# 1    2014년2월    145      3    268  2014년   2월
# 2    2014년3월    206     12    358  2014년   3월
# 3    2014년4월    182      4    360  2014년   4월
# 4    2014년5월    218     17    474  2014년   5월
# 5    2014년6월    233     13    457  2014년   6월
# 6    2014년7월    229     14    431  2014년   7월
# 7    2014년8월    222      9    447  2014년   8월
# 8    2014년9월    225     15    430  2014년   9월
# 9   2014년10월    210     14    392  2014년  10월
# 10  2014년11월    209     10    386  2014년  11월
# 11  2014년12월    178     12    329  2014년  12월
# 12   2015년1월    205      8    375  2015년   1월
# 13   2015년2월    175      8    375  2015년   2월
# 14   2015년3월    237      4    492  2015년   3월
# 15   2015년4월    227     10    486  2015년   4월
# 16   2015년5월    231      9    504  2015년   5월
# 17   2015년6월    207      8    401  2015년   6월
# 18   2015년7월    273      7    556  2015년   7월
# ...

# %%
category_sum = merged_data.groupby(["년도", "월별"])[["사고(건)", "사망(명)", "부상(명)"]].sum().reset_index()

# %%
category_sum
# Out:
#        년도   월별  사고(건)  사망(명)  부상(명)
# 0   2014년  10월    210     14    392
# 1   2014년  11월    209     10    386
# 2   2014년  12월    178     12    329
# 3   2014년   1월    169      7    347
# 4   2014년   2월    145      3    268
# 5   2014년   3월    206     12    358
# 6   2014년   4월    182      4    360
# 7   2014년   5월    218     17    474
# 8   2014년   6월    233     13    457
# 9   2014년   7월    229     14    431
# 10  2014년   8월    222      9    447
# 11  2014년   9월    225     15    430
# 12  2015년  10월    214     14    475
# 13  2015년  11월    199      3    398
# 14  2015년  12월    213      8    428
# 15  2015년   1월    205      8    375
# 16  2015년   2월    175      8    375
# 17  2015년   3월    237      4    492
# 18  2015년   4월    227     10    486
# 19  2015년   5월    231      9    504
# 20  2015년   6월    207      8    401
# 21  2015년   7월    273      7    556
# 22  2015년   8월    268     19    534
# 23  2015년   9월    252     10    501
# 24  2016년  10월    183     10    367
# ...

# %%
df_multiindex = category_sum.set_index(["년도", "월별"])

# %%
df_multiindex
# Out:
#            사고(건)  사망(명)  부상(명)
# 년도    월별
# 2014년 10월    210     14    392
#       11월    209     10    386
#       12월    178     12    329
#       1월     169      7    347
#       2월     145      3    268
#       3월     206     12    358
#       4월     182      4    360
#       5월     218     17    474
#       6월     233     13    457
#       7월     229     14    431
#       8월     222      9    447
#       9월     225     15    430
# 2015년 10월    214     14    475
#       11월    199      3    398
#       12월    213      8    428
#       1월     205      8    375
#       2월     175      8    375
#       3월     237      4    492
#       4월     227     10    486
#       5월     231      9    504
#       6월     207      8    401
#       7월     273      7    556
#       8월     268     19    534
#       9월     252     10    501
# 2016년 10월    183     10    367
#       11월    200      5    418
#       12월    168      4    364
#       1월     192      5    387
# ...

# %%
## 3. 년도 및 월별 평균 사망자를 보여주시오

# %%
mean_by_year = df_multiindex.groupby("년도").mean()
mean_by_month = df_multiindex.groupby("월별").mean()

# %%
mean_by_year
# Out:
#             사고(건)      사망(명)       부상(명)
# 년도
# 2014년  202.166667  10.833333  389.916667
# 2015년  225.083333   9.000000  460.416667
# 2016년  202.750000   8.166667  408.250000

# %%
mean_by_month
# Out:
#           사고(건)      사망(명)       부상(명)
# 월별
# 10월  202.333333  12.666667  411.333333
# 11월  202.666667   6.000000  400.666667
# 12월  186.333333   8.000000  373.666667
# 1월   188.666667   6.666667  369.666667
# 2월   164.666667   5.666667  323.666667
# 3월   220.000000   7.666667  428.333333
# 4월   208.333333   7.000000  421.666667
# 5월   229.333333  13.000000  500.000000
# 6월   213.333333  11.000000  406.666667
# 7월   243.000000  10.000000  482.333333
# 8월   240.000000  11.666667  490.333333
# 9월   221.333333  12.666667  426.000000

# %%
## 4.  2016년 사고대비 사망율을 구하시오

# %%
df_2016 = df_multiindex.loc["2016년"]

# %%
df_2016
# Out:
#      사고(건)  사망(명)  부상(명)
# 월별
# 10월    183     10    367
# 11월    200      5    418
# 12월    168      4    364
# 1월     192      5    387
# 2월     174      6    328
# 3월     217      7    435
# 4월     216      7    419
# 5월     239     13    522
# 6월     200     12    362
# 7월     227      9    460
# 8월     230      7    490
# 9월     187     13    347

# %%
df_2016["사고 대비 사망률"] = df_2016["사망(명)"] / df_2016["사고(건)"]

# %%
df_2016
# Out:
#      사고(건)  사망(명)  부상(명)  사고 대비 사망률
# 월별
# 10월    183     10    367   0.054645
# 11월    200      5    418   0.025000
# 12월    168      4    364   0.023810
# 1월     192      5    387   0.026042
# 2월     174      6    328   0.034483
# 3월     217      7    435   0.032258
# 4월     216      7    419   0.032407
# 5월     239     13    522   0.054393
# 6월     200     12    362   0.060000
# 7월     227      9    460   0.039648
# 8월     230      7    490   0.030435
# 9월     187     13    347   0.069519

# %%
## 5. 2014년도 월별 사망, 부상 데이터를 바차트로 보여주시오

# %%
df_2014 = df_multiindex.loc["2014년"]

# %%
df_2014
# Out:
#      사고(건)  사망(명)  부상(명)
# 월별
# 10월    210     14    392
# 11월    209     10    386
# 12월    178     12    329
# 1월     169      7    347
# 2월     145      3    268
# 3월     206     12    358
# 4월     182      4    360
# 5월     218     17    474
# 6월     233     13    457
# 7월     229     14    431
# 8월     222      9    447
# 9월     225     15    430

# %%
df_2014[["사망(명)", "부상(명)"]].groupby("월별").plot(kind = "bar",)
# Out:
# 월별
# 10월    AxesSubplot(0.125,0.125;0.775x0.755)
# 11월    AxesSubplot(0.125,0.125;0.775x0.755)
# 12월    AxesSubplot(0.125,0.125;0.775x0.755)
# 1월     AxesSubplot(0.125,0.125;0.775x0.755)
# 2월     AxesSubplot(0.125,0.125;0.775x0.755)
# 3월     AxesSubplot(0.125,0.125;0.775x0.755)
# 4월     AxesSubplot(0.125,0.125;0.775x0.755)
# 5월     AxesSubplot(0.125,0.125;0.775x0.755)
# 6월     AxesSubplot(0.125,0.125;0.775x0.755)
# 7월     AxesSubplot(0.125,0.125;0.775x0.755)
# 8월     AxesSubplot(0.125,0.125;0.775x0.755)
# 9월     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
## 6. 2015년 대비  사망이 가장 많이 증가한 2016년도 월을 구하시오
