# %% [markdown]
# # 입문자를 위한, 파이썬/R 데이터 분석

# %% [markdown]
# ## Part(1) - Day02  :

# %% [markdown]
# -  Kaggle 소개 및 타이타닉 예제 실습 (Kaggle competition)
# -  (초급분석) Titanic - Machine Learning from Disaster
# -  Start here! Predict survival on the Titanic and get familiar with ML basics

# %% [markdown]
# - 캐글 가입 및 제출 참고 : https://brunch.co.kr/@hansungdev/12
#
# - Kaggle Titanbic Competition : https://www.kaggle.com/c/titanic

# %% [markdown]
# ![image.png](attachment:7ceaa0c0-1c03-401d-9c4d-5524682ffc61.png)9
#
# 9
#
#
# 	1309				1309

# %% [markdown]
# ## Import Package

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 유의사항 :
#
# 1) Python 소스(본인의 titanic 주피터노트북 소스) 폴더경로에서, data_titanic 폴더 안에 train.csv 파일이 저장되어 있을 경우에 아래처럼 입력
#
# 2) 오류나면 철자 Spelling 확인, 또는 상단에 import pandas 등 실행했는지 점검

# %%
train = pd.read_csv("data_titanic/train_one_hot.csv", index_col = "PassengerId")
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin  ... Age(fill)  \
# PassengerId                                                 ...
# 1                1      0         A/5 21171   7.2500   NaN  ...  22.00000
# 2                1      0          PC 17599  71.2833   C85  ...  38.00000
# 3                0      0  STON/O2. 3101282   7.9250   NaN  ...  26.00000
# 4                1      0            113803  53.1000  C123  ...  35.00000
# 5                0      0            373450   8.0500   NaN  ...  35.00000
# ...            ...    ...               ...      ...   ...  ...       ...
# 887              0      0            211536  13.0000   NaN  ...  27.00000
# 888              0      0            112053  30.0000   B42  ...  19.00000
# 889              1      2        W./C. 6607  23.4500   NaN  ...  25.14062
# 890              0      0            111369  30.0000  C148  ...  26.00000
# 891              0      0            370376   7.7500   NaN  ...  32.00000
#
#             Single FamilySize FamilyType  FamilyType(Single)  \
# PassengerId
# 1            False          2    Nuclear               False
# 2            False          2    Nuclear               False
# 3             True          1     Single                True
# 4            False          2    Nuclear               False
# 5             True          1     Single                True
# ...            ...        ...        ...                 ...
# 887           True          1     Single                True
# 888           True          1     Single                True
# 889          False          4    Nuclear               False
# 890           True          1     Single                True
# 891           True          1     Single                True
#
#              FamilyType(Nuclear)  FamilyType(Big)  Title  Title(Status)  \
# PassengerId
# 1                           True            False     Mr             Mr
# 2                           True            False    Mrs            Mrs
# 3                          False            False   Miss           Miss
# 4                           True            False    Mrs            Mrs
# 5                          False            False     Mr             Mr
# ...                          ...              ...    ...            ...
# 887                        False            False    Rev         Others
# 888                        False            False   Miss           Miss
# 889                         True            False   Miss           Miss
# 890                        False            False     Mr             Mr
# 891                        False            False     Mr             Mr
#
#              Married
# PassengerId
# 1               True
# 2               True
# 3              False
# 4               True
# 5               True
# ...              ...
# 887            False
# 888            False
# 889            False
# 890             True
# 891             True
#
# [891 rows x 32 columns]

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin  ... Age(fill)  \
# PassengerId                                                 ...
# 1                1      0         A/5 21171   7.2500   NaN  ...      22.0
# 2                1      0          PC 17599  71.2833   C85  ...      38.0
# 3                0      0  STON/O2. 3101282   7.9250   NaN  ...      26.0
# 4                1      0            113803  53.1000  C123  ...      35.0
# 5                0      0            373450   8.0500   NaN  ...      35.0
#
#             Single FamilySize FamilyType  FamilyType(Single)  \
# PassengerId
# 1            False          2    Nuclear               False
# 2            False          2    Nuclear               False
# 3             True          1     Single                True
# 4            False          2    Nuclear               False
# 5             True          1     Single                True
#
#              FamilyType(Nuclear)  FamilyType(Big)  Title  Title(Status)  \
# PassengerId
# 1                           True            False     Mr             Mr
# 2                           True            False    Mrs            Mrs
# 3                          False            False   Miss           Miss
# 4                           True            False    Mrs            Mrs
# 5                          False            False     Mr             Mr
#
#              Married
# PassengerId
# 1               True
# 2               True
# 3              False
# 4               True
# 5               True
#
# [5 rows x 32 columns]

# %%
train.shape
# Out:
# (891, 32)

# %%
train.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Survived(Status)', 'Pclass(Status)',
#        'Embarked(Status)', 'Embarked(C)', 'Embarked(S)', 'Embarked(Q)',
#        'Pclass(F)', 'Pclass(B)', 'Pclass(E)', 'AgeType', 'AgeBlank',
#        'Age(fill)', 'Single', 'FamilySize', 'FamilyType', 'FamilyType(Single)',
#        'FamilyType(Nuclear)', 'FamilyType(Big)', 'Title', 'Title(Status)',
#        'Married'],
#       dtype='object')

# %%
train["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train["Sex"].groupby(train["Survived"]).value_counts()
# Out:
# Survived  Sex
# 0         male      468
#           female     81
# 1         female    233
#           male      109
# Name: Sex, dtype: int64

# %%
sns.countplot(data = train, x = "Sex", hue = "Survived")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
train[['Sex', 'Survived']]
# Out:
#                 Sex  Survived
# PassengerId
# 1              male         0
# 2            female         1
# 3            female         1
# 4            female         1
# 5              male         0
# ...             ...       ...
# 887            male         0
# 888          female         1
# 889          female         0
# 890            male         1
# 891            male         0
#
# [891 rows x 2 columns]

# %%
pd.pivot_table(train, index = "Sex", values = "Survived")
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
# import warnings
# warnings.filterwarnings("ignore")

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
sns.countplot(data = train, x = "Pclass", hue = "Survived")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.lmplot(data = train, x = "Age", y = "Fare", hue = "Survived", fit_reg = True )

# %% [markdown]
# ### Pre-processing
#
# 프로그램 encoding

# %%
# Sex (1: female, 0: male)
train["Sex"] == "male"
# Out:
# PassengerId
# 1       True
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 887     True
# 888    False
# 889    False
# 890     True
# 891     True
# Name: Sex, Length: 891, dtype: bool

# %%
train.loc[train["Sex"] == "male", "Sex_encode"] = 0

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin  ... Single  \
# PassengerId                                                 ...
# 1                1      0         A/5 21171   7.2500   NaN  ...  False
# 2                1      0          PC 17599  71.2833   C85  ...  False
# 3                0      0  STON/O2. 3101282   7.9250   NaN  ...   True
# 4                1      0            113803  53.1000  C123  ...  False
# 5                0      0            373450   8.0500   NaN  ...   True
#
#             FamilySize FamilyType FamilyType(Single)  FamilyType(Nuclear)  \
# PassengerId
# 1                    2    Nuclear              False                 True
# 2                    2    Nuclear              False                 True
# 3                    1     Single               True                False
# 4                    2    Nuclear              False                 True
# 5                    1     Single               True                False
#
#              FamilyType(Big)  Title  Title(Status)  Married  Sex_encode
# PassengerId
# 1                      False     Mr             Mr     True         0.0
# 2                      False    Mrs            Mrs     True         NaN
# 3                      False   Miss           Miss    False         NaN
# 4                      False    Mrs            Mrs     True         NaN
# 5                      False     Mr             Mr     True         0.0
#
# [5 rows x 33 columns]

# %%
train.loc[train["Sex"] == "female", "Sex_encode"] = 1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Survived             891 non-null    int64
#  1   Pclass               891 non-null    int64
#  2   Name                 891 non-null    object
#  3   Sex                  891 non-null    object
#  4   Age                  714 non-null    float64
#  5   SibSp                891 non-null    int64
#  6   Parch                891 non-null    int64
#  7   Ticket               891 non-null    object
#  8   Fare                 891 non-null    float64
#  9   Cabin                204 non-null    object
#  10  Embarked             889 non-null    object
#  11  Survived(Status)     891 non-null    object
#  12  Pclass(Status)       891 non-null    object
#  13  Embarked(Status)     889 non-null    object
#  14  Embarked(C)          891 non-null    bool
#  15  Embarked(S)          891 non-null    bool
#  16  Embarked(Q)          891 non-null    bool
#  17  Pclass(F)            891 non-null    bool
#  18  Pclass(B)            891 non-null    bool
#  19  Pclass(E)            891 non-null    bool
#  20  AgeType              714 non-null    object
#  21  AgeBlank             891 non-null    object
#  22  Age(fill)            891 non-null    float64
#  23  Single               891 non-null    bool
#  24  FamilySize           891 non-null    int64
#  25  FamilyType           891 non-null    object
#  26  FamilyType(Single)   891 non-null    bool
#  27  FamilyType(Nuclear)  891 non-null    bool
#  28  FamilyType(Big)      891 non-null    bool
#  29  Title                891 non-null    object
#  30  Title(Status)        891 non-null    object
#  31  Married              891 non-null    bool
#  32  Sex_encode           891 non-null    float64
# dtypes: bool(11), float64(4), int64(5), object(13)
# memory usage: 169.7+ KB

# %%
train.isnull().sum()
# Out:
# Survived                 0
# Pclass                   0
# Name                     0
# Sex                      0
# Age                    177
# SibSp                    0
# Parch                    0
# Ticket                   0
# Fare                     0
# Cabin                  687
# Embarked                 2
# Survived(Status)         0
# Pclass(Status)           0
# Embarked(Status)         2
# Embarked(C)              0
# Embarked(S)              0
# Embarked(Q)              0
# Pclass(F)                0
# Pclass(B)                0
# Pclass(E)                0
# AgeType                177
# AgeBlank                 0
# Age(fill)                0
# Single                   0
# FamilySize               0
# FamilyType               0
# FamilyType(Single)       0
# FamilyType(Nuclear)      0
# FamilyType(Big)          0
# Title                    0
# Title(Status)            0
# Married                  0
# Sex_encode               0
# dtype: int64

# %% [markdown]
# ## Upload test data

# %%
test = pd.read_csv("data_titanic/test.csv", index_col = "PassengerId")

# %%
test#.head(3)
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
#               Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0              330911    7.8292   NaN        Q
# 893          47.0      1      0              363272    7.0000   NaN        S
# 894          62.0      0      0              240276    9.6875   NaN        Q
# 895          27.0      0      0              315154    8.6625   NaN        S
# 896          22.0      1      1             3101298   12.2875   NaN        S
# ...           ...    ...    ...                 ...       ...   ...      ...
# 1305          NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1306         39.0      0      0            PC 17758  108.9000  C105        C
# 1307         38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308          NaN      0      0              359309    8.0500   NaN        S
# 1309          NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %%
test.shape
# Out:
# (418, 10)

# %%
test.columns
# Out:
# Index(['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')

# %%
test["Sex"] == 'male'
test.loc[test["Sex"] == "male", "Sex_encode"] = 0
test.loc[test["Sex"] == "female", "Sex_encode"] = 1
test[["Sex", "Sex_encode"]].head()
# Out:
#                 Sex  Sex_encode
# PassengerId
# 892            male         0.0
# 893          female         1.0
# 894            male         0.0
# 895            male         0.0
# 896          female         1.0

# %% [markdown]
# ## Learning (Decision-tree)

# %% [markdown]
# 참고 : [머신러닝 학습을 위한 데이터셋 분리(train,test,validation)](https://velog.io/@ljs7463/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D-%ED%95%99%EC%8A%B5%EC%9D%84-%EC%9C%84%ED%95%9C-%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B-%EB%B6%84%EB%A6%ACtraintestvalidation)

# %% [markdown]
# 1. feature 선택
# 2. 예측결과를 정답과 비교하며 학습
# 3. 의사결정트리 생성

# %%
train.head(1)
# Out:
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#              Parch     Ticket  Fare Cabin  ... Single FamilySize FamilyType  \
# PassengerId                                ...
# 1                0  A/5 21171  7.25   NaN  ...  False          2    Nuclear
#
#             FamilyType(Single)  FamilyType(Nuclear)  FamilyType(Big)  Title  \
# PassengerId
# 1                        False                 True            False     Mr
#
#              Title(Status)  Married  Sex_encode
# PassengerId
# 1                       Mr     True         0.0
#
# [1 rows x 33 columns]

# %%
train.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Survived(Status)', 'Pclass(Status)',
#        'Embarked(Status)', 'Embarked(C)', 'Embarked(S)', 'Embarked(Q)',
#        'Pclass(F)', 'Pclass(B)', 'Pclass(E)', 'AgeType', 'AgeBlank',
#        'Age(fill)', 'Single', 'FamilySize', 'FamilyType', 'FamilyType(Single)',
#        'FamilyType(Nuclear)', 'FamilyType(Big)', 'Title', 'Title(Status)',
#        'Married', 'Sex_encode'],
#       dtype='object')

# %%
# Label : Survived ( Target Goal )
# Feature : using Columns while learning

label_name = "Survived"
#feature_names = ["Pclass", "Sex_encode"]

# feature_names = ['Embarked(C)', 'Embarked(S)', 'Embarked(Q)',
#                  'Pclass(F)', 'Pclass(B)', 'Pclass(E)', 
#                  'Age(fill)', 'Single', 'FamilySize', 
#                  'FamilyType(Single)', 'FamilyType(Nuclear)', 'FamilyType(Big)', 
#                  'Married', 'Sex_encode']

feature_names = ['Pclass(F)', 'Pclass(B)', 'Pclass(E)', 
                 'SibSp', 'Parch', 'Single','Sex_encode']

# %%
# 모든 컬럼이 출력되도록 설정
pd.set_option('display.max_columns', None)
train.head(1)
# Out:
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#              Parch     Ticket  Fare Cabin Embarked Survived(Status)  \
# PassengerId
# 1                0  A/5 21171  7.25   NaN        S           Perish
#
#             Pclass(Status) Embarked(Status)  Embarked(C)  Embarked(S)  \
# PassengerId
# 1                  Economy      Southampton        False         True
#
#              Embarked(Q)  Pclass(F)  Pclass(B)  Pclass(E) AgeType   AgeBlank  \
# PassengerId
# 1                  False      False      False       True  Medium  Not Blank
#
#              Age(fill)  Single  FamilySize FamilyType  FamilyType(Single)  \
# PassengerId
# 1                 22.0   False           2    Nuclear               False
#
#              FamilyType(Nuclear)  FamilyType(Big) Title Title(Status)  \
# PassengerId
# 1                           True            False    Mr            Mr
#
#              Married  Sex_encode
# PassengerId
# 1               True         0.0

# %%
label_name
# Out:
# 'Survived'

# %%
feature_names
# Out:
# ['Pclass(F)',
#  'Pclass(B)',
#  'Pclass(E)',
#  'SibSp',
#  'Parch',
#  'Single',
#  'Sex_encode']

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#             Survived(Status) Pclass(Status) Embarked(Status)  Embarked(C)  \
# PassengerId
# 1                     Perish        Economy      Southampton        False
# 2                   Survived    First Class        Cherbourg         True
# 3                   Survived        Economy      Southampton        False
# 4                   Survived    First Class      Southampton        False
# 5                     Perish        Economy      Southampton        False
#
#              Embarked(S)  Embarked(Q)  Pclass(F)  Pclass(B)  Pclass(E)  \
# PassengerId
# 1                   True        False      False      False       True
# 2                  False        False       True      False      False
# 3                   True        False      False      False       True
# 4                   True        False       True      False      False
# 5                   True        False      False      False       True
#
#             AgeType   AgeBlank  Age(fill)  Single  FamilySize FamilyType  \
# PassengerId
# 1            Medium  Not Blank       22.0   False           2    Nuclear
# 2               Old  Not Blank       38.0   False           2    Nuclear
# 3            Medium  Not Blank       26.0    True           1     Single
# 4               Old  Not Blank       35.0   False           2    Nuclear
# 5               Old  Not Blank       35.0    True           1     Single
#
#              FamilyType(Single)  FamilyType(Nuclear)  FamilyType(Big) Title  \
# PassengerId
# 1                         False                 True            False    Mr
# 2                         False                 True            False   Mrs
# 3                          True                False            False  Miss
# 4                         False                 True            False   Mrs
# 5                          True                False            False    Mr
#
#             Title(Status)  Married  Sex_encode
# PassengerId
# 1                      Mr     True         0.0
# 2                     Mrs     True         1.0
# 3                    Miss    False         1.0
# 4                     Mrs     True         1.0
# 5                      Mr     True         0.0

# %%
X_train = train[feature_names]
X_train.head()
# Out:
#              Pclass(F)  Pclass(B)  Pclass(E)  SibSp  Parch  Single  Sex_encode
# PassengerId
# 1                False      False       True      1      0   False         0.0
# 2                 True      False      False      1      0   False         1.0
# 3                False      False       True      0      0    True         1.0
# 4                 True      False      False      1      0   False         1.0
# 5                False      False       True      0      0    True         0.0

# %%
X_test = test[feature_names]
X_test.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 X_test = test[feature_names]
#       2 X_test.tail()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Pclass(F)', 'Pclass(B)', 'Pclass(E)', 'Single'] not in index"

# %%
y_train = train[label_name]
y_train.head()

# %% [markdown]
# ### Machine Learning : scikit-learn

# %% [markdown]
# 참고 : [머신러닝 - 결정 트리(Decision Tree)](https://bkshin.tistory.com/entry/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D-4-%EA%B2%B0%EC%A0%95-%ED%8A%B8%EB%A6%ACDecision-Tree)

# %%
# fit : learning
# predict : forecast

from sklearn.tree import DecisionTreeClassifier

# %%
# max_depth : Depth number in DecisionTree
# random_state : 

model = DecisionTreeClassifier(max_depth = 3, random_state = 0)
model

# %% [markdown]
# ### fit : learning by model

# %%
#X_train
#y_train

# %%
model.fit(X_train, y_train)

# %%
model.score(X_train, y_train)

# %% [markdown]
# ### 그럼, 동전 던지기로 예측...

# %%
import numpy as np

# %%
y_train

# %%
np.random.randint(0,2)

# %%
df = pd.DataFrame(np.random.randint(0, 2, size=(len(y_train), 1)), columns=['x'])
#df

# %%
y_guess = df['x']
y_guess

# %%
model.score(X_train, y_guess)

# %%
#!pip install graphviz

# %%
# from sklearn.tree import export_graphviz
# import graphviz

# %% [markdown]
# ### (라이브러리) [Graphviz 설치 방법](https://zephyrus1111.tistory.com/123)

# %%
feature_names

# %%
# export_graphviz(model,
#                 feature_names=feature_names,
#                 class_names=['Unsurvived','Survived'],
#                 out_file="data_titanic/decision-tree.dot")

# %%
# with open("data_titanic/decision-tree.dot") as f:
#     dot_graph = f.read()
    
# graphviz.Source(dot_graph)

# %% [markdown]
# ### predict : prediction

# %%
#X_test

# %%
model.predict(X_test)

# %%
predictions = model.predict(X_test)

# %%
len(predictions)

# %%
X_test

# %% [markdown]
# ## Submission

# %%
submission = pd.read_csv("data_titanic/gender_submission.csv", index_col="PassengerId")
submission.head()

# %%
submission["Survived"] = predictions
submission.head()

# %%
submission.to_csv("data_titanic/submission_test.csv")

# %%
# 캐글 제출 0.77 : 9000등 성능

# %%
# 중급적용 후 캐글 제출 0.78229 : 2894등 성능
