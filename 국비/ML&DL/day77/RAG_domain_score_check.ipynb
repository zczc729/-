# %%
import pandas as pd
import numpy as np

co_score_1 = pd.read_csv("file/요약_O_리랭크_X_코사인_유사도.csv")
co_score_2 = pd.read_csv("file/요약_O_리랭크_O_코사인_유사도.csv")
co_score_3 = pd.read_csv("file/요약_X_리랭크_O_코사인_유사도.csv")

co_answer_1 = pd.read_csv("file/요약_O_리랭크_X_답변.csv")
co_answer_2 = pd.read_csv("file/요약_X_리랭크_O_답변.csv")

# pd.set_option('display.max_columns', None)

# %%
co_score_1.rename({"Unnamed: 0" : "Describe"}, inplace=True)
co_score_1
# Out:
#   Unnamed: 0  alli_gpt-4-turbo_answer_cosine_similarity  \
# 0      count                                 289.000000
# 1       mean                                   0.861440
# 2        std                                   0.152223
# 3        min                                   0.141284
# 4        25%                                   0.831598
# 5        50%                                   0.912473
# 6        75%                                   0.955689
# 7        max                                   0.996907
#
#    alli_gpt-4_answer_cosine_similarity  \
# 0                           289.000000
# 1                             0.854913
# 2                             0.157872
# 3                             0.143413
# 4                             0.815049
# 5                             0.911281
# 6                             0.954281
# 7                             0.999642
#
#    alli_claude3-opus_answer_cosine_similarity  \
# 0                                  289.000000
# ...

# %%
co_answer_1.groupby(["domain"]).describe()
# Out:
#          Unnamed: 0                                                         \
#               count   mean        std    min     25%    50%     75%    max
# domain
# commerce       54.0  261.5  15.732133  235.0  248.25  261.5  274.75  288.0
# finance        60.0   29.5  17.464249    0.0   14.75   29.5   44.25   59.0
# law            57.0  206.0  16.598193  178.0  192.00  206.0  220.00  234.0
# medical        58.0  148.5  16.886879  120.0  134.25  148.5  162.75  177.0
# public         60.0   89.5  17.464249   60.0   74.75   89.5  104.25  119.0
#
#          alli_gpt-4-turbo_answer_cosine_similarity            ...  \
#                                              count      mean  ...
# domain                                                        ...
# commerce                                      54.0  0.881782  ...
# finance                                       60.0  0.871252  ...
# law                                           57.0  0.844841  ...
# ...

# %%
co_score_1
# Out:
#   Unnamed: 0  alli_gpt-4-turbo_answer_cosine_similarity  \
# 0      count                                 289.000000
# 1       mean                                   0.861440
# 2        std                                   0.152223
# 3        min                                   0.141284
# 4        25%                                   0.831598
# 5        50%                                   0.912473
# 6        75%                                   0.955689
# 7        max                                   0.996907
#
#    alli_gpt-4_answer_cosine_similarity  \
# 0                           289.000000
# 1                             0.854913
# 2                             0.157872
# 3                             0.143413
# 4                             0.815049
# 5                             0.911281
# 6                             0.954281
# 7                             0.999642
#
#    alli_claude3-opus_answer_cosine_similarity  \
# 0                                  289.000000
# ...

# %%
co_score_2
# Out:
#   Unnamed: 0  My Model Answer_cosine_similarity
# 0      count                         289.000000
# 1       mean                           0.782550
# 2        std                           0.161069
# 3        min                           0.096596
# 4        25%                           0.714759
# 5        50%                           0.825831
# 6        75%                           0.895796
# 7        max                           0.999525

# %%
co_score_3['My Model Answer_cosine_similarity']
# Out:
# 0    289.000000
# 1      0.787239
# 2      0.153460
# 3      0.096596
# 4      0.729015
# 5      0.822780
# 6      0.893330
# 7      0.999525
# Name: My Model Answer_cosine_similarity, dtype: float64

# %%
co_answer_1
# Out:
#      Unnamed: 0    domain                                           question  \
# 0             0   finance  시중은행, 지방은행, 인터넷은행의 인가 요건 및 절차에 차이가 있는데 그 차이점은 ...
# 1             1   finance  은행업을 신청하고자 할 때, 은행법상 소유규제에 부합하는 대주주 요건을 충족하려면 ...
# 2             2   finance  본인가를 받으려는 지방은행이 시중은행 전환시 예비인가를 받을 필요가 있는지 설명하시...
# 3             3   finance  은행법에 의거 예비인가를 신청할 수 있는지와, 그 경우 금융위원회가 검토했어야 하는...
# 4             4   finance  2019년 YTD 기준으로 브라질의 주식 시장 수익률과 베트남의 주식 시장 수익률 ...
# ..          ...       ...                                                ...
# 284         284  commerce  2020년 기업의 자체 라방 거래액이 전체 생방송 라이브커머스 대비 차지하는 비율과...
# 285         285  commerce  콰이서우와 틱톡에서 거래비율이 급성장한 연도와 그 이유, 그리고 현재 거래액은 어떻...
# 286         286  commerce               틱톡과 콰이서우의 서비스 업체 보상 정책이 어떻게 서로 다른가요?
# 287         287  commerce  한국콘텐츠진흥원 북경비즈니스센터의 시설 중 상설전시공간에서는 어떤 종류의 한국 콘텐...
# 288         288  commerce  KOCCA 북경비즈니스센터의 통역 서비스를 신청하기 위해 필요한 절차와 조건은 무엇...
#
# ...

# %%
co_answer_2
# Out:
#      Unnamed: 0    domain                                           question  \
# 0             0   finance  시중은행, 지방은행, 인터넷은행의 인가 요건 및 절차에 차이가 있는데 그 차이점은 ...
# 1             1   finance  은행업을 신청하고자 할 때, 은행법상 소유규제에 부합하는 대주주 요건을 충족하려면 ...
# 2             2   finance  본인가를 받으려는 지방은행이 시중은행 전환시 예비인가를 받을 필요가 있는지 설명하시...
# 3             3   finance  은행법에 의거 예비인가를 신청할 수 있는지와, 그 경우 금융위원회가 검토했어야 하는...
# 4             4   finance  2019년 YTD 기준으로 브라질의 주식 시장 수익률과 베트남의 주식 시장 수익률 ...
# ..          ...       ...                                                ...
# 284         284  commerce  2020년 기업의 자체 라방 거래액이 전체 생방송 라이브커머스 대비 차지하는 비율과...
# 285         285  commerce  콰이서우와 틱톡에서 거래비율이 급성장한 연도와 그 이유, 그리고 현재 거래액은 어떻...
# 286         286  commerce               틱톡과 콰이서우의 서비스 업체 보상 정책이 어떻게 서로 다른가요?
# 287         287  commerce  한국콘텐츠진흥원 북경비즈니스센터의 시설 중 상설전시공간에서는 어떤 종류의 한국 콘텐...
# 288         288  commerce  KOCCA 북경비즈니스센터의 통역 서비스를 신청하기 위해 필요한 절차와 조건은 무엇...
#
#                       target_file_name  \
# ...

# %%
co_score_1.columns
