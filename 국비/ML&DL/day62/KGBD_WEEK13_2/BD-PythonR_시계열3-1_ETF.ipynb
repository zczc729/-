# %% [markdown]
# # 입문자를 위한, 파이썬/R 데이터 분석

# %% [markdown]
# ]

# %% [markdown]
# ## Today's mission
#
# - <p style="font-weight:bold">ETF(상장지수펀드) 목록 수집</p>
# - ETF 데이터 전처리
# - ETF 분석과 시각화

# %% [markdown]
# ]

# %% [markdown]
# ## ETF(상장지수펀드) 목록 수집
#
#
# ### ETF(Exchange Traded Fund, 上場指數-)란?
# * ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF:Portfolio Deposit File)이 투명하게 공개되어 있고, 장중에는 실시간으로 순자산가치(NAV:Net Asset Value)가 제공되어 거래에 참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
#     * 출처 : [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)
#
#
# ### 크롬 브라우저의 네트워크 정보를 통한 데이터 수집
# * json 데이터 수집과 파일저장 방법
#
# * [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)

# %%
# 라이브러리를 불러옵니다.
# 데이터 분석을 위한 pandas, 수치계산을 위한 numpy, http 요청을 위한 requests를 받아옵니다.
import pandas as pd
import numpy as np
import requests

# %%
# 수집할 url을 가져옵니다.
url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc"
url
# Out:
# 'https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc'

# %% [markdown]
# ### Pandas를 통한 요청

# %%
#pd.read_html(url)

# %% [markdown]
# ### JSON
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/JSON_vector_logo.svg/300px-JSON_vector_logo.svg.png" width="100">
#
# JSON(제이슨, JavaScript Object Notation)은 속성-값 쌍( attribute–value pairs and array data types (or any other serializable value)) 또는 "키-값 쌍"으로 이루어진 데이터 오브젝트를 전달하기 위해 인간이 읽을 수 있는 텍스트를 사용하는 개방형 표준 포맷이다. 비동기 브라우저/서버 통신 (AJAX)을 위해, 넓게는 XML(AJAX가 사용)을 대체하는 주요 데이터 포맷이다. 특히, 인터넷에서 자료를 주고 받을 때 그 자료를 표현하는 방법으로 알려져 있다. 자료의 종류에 큰 제한은 없으며, 특히 컴퓨터 프로그램의 변수값을 표현하는 데 적합하다.
# 본래는 자바스크립트 언어로부터 파생되어 자바스크립트의 구문 형식을 따르지만 언어 독립형 데이터 포맷이다. 즉, 프로그래밍 언어나 플랫폼에 독립적이므로, 구문 분석 및 JSON 데이터 생성을 위한 코드는 C, C++, C#, 자바, 자바스크립트, 펄, 파이썬 등 수많은 프로그래밍 언어에서 쉽게 이용할 수 있다.
#
# * 출처 : [JSON - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/JSON)

# %% [markdown]
# ### requests를 통한 HTTP 요청
# * [Requests: HTTP for Humans™ — Requests documentation](https://requests.readthedocs.io/en/master/)

# %%
# requests 라이브러리를 통해 url을 받아옵니다.
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'resultCode': 'success',
#  'result': {'etfItemList': [{'itemcode': '459580',
#     'etfTabCode': 6,
#     'itemname': 'KODEX CD금리액티브(합성)',
#     'nowVal': 1046085,
#     'risefall': '2',
#     'changeVal': 230,
#     'changeRate': 0.02,
#     'nav': 1046089.0,
#     'threeMonthEarnRate': 0.8972,
#     'quant': 195638,
#     'amonut': 204654,
#     'marketSum': 93402},
#    {'itemcode': '069500',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200',
#     'nowVal': 36820,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -0.31,
#     'nav': 36885.0,
#     'threeMonthEarnRate': -0.4931,
#     'quant': 1101467,
#     'amonut': 40510,
#     'marketSum': 61140},
#    {'itemcode': '357870',
#     'etfTabCode': 6,
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'nowVal': 54825,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 54828.0,
#     'threeMonthEarnRate': 0.911,
#     'quant': 25319,
#     'amonut': 1388,
#     'marketSum': 61007},
#    {'itemcode': '423160',
#     'etfTabCode': 6,
#     'itemname': 'KODEX KOFR금리액티브(합성)',
#     'nowVal': 107820,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.03,
#     'nav': 107779.0,
#     'threeMonthEarnRate': 0.8939,
#     'quant': 16807,
#     'amonut': 1812,
#     'marketSum': 45037},
#    {'itemcode': '360750',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500',
#     'nowVal': 18650,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.19,
#     'nav': 18599.0,
#     'threeMonthEarnRate': 3.673,
#     'quant': 4820460,
#     'amonut': 89909,
#     'marketSum': 43184},
#    {'itemcode': '449170',
#     'etfTabCode': 6,
#     'itemname': 'TIGER KOFR금리액티브(합성)',
#     'nowVal': 106345,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.02,
#     'nav': 106309.0,
#     'threeMonthEarnRate': 0.9063,
#     'quant': 12834,
#     'amonut': 1364,
#     'marketSum': 36896},
#    {'itemcode': '133690',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100',
#     'nowVal': 116830,
#     'risefall': '5',
#     'changeVal': -1045,
#     'changeRate': -0.89,
#     'nav': 116383.0,
#     'threeMonthEarnRate': 3.8162,
#     'quant': 57140,
#     'amonut': 6677,
#     'marketSum': 36299},
#    {'itemcode': '273130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'nowVal': 113760,
#     'risefall': '5',
#     'changeVal': -185,
#     'changeRate': -0.16,
#     'nav': 113765.0,
#     'threeMonthEarnRate': 3.2578,
#     'quant': 2537,
#     'amonut': 288,
#     'marketSum': 28027},
#    {'itemcode': '381180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체나스닥',
#     'nowVal': 18150,
#     'risefall': '5',
#     'changeVal': -450,
#     'changeRate': -2.42,
#     'nav': 18022.0,
#     'threeMonthEarnRate': 1.4619,
#     'quant': 687020,
#     'amonut': 12464,
#     'marketSum': 27506},
#    {'itemcode': '381170',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10 INDXX',
#     'nowVal': 20120,
#     'risefall': '5',
#     'changeVal': -235,
#     'changeRate': -1.15,
#     'nav': 20044.0,
#     'threeMonthEarnRate': 7.6984,
#     'quant': 1040203,
#     'amonut': 20942,
#     'marketSum': 27182},
#    {'itemcode': '278530',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200TR',
#     'nowVal': 12855,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.31,
#     'nav': 12880.0,
#     'threeMonthEarnRate': -0.54,
#     'quant': 8870,
#     'amonut': 113,
#     'marketSum': 22657},
#    {'itemcode': '122630',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 레버리지',
#     'nowVal': 18745,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -0.64,
#     'nav': 18902.0,
#     'threeMonthEarnRate': -4.19,
#     'quant': 4098125,
#     'amonut': 76627,
#     'marketSum': 21332},
#    {'itemcode': '465680',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 24-12 은행채(AA+이상)액티브',
#     'nowVal': 10395,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.05,
#     'nav': 10393.0,
#     'threeMonthEarnRate': 0.9227,
#     'quant': 451,
#     'amonut': 4,
#     'marketSum': 21222},
#    {'itemcode': '455890',
#     'etfTabCode': 6,
#     'itemname': 'RISE 머니마켓액티브',
#     'nowVal': 52800,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 52800.0,
#     'threeMonthEarnRate': 1.0237,
#     'quant': 18609,
#     'amonut': 982,
#     'marketSum': 20194},
#    {'itemcode': '102110',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200',
#     'nowVal': 36880,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -0.3,
#     'nav': 36949.0,
#     'threeMonthEarnRate': -0.5325,
#     'quant': 348733,
#     'amonut': 12843,
#     'marketSum': 19712},
#    {'itemcode': '379800',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500TR',
#     'nowVal': 17040,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.2,
#     'nav': 17000.0,
#     'threeMonthEarnRate': 3.6733,
#     'quant': 1098057,
#     'amonut': 18717,
#     'marketSum': 16733},
#    {'itemcode': '481050',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 1년은행양도성예금증서+액티브(합성)',
#     'nowVal': 1012900,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.01,
#     'nav': 1012905.0,
#     'threeMonthEarnRate': 0.9066,
#     'quant': 5609,
#     'amonut': 5681,
#     'marketSum': 16717},
#    {'itemcode': '470260',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 24-12 금융채(AA-이상)',
#     'nowVal': 51775,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 51776.0,
#     'threeMonthEarnRate': 1.0243,
#     'quant': 63,
#     'amonut': 3,
#     'marketSum': 16199},
#    {'itemcode': '453850',
#     'etfTabCode': 6,
#     'itemname': 'ACE 미국30년국채액티브(H)',
#     'nowVal': 8885,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.73,
#     'nav': 8869.0,
#     'threeMonthEarnRate': 8.4717,
#     'quant': 861121,
#     'amonut': 7656,
#     'marketSum': 15309},
#    {'itemcode': '371460',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'nowVal': 6525,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 6549.0,
#     'threeMonthEarnRate': -17.6137,
#     'quant': 145736,
#     'amonut': 952,
#     'marketSum': 14666},
#    {'itemcode': '214980',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권PLUS',
#     'nowVal': 111670,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.01,
#     'nav': 111671.0,
#     'threeMonthEarnRate': 0.963,
#     'quant': 202218,
#     'amonut': 22580,
#     'marketSum': 14075},
#    {'itemcode': '233740',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150레버리지',
#     'nowVal': 9125,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.71,
#     'nav': 9187.0,
#     'threeMonthEarnRate': -12.1415,
#     'quant': 5627739,
#     'amonut': 50934,
#     'marketSum': 13186},
#    {'itemcode': '252670',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 200선물인버스2X',
#     'nowVal': 1989,
#     'risefall': '2',
#     'changeVal': 14,
#     'changeRate': 0.71,
#     'nav': 1991.0,
#     'threeMonthEarnRate': -1.9852,
#     'quant': 70732449,
#     'amonut': 141032,
#     'marketSum': 13054},
#    {'itemcode': '102780',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹',
#     'nowVal': 9530,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.16,
#     'nav': 9553.0,
#     'threeMonthEarnRate': 0.5282,
#     'quant': 74257,
#     'amonut': 706,
#     'marketSum': 12904},
#    {'itemcode': '385540',
#     'etfTabCode': 6,
#     'itemname': 'RISE 종합채권(A-이상)액티브',
#     'nowVal': 105545,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.04,
#     'nav': 105532.0,
#     'threeMonthEarnRate': 3.302,
#     'quant': 13,
#     'amonut': 1,
#     'marketSum': 12555},
#    {'itemcode': '148020',
#     'etfTabCode': 1,
#     'itemname': 'RISE 200',
#     'nowVal': 37075,
#     'risefall': '5',
#     'changeVal': -135,
#     'changeRate': -0.36,
#     'nav': 37139.0,
#     'threeMonthEarnRate': -0.4362,
#     'quant': 112656,
#     'amonut': 4171,
#     'marketSum': 12494},
#    {'itemcode': '458730',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국배당다우존스',
#     'nowVal': 11780,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.26,
#     'nav': 11751.0,
#     'threeMonthEarnRate': 2.8716,
#     'quant': 191332,
#     'amonut': 2253,
#     'marketSum': 12210},
#    {'itemcode': '310970',
#     'etfTabCode': 1,
#     'itemname': 'TIGER MSCI Korea TR',
#     'nowVal': 15755,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.28,
#     'nav': 15788.0,
#     'threeMonthEarnRate': 0.1902,
#     'quant': 12,
#     'amonut': 0,
#     'marketSum': 12179},
#    {'itemcode': '360200',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국S&P500',
#     'nowVal': 18850,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.21,
#     'nav': 18805.0,
#     'threeMonthEarnRate': 3.6602,
#     'quant': 490701,
#     'amonut': 9256,
#     'marketSum': 12045},
#    {'itemcode': '315930',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Top5PlusTR',
#     'nowVal': 23645,
#     'risefall': '5',
#     'changeVal': -190,
#     'changeRate': -0.8,
#     'nav': 23667.0,
#     'threeMonthEarnRate': -0.2303,
#     'quant': 13806,
#     'amonut': 326,
#     'marketSum': 11917},
#    {'itemcode': '379810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100TR',
#     'nowVal': 17480,
#     'risefall': '5',
#     'changeVal': -155,
#     'changeRate': -0.88,
#     'nav': 17416.0,
#     'threeMonthEarnRate': 3.8269,
#     'quant': 411749,
#     'amonut': 7200,
#     'marketSum': 11729},
#    {'itemcode': '292150',
#     'etfTabCode': 2,
#     'itemname': 'TIGER TOP10',
#     'nowVal': 12260,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -0.81,
#     'nav': 12273.0,
#     'threeMonthEarnRate': -1.9826,
#     'quant': 10694,
#     'amonut': 130,
#     'marketSum': 11028},
#    {'itemcode': '305720',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업',
#     'nowVal': 16310,
#     'risefall': '5',
#     'changeVal': -195,
#     'changeRate': -1.18,
#     'nav': 16333.0,
#     'threeMonthEarnRate': -12.7874,
#     'quant': 564580,
#     'amonut': 9210,
#     'marketSum': 10960},
#    {'itemcode': '305540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지테마',
#     'nowVal': 19310,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -1.18,
#     'nav': 19342.0,
#     'threeMonthEarnRate': -12.7874,
#     'quant': 208988,
#     'amonut': 4039,
#     'marketSum': 10592},
#    {'itemcode': '475630',
#     'etfTabCode': 7,
#     'itemname': 'TIGER CD1년금리액티브(합성)',
#     'nowVal': 1020570,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.01,
#     'nav': 1020572.0,
#     'threeMonthEarnRate': 0.9162,
#     'quant': 9911,
#     'amonut': 10114,
#     'marketSum': 10259},
#    {'itemcode': '476810',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 25-11 은행채(AA-이상)PLUS액티브',
#     'nowVal': 10250,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.05,
#     'nav': 10245.0,
#     'threeMonthEarnRate': 1.4356,
#     'quant': 12070,
#     'amonut': 123,
#     'marketSum': 10066},
#    {'itemcode': '367380',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국나스닥100',
#     'nowVal': 20075,
#     'risefall': '5',
#     'changeVal': -175,
#     'changeRate': -0.86,
#     'nav': 19998.0,
#     'threeMonthEarnRate': 3.7876,
#     'quant': 158291,
#     'amonut': 3177,
#     'marketSum': 10017},
#    {'itemcode': '453540',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 25-10 회사채(A+이상)액티브',
#     'nowVal': 53375,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.07,
#     'nav': 53393.0,
#     'threeMonthEarnRate': 1.2511,
#     'quant': 22110,
#     'amonut': 1180,
#     'marketSum': 9490},
#    {'itemcode': '229200',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥150',
#     'nowVal': 12870,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.19,
#     'nav': 12932.0,
#     'threeMonthEarnRate': -4.2688,
#     'quant': 979430,
#     'amonut': 12546,
#     'marketSum': 9318},
#    {'itemcode': '356540',
#     'etfTabCode': 6,
#     'itemname': 'ACE 종합채권(AA-이상)KIS액티브',
#     'nowVal': 104105,
#     'risefall': '5',
#     'changeVal': -185,
#     'changeRate': -0.18,
#     'nav': 104130.0,
#     'threeMonthEarnRate': 3.4725,
#     'quant': 3107,
#     'amonut': 323,
#     'marketSum': 8580},
#    {'itemcode': '396500',
#     'etfTabCode': 2,
#     'itemname': 'TIGER Fn반도체TOP10',
#     'nowVal': 11680,
#     'risefall': '5',
#     'changeVal': -155,
#     'changeRate': -1.31,
#     'nav': 11697.0,
#     'threeMonthEarnRate': -11.3151,
#     'quant': 229146,
#     'amonut': 2673,
#     'marketSum': 8036},
#    {'itemcode': '157450',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기통안채',
#     'nowVal': 107995,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 108008.0,
#     'threeMonthEarnRate': 0.9394,
#     'quant': 1273,
#     'amonut': 137,
#     'marketSum': 7778},
#    {'itemcode': '447820',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 24-10 회사채(A+이상)액티브',
#     'nowVal': 55470,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 55475.0,
#     'threeMonthEarnRate': 0.9463,
#     'quant': 7128,
#     'amonut': 395,
#     'marketSum': 7723},
#    {'itemcode': '476550',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국30년국채프리미엄액티브(H)',
#     'nowVal': 9800,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.66,
#     'nav': 9788.0,
#     'threeMonthEarnRate': 7.0072,
#     'quant': 871487,
#     'amonut': 8543,
#     'marketSum': 7580},
#    {'itemcode': '152100',
#     'etfTabCode': 1,
#     'itemname': 'PLUS 200',
#     'nowVal': 37390,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -0.31,
#     'nav': 37455.0,
#     'threeMonthEarnRate': -0.4328,
#     'quant': 132933,
#     'amonut': 4959,
#     'marketSum': 7441},
#    {'itemcode': '294400',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200TR',
#     'nowVal': 46740,
#     'risefall': '5',
#     'changeVal': -165,
#     'changeRate': -0.35,
#     'nav': 46821.0,
#     'threeMonthEarnRate': -0.4775,
#     'quant': 63734,
#     'amonut': 2974,
#     'marketSum': 7221},
#    {'itemcode': '153130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권',
#     'nowVal': 110725,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 110729.0,
#     'threeMonthEarnRate': 0.962,
#     'quant': 1203,
#     'amonut': 133,
#     'marketSum': 7217},
#    {'itemcode': '436140',
#     'etfTabCode': 6,
#     'itemname': 'SOL 종합채권(AA-이상)액티브',
#     'nowVal': 110270,
#     'risefall': '5',
#     'changeVal': -135,
#     'changeRate': -0.12,
#     'nav': 110277.0,
#     'threeMonthEarnRate': 3.3464,
#     'quant': 802,
#     'amonut': 88,
#     'marketSum': 7173},
#    {'itemcode': '458760',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국배당+7%프리미엄다우존스',
#     'nowVal': 10280,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.19,
#     'nav': 10262.0,
#     'threeMonthEarnRate': 2.1098,
#     'quant': 73845,
#     'amonut': 759,
#     'marketSum': 7155},
#    {'itemcode': '488770',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 머니마켓액티브',
#     'nowVal': 100260,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.03,
#     'nav': 100260.0,
#     'threeMonthEarnRate': None,
#     'quant': 3621,
#     'amonut': 363,
#     'marketSum': 6717},
#    {'itemcode': '451540',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 종합채권(AA-이상)액티브',
#     'nowVal': 54500,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.06,
#     'nav': 54490.0,
#     'threeMonthEarnRate': 3.3544,
#     'quant': 670,
#     'amonut': 36,
#     'marketSum': 6636},
#    {'itemcode': '139260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 IT',
#     'nowVal': 32340,
#     'risefall': '5',
#     'changeVal': -490,
#     'changeRate': -1.49,
#     'nav': 32376.0,
#     'threeMonthEarnRate': -6.0094,
#     'quant': 1642,
#     'amonut': 53,
#     'marketSum': 6597},
#    {'itemcode': '453870',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 인도니프티50',
#     'nowVal': 13395,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.26,
#     'nav': 13404.0,
#     'threeMonthEarnRate': 7.292,
#     'quant': 80060,
#     'amonut': 1072,
#     'marketSum': 6476},
#    {'itemcode': '272580',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기채권액티브',
#     'nowVal': 54385,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 54391.0,
#     'threeMonthEarnRate': 0.9466,
#     'quant': 1993,
#     'amonut': 108,
#     'marketSum': 6350},
#    {'itemcode': '446720',
#     'etfTabCode': 4,
#     'itemname': 'SOL 미국배당다우존스',
#     'nowVal': 10795,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.19,
#     'nav': 10786.0,
#     'threeMonthEarnRate': 2.7952,
#     'quant': 71046,
#     'amonut': 767,
#     'marketSum': 6088},
#    {'itemcode': '368590',
#     'etfTabCode': 4,
#     'itemname': 'RISE 미국나스닥100',
#     'nowVal': 19445,
#     'risefall': '5',
#     'changeVal': -170,
#     'changeRate': -0.87,
#     'nav': 19369.0,
#     'threeMonthEarnRate': 3.8545,
#     'quant': 54525,
#     'amonut': 1060,
#     'marketSum': 6067},
#    {'itemcode': '114800',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 인버스',
#     'nowVal': 4160,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.36,
#     'nav': 4161.0,
#     'threeMonthEarnRate': 0.2418,
#     'quant': 7432640,
#     'amonut': 30963,
#     'marketSum': 5874},
#    {'itemcode': '196230',
#     'etfTabCode': 6,
#     'itemname': 'RISE 단기통안채',
#     'nowVal': 112645,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 112651.0,
#     'threeMonthEarnRate': 0.9228,
#     'quant': 2556,
#     'amonut': 287,
#     'marketSum': 5772},
#    {'itemcode': '462010',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지소재Fn',
#     'nowVal': 5740,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -1.88,
#     'nav': 5743.0,
#     'threeMonthEarnRate': -13.3334,
#     'quant': 679534,
#     'amonut': 3913,
#     'marketSum': 5757},
#    {'itemcode': '390390',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국반도체MV',
#     'nowVal': 22350,
#     'risefall': '5',
#     'changeVal': -565,
#     'changeRate': -2.47,
#     'nav': 22230.0,
#     'threeMonthEarnRate': 4.268,
#     'quant': 223179,
#     'amonut': 4987,
#     'marketSum': 5688},
#    {'itemcode': '314250',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국빅테크10(H)',
#     'nowVal': 39950,
#     'risefall': '5',
#     'changeVal': -985,
#     'changeRate': -2.41,
#     'nav': 39693.0,
#     'threeMonthEarnRate': 7.1316,
#     'quant': 17424,
#     'amonut': 695,
#     'marketSum': 5685},
#    {'itemcode': '329750',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'nowVal': 12050,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.46,
#     'nav': 12058.0,
#     'threeMonthEarnRate': -0.5802,
#     'quant': 27810,
#     'amonut': 335,
#     'marketSum': 5635},
#    {'itemcode': '458250',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국30년국채스트립액티브(합성 H)',
#     'nowVal': 47430,
#     'risefall': '5',
#     'changeVal': -570,
#     'changeRate': -1.19,
#     'nav': 47312.0,
#     'threeMonthEarnRate': 12.9013,
#     'quant': 92690,
#     'amonut': 4400,
#     'marketSum': 5564},
#    {'itemcode': '329200',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 리츠부동산인프라',
#     'nowVal': 4700,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.21,
#     'nav': 4701.0,
#     'threeMonthEarnRate': 3.7381,
#     'quant': 220693,
#     'amonut': 1034,
#     'marketSum': 5335},
#    {'itemcode': '091160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 반도체',
#     'nowVal': 36460,
#     'risefall': '5',
#     'changeVal': -470,
#     'changeRate': -1.27,
#     'nav': 36515.0,
#     'threeMonthEarnRate': -12.2282,
#     'quant': 91481,
#     'amonut': 3335,
#     'marketSum': 5250},
#    {'itemcode': '091180',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 자동차',
#     'nowVal': 19195,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.31,
#     'nav': 19209.0,
#     'threeMonthEarnRate': -10.2907,
#     'quant': 57383,
#     'amonut': 1100,
#     'marketSum': 5240},
#    {'itemcode': '105190',
#     'etfTabCode': 1,
#     'itemname': 'ACE 200',
#     'nowVal': 37220,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -0.28,
#     'nav': 37274.0,
#     'threeMonthEarnRate': -0.5065,
#     'quant': 9057,
#     'amonut': 336,
#     'marketSum': 5229},
#    {'itemcode': '371160',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나항셍테크',
#     'nowVal': 5160,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.1,
#     'nav': 5237.0,
#     'threeMonthEarnRate': -14.9795,
#     'quant': 130728,
#     'amonut': 674,
#     'marketSum': 5106},
#    {'itemcode': '469830',
#     'etfTabCode': 6,
#     'itemname': 'SOL 초단기채권액티브',
#     'nowVal': 51750,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 51745.0,
#     'threeMonthEarnRate': 0.9855,
#     'quant': 10785,
#     'amonut': 558,
#     'marketSum': 4925},
#    {'itemcode': '453810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 인도Nifty50',
#     'nowVal': 13735,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.26,
#     'nav': 13744.0,
#     'threeMonthEarnRate': 7.5184,
#     'quant': 187600,
#     'amonut': 2576,
#     'marketSum': 4869},
#    {'itemcode': '293180',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200',
#     'nowVal': 36880,
#     'risefall': '5',
#     'changeVal': -180,
#     'changeRate': -0.49,
#     'nav': 37003.0,
#     'threeMonthEarnRate': -0.4647,
#     'quant': 1568,
#     'amonut': 57,
#     'marketSum': 4868},
#    {'itemcode': '148070',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 국고채10년',
#     'nowVal': 116335,
#     'risefall': '5',
#     'changeVal': -260,
#     'changeRate': -0.22,
#     'nav': 116395.0,
#     'threeMonthEarnRate': 4.5179,
#     'quant': 6874,
#     'amonut': 799,
#     'marketSum': 4770},
#    {'itemcode': '161510',
#     'etfTabCode': 2,
#     'itemname': 'PLUS 고배당주',
#     'nowVal': 15785,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.41,
#     'nav': 15805.0,
#     'threeMonthEarnRate': 13.5181,
#     'quant': 121031,
#     'amonut': 1905,
#     'marketSum': 4736},
#    {'itemcode': '379780',
#     'etfTabCode': 4,
#     'itemname': 'RISE 미국S&P500',
#     'nowVal': 16315,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.21,
#     'nav': 16280.0,
#     'threeMonthEarnRate': 3.6975,
#     'quant': 29206,
#     'amonut': 476,
#     'marketSum': 4682},
#    {'itemcode': '446770',
#     'etfTabCode': 4,
#     'itemname': 'ACE 글로벌반도체TOP4 Plus SOLACTIVE',
#     'nowVal': 24600,
#     'risefall': '5',
#     'changeVal': -505,
#     'changeRate': -2.01,
#     'nav': 24434.0,
#     'threeMonthEarnRate': 8.1692,
#     'quant': 53925,
#     'amonut': 1324,
#     'marketSum': 4674},
#    {'itemcode': '278540',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea TR',
#     'nowVal': 12565,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.44,
#     'nav': 12563.0,
#     'threeMonthEarnRate': 0.4777,
#     'quant': 5321,
#     'amonut': 66,
#     'marketSum': 4649},
#    {'itemcode': '439870',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채30년액티브',
#     'nowVal': 114460,
#     'risefall': '5',
#     'changeVal': -470,
#     'changeRate': -0.41,
#     'nav': 114336.0,
#     'threeMonthEarnRate': 8.4501,
#     'quant': 2653,
#     'amonut': 303,
#     'marketSum': 4569},
#    {'itemcode': '477080',
#     'etfTabCode': 6,
#     'itemname': 'RISE CD금리액티브(합성)',
#     'nowVal': 101505,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 101472.0,
#     'threeMonthEarnRate': 0.8996,
#     'quant': 519,
#     'amonut': 52,
#     'marketSum': 4520},
#    {'itemcode': '091170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 은행',
#     'nowVal': 8965,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.39,
#     'nav': 8973.0,
#     'threeMonthEarnRate': 10.5243,
#     'quant': 138501,
#     'amonut': 1243,
#     'marketSum': 4353},
#    {'itemcode': '465580',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국빅테크TOP7 Plus',
#     'nowVal': 14520,
#     'risefall': '5',
#     'changeVal': -205,
#     'changeRate': -1.39,
#     'nav': 14464.0,
#     'threeMonthEarnRate': 6.7028,
#     'quant': 48068,
#     'amonut': 697,
#     'marketSum': 4312},
#    {'itemcode': '467940',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 25-11 회사채(A+이상)액티브',
#     'nowVal': 10580,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 10579.0,
#     'threeMonthEarnRate': 1.244,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 4151},
#    {'itemcode': '069660',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200',
#     'nowVal': 36910,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.24,
#     'nav': 36957.0,
#     'threeMonthEarnRate': -0.5511,
#     'quant': 36352,
#     'amonut': 1339,
#     'marketSum': 4115},
#    {'itemcode': '474220',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10+10%프리미엄',
#     'nowVal': 11950,
#     'risefall': '5',
#     'changeVal': -150,
#     'changeRate': -1.24,
#     'nav': 11913.0,
#     'threeMonthEarnRate': 7.8815,
#     'quant': 85994,
#     'amonut': 1027,
#     'marketSum': 4039},
#    {'itemcode': '451000',
#     'etfTabCode': 6,
#     'itemname': 'PLUS 종합채권(AA-이상)액티브',
#     'nowVal': 110880,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -0.21,
#     'nav': 110921.0,
#     'threeMonthEarnRate': 3.4447,
#     'quant': 2,
#     'amonut': 0,
#     'marketSum': 3985},
#    {'itemcode': '402970',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국배당다우존스',
#     'nowVal': 11930,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.13,
#     'nav': 11924.0,
#     'threeMonthEarnRate': 2.9195,
#     'quant': 62904,
#     'amonut': 751,
#     'marketSum': 3913},
#    {'itemcode': '476450',
#     'etfTabCode': 6,
#     'itemname': '히어로즈 머니마켓액티브',
#     'nowVal': 51010,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 51010.0,
#     'threeMonthEarnRate': 0.99,
#     'quant': 820,
#     'amonut': 41,
#     'marketSum': 3868},
#    {'itemcode': '385560',
#     'etfTabCode': 6,
#     'itemname': 'RISE KIS국고채30년Enhanced',
#     'nowVal': 78755,
#     'risefall': '5',
#     'changeVal': -415,
#     'changeRate': -0.52,
#     'nav': 78689.0,
#     'threeMonthEarnRate': 11.3345,
#     'quant': 9744,
#     'amonut': 767,
#     'marketSum': 3843},
#    {'itemcode': '114260',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채3년',
#     'nowVal': 60850,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.09,
#     'nav': 60866.0,
#     'threeMonthEarnRate': 2.2153,
#     'quant': 1385,
#     'amonut': 84,
#     'marketSum': 3827},
#    {'itemcode': '486290',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100+15%프리미엄초단기',
#     'nowVal': 9410,
#     'risefall': '5',
#     'changeVal': -80,
#     'changeRate': -0.84,
#     'nav': 9376.0,
#     'threeMonthEarnRate': None,
#     'quant': 210153,
#     'amonut': 1978,
#     'marketSum': 3750},
#    {'itemcode': '456610',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러SOFR금리액티브(합성)',
#     'nowVal': 53570,
#     'risefall': '2',
#     'changeVal': 235,
#     'changeRate': 0.44,
#     'nav': 53564.0,
#     'threeMonthEarnRate': -0.5408,
#     'quant': 3454,
#     'amonut': 185,
#     'marketSum': 3711},
#    {'itemcode': '251350',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 선진국MSCI World',
#     'nowVal': 27910,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -0.36,
#     'nav': 27894.0,
#     'threeMonthEarnRate': 2.6947,
#     'quant': 2811,
#     'amonut': 78,
#     'marketSum': 3684},
#    {'itemcode': '226490',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스피',
#     'nowVal': 27470,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.22,
#     'nav': 27535.0,
#     'threeMonthEarnRate': -0.542,
#     'quant': 13446,
#     'amonut': 368,
#     'marketSum': 3599},
#    {'itemcode': '454780',
#     'etfTabCode': 6,
#     'itemname': '히어로즈 종합채권(AA-이상)액티브',
#     'nowVal': 108075,
#     'risefall': '5',
#     'changeVal': -215,
#     'changeRate': -0.2,
#     'nav': 108070.0,
#     'threeMonthEarnRate': 3.5821,
#     'quant': 2000,
#     'amonut': 216,
#     'marketSum': 3544},
#    {'itemcode': '441680',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 미국나스닥100커버드콜(합성)',
#     'nowVal': 10315,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.15,
#     'nav': 10317.0,
#     'threeMonthEarnRate': 2.2671,
#     'quant': 42536,
#     'amonut': 438,
#     'marketSum': 3538},
#    {'itemcode': '466920',
#     'etfTabCode': 2,
#     'itemname': 'SOL 조선TOP3플러스',
#     'nowVal': 12785,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.12,
#     'nav': 12790.0,
#     'threeMonthEarnRate': 23.322,
#     'quant': 504948,
#     'amonut': 6405,
#     'marketSum': 3522},
#    {'itemcode': '364980',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지TOP10',
#     'nowVal': 10650,
#     'risefall': '5',
#     'changeVal': -170,
#     'changeRate': -1.57,
#     'nav': 10677.0,
#     'threeMonthEarnRate': -11.2388,
#     'quant': 957838,
#     'amonut': 10224,
#     'marketSum': 3509},
#    {'itemcode': '455030',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 미국달러SOFR금리액티브(합성)',
#     'nowVal': 11075,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.27,
#     'nav': 11095.0,
#     'threeMonthEarnRate': -0.4058,
#     'quant': 27707,
#     'amonut': 306,
#     'marketSum': 3449},
#    {'itemcode': '472870',
#     'etfTabCode': 6,
#     'itemname': 'RISE 미국30년국채엔화노출(합성 H)',
#     'nowVal': 9525,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.88,
#     'nav': 9536.0,
#     'threeMonthEarnRate': 12.7801,
#     'quant': 429934,
#     'amonut': 4094,
#     'marketSum': 3353},
#    {'itemcode': '479080',
#     'etfTabCode': 6,
#     'itemname': '1Q 머니마켓액티브',
#     'nowVal': 50875,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 50873.0,
#     'threeMonthEarnRate': 1.103,
#     'quant': 7102,
#     'amonut': 361,
#     'marketSum': 3266},
#    {'itemcode': '251340',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'nowVal': 3695,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.41,
#     'nav': 3709.0,
#     'threeMonthEarnRate': 1.798,
#     'quant': 12432953,
#     'amonut': 46131,
#     'marketSum': 3248},
#    {'itemcode': '304660',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 미국30년국채울트라선물(H)',
#     'nowVal': 8395,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -1.12,
#     'nav': 8402.0,
#     'threeMonthEarnRate': 8.2908,
#     'quant': 89380,
#     'amonut': 751,
#     'marketSum': 3224},
#    {'itemcode': '411060',
#     'etfTabCode': 5,
#     'itemname': 'ACE KRX금현물',
#     'nowVal': 15470,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.06,
#     'nav': 15355.0,
#     'threeMonthEarnRate': 2.1782,
#     'quant': 44266,
#     'amonut': 684,
#     'marketSum': 3202},
#    {'itemcode': '272560',
#     'etfTabCode': 6,
#     'itemname': 'RISE 단기국공채액티브',
#     'nowVal': 110220,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 110205.0,
#     'threeMonthEarnRate': 1.1008,
#     'quant': 22,
#     'amonut': 2,
#     'marketSum': 3195},
#    {'itemcode': '302190',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 중장기국채',
#     'nowVal': 51800,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.13,
#     'nav': 51806.0,
#     'threeMonthEarnRate': 3.3678,
#     'quant': 4499,
#     'amonut': 233,
#     'marketSum': 3191},
#    {'itemcode': '455850',
#     'etfTabCode': 2,
#     'itemname': 'SOL AI반도체소부장',
#     'nowVal': 12630,
#     'risefall': '5',
#     'changeVal': -155,
#     'changeRate': -1.21,
#     'nav': 12648.0,
#     'threeMonthEarnRate': -20.6148,
#     'quant': 65365,
#     'amonut': 822,
#     'marketSum': 3158},
#    {'itemcode': '457480',
#     'etfTabCode': 4,
#     'itemname': 'ACE 테슬라밸류체인액티브',
#     'nowVal': 10520,
#     'risefall': '5',
#     'changeVal': -380,
#     'changeRate': -3.49,
#     'nav': 10453.0,
#     'threeMonthEarnRate': 5.0602,
#     'quant': 127720,
#     'amonut': 1342,
#     'marketSum': 3151},
#    {'itemcode': '449180',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500(H)',
#     'nowVal': 13065,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.68,
#     'nav': 13036.0,
#     'threeMonthEarnRate': 5.2315,
#     'quant': 53263,
#     'amonut': 695,
#     'marketSum': 3136},
#    {'itemcode': '241180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 일본니케이225',
#     'nowVal': 21060,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.19,
#     'nav': 21051.0,
#     'threeMonthEarnRate': 3.33,
#     'quant': 5867,
#     'amonut': 123,
#     'marketSum': 3020},
#    {'itemcode': '481060',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 미국30년국채+12%프리미엄(합성 H)',
#     'nowVal': 10640,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.61,
#     'nav': 10628.0,
#     'threeMonthEarnRate': 6.7404,
#     'quant': 299326,
#     'amonut': 3185,
#     'marketSum': 2867},
#    {'itemcode': '448290',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500TR(H)',
#     'nowVal': 13465,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.7,
#     'nav': 13437.0,
#     'threeMonthEarnRate': 5.2386,
#     'quant': 96448,
#     'amonut': 1298,
#     'marketSum': 2861},
#    {'itemcode': '439860',
#     'etfTabCode': 6,
#     'itemname': 'KODEX ESG종합채권(A-이상)액티브',
#     'nowVal': 111350,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.07,
#     'nav': 111332.0,
#     'threeMonthEarnRate': 1.9935,
#     'quant': 9,
#     'amonut': 1,
#     'marketSum': 2844},
#    {'itemcode': '483280',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국AI테크TOP10+15%프리미엄',
#     'nowVal': 10005,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -1.23,
#     'nav': 9967.0,
#     'threeMonthEarnRate': None,
#     'quant': 233392,
#     'amonut': 2335,
#     'marketSum': 2821},
#    {'itemcode': '449190',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100(H)',
#     'nowVal': 15465,
#     'risefall': '5',
#     'changeVal': -215,
#     'changeRate': -1.37,
#     'nav': 15410.0,
#     'threeMonthEarnRate': 5.3763,
#     'quant': 50898,
#     'amonut': 787,
#     'marketSum': 2761},
#    {'itemcode': '477050',
#     'etfTabCode': 6,
#     'itemname': 'PLUS 머니마켓액티브',
#     'nowVal': 50840,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 50840.0,
#     'threeMonthEarnRate': 1.0333,
#     'quant': 10245,
#     'amonut': 520,
#     'marketSum': 2717},
#    {'itemcode': '245710',
#     'etfTabCode': 4,
#     'itemname': 'ACE 베트남VN30(합성)',
#     'nowVal': 20000,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.22,
#     'nav': 20253.0,
#     'threeMonthEarnRate': 1.3397,
#     'quant': 7098,
#     'amonut': 142,
#     'marketSum': 2660},
#    {'itemcode': '466940',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 은행고배당플러스TOP10',
#     'nowVal': 14595,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.14,
#     'nav': 14612.0,
#     'threeMonthEarnRate': 10.8961,
#     'quant': 97732,
#     'amonut': 1425,
#     'marketSum': 2656},
#    {'itemcode': '394660',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#     'nowVal': 9790,
#     'risefall': '5',
#     'changeVal': -130,
#     'changeRate': -1.31,
#     'nav': 9816.0,
#     'threeMonthEarnRate': -11.3891,
#     'quant': 2816,
#     'amonut': 27,
#     'marketSum': 2655},
#    {'itemcode': '091230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 반도체',
#     'nowVal': 37740,
#     'risefall': '5',
#     'changeVal': -525,
#     'changeRate': -1.37,
#     'nav': 37778.0,
#     'threeMonthEarnRate': -12.3067,
#     'quant': 21133,
#     'amonut': 796,
#     'marketSum': 2634},
#    {'itemcode': '143860',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 헬스케어',
#     'nowVal': 37310,
#     'risefall': '2',
#     'changeVal': 260,
#     'changeRate': 0.7,
#     'nav': 37430.0,
#     'threeMonthEarnRate': 18.4273,
#     'quant': 34367,
#     'amonut': 1275,
#     'marketSum': 2619},
#    {'itemcode': '388420',
#     'etfTabCode': 2,
#     'itemname': 'RISE 비메모리반도체액티브',
#     'nowVal': 11375,
#     'risefall': '5',
#     'changeVal': -145,
#     'changeRate': -1.26,
#     'nav': 11387.0,
#     'threeMonthEarnRate': -18.7302,
#     'quant': 32280,
#     'amonut': 366,
#     'marketSum': 2603},
#    {'itemcode': '273140',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'nowVal': 111615,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 111657.0,
#     'threeMonthEarnRate': 0.863,
#     'quant': 362,
#     'amonut': 40,
#     'marketSum': 2589},
#    {'itemcode': '361580',
#     'etfTabCode': 1,
#     'itemname': 'RISE 200TR',
#     'nowVal': 20215,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.44,
#     'nav': 20274.0,
#     'threeMonthEarnRate': -0.4657,
#     'quant': 776,
#     'amonut': 15,
#     'marketSum': 2588},
#    {'itemcode': '451600',
#     'etfTabCode': 6,
#     'itemname': 'PLUS 국고채30년액티브',
#     'nowVal': 110240,
#     'risefall': '5',
#     'changeVal': -605,
#     'changeRate': -0.55,
#     'nav': 110173.0,
#     'threeMonthEarnRate': 8.9439,
#     'quant': 61,
#     'amonut': 6,
#     'marketSum': 2485},
#    {'itemcode': '473290',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 26-12 회사채(AA-이상)액티브',
#     'nowVal': 10425,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.05,
#     'nav': 10430.0,
#     'threeMonthEarnRate': 1.6569,
#     'quant': 13372,
#     'amonut': 139,
#     'marketSum': 2470},
#    {'itemcode': '449450',
#     'etfTabCode': 2,
#     'itemname': 'PLUS K방산',
#     'nowVal': 17765,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.42,
#     'nav': 17796.0,
#     'threeMonthEarnRate': 16.6117,
#     'quant': 142387,
#     'amonut': 2528,
#     'marketSum': 2452},
#    {'itemcode': '471230',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채10년액티브',
#     'nowVal': 110545,
#     'risefall': '5',
#     'changeVal': -185,
#     'changeRate': -0.17,
#     'nav': 110596.0,
#     'threeMonthEarnRate': 4.6993,
#     'quant': 21495,
#     'amonut': 2376,
#     'marketSum': 2451},
#    {'itemcode': '489250',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국배당다우존스',
#     'nowVal': 10070,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.2,
#     'nav': 10074.0,
#     'threeMonthEarnRate': None,
#     'quant': 336215,
#     'amonut': 3386,
#     'marketSum': 2417},
#    {'itemcode': '200250',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 인도Nifty50(합성)',
#     'nowVal': 25270,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.14,
#     'nav': 25306.0,
#     'threeMonthEarnRate': 7.0867,
#     'quant': 27487,
#     'amonut': 695,
#     'marketSum': 2363},
#    {'itemcode': '367770',
#     'etfTabCode': 2,
#     'itemname': 'RISE 수소경제테마',
#     'nowVal': 9015,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.22,
#     'nav': 9015.0,
#     'threeMonthEarnRate': -7.3809,
#     'quant': 2736,
#     'amonut': 24,
#     'marketSum': 2353},
#    {'itemcode': '423920',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체레버리지(합성)',
#     'nowVal': 23435,
#     'risefall': '5',
#     'changeVal': -1120,
#     'changeRate': -4.56,
#     'nav': 23046.0,
#     'threeMonthEarnRate': -2.8526,
#     'quant': 80014,
#     'amonut': 1873,
#     'marketSum': 2325},
#    {'itemcode': '290130',
#     'etfTabCode': 2,
#     'itemname': 'RISE ESG사회책임투자',
#     'nowVal': 12720,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 12744.0,
#     'threeMonthEarnRate': 2.7463,
#     'quant': 352,
#     'amonut': 4,
#     'marketSum': 2302},
#    {'itemcode': '456600',
#     'etfTabCode': 4,
#     'itemname': 'TIMEFOLIO 글로벌AI인공지능액티브',
#     'nowVal': 19325,
#     'risefall': '5',
#     'changeVal': -325,
#     'changeRate': -1.65,
#     'nav': 19314.0,
#     'threeMonthEarnRate': -0.3803,
#     'quant': 18926,
#     'amonut': 365,
#     'marketSum': 2269},
#    {'itemcode': '463290',
#     'etfTabCode': 6,
#     'itemname': '1Q 단기금융채액티브',
#     'nowVal': 104695,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 104692.0,
#     'threeMonthEarnRate': 1.0716,
#     'quant': 3039,
#     'amonut': 318,
#     'marketSum': 2266},
#    {'itemcode': '448880',
#     'etfTabCode': 6,
#     'itemname': 'ACE 24-12 회사채(AA-이상)액티브',
#     'nowVal': 105390,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 105395.0,
#     'threeMonthEarnRate': 0.9821,
#     'quant': 7,
#     'amonut': 0,
#     'marketSum': 2244},
#    {'itemcode': '394670',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#     'nowVal': 5510,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.81,
#     'nav': 5540.0,
#     'threeMonthEarnRate': -19.0824,
#     'quant': 8211,
#     'amonut': 45,
#     'marketSum': 2237},
#    {'itemcode': '295040',
#     'etfTabCode': 1,
#     'itemname': 'SOL 200TR',
#     'nowVal': 13375,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.34,
#     'nav': 13394.0,
#     'threeMonthEarnRate': -0.4452,
#     'quant': 1721,
#     'amonut': 23,
#     'marketSum': 2207},
#    {'itemcode': '484790',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 미국30년국채액티브(H)',
#     'nowVal': 10295,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.82,
#     'nav': 10285.0,
#     'threeMonthEarnRate': None,
#     'quant': 540906,
#     'amonut': 5570,
#     'marketSum': 2204},
#    {'itemcode': '462330',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업레버리지',
#     'nowVal': 2350,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -2.69,
#     'nav': 2363.0,
#     'threeMonthEarnRate': -28.9706,
#     'quant': 1441541,
#     'amonut': 3391,
#     'marketSum': 2200},
#    {'itemcode': '472160',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10 INDXX(H)',
#     'nowVal': 13255,
#     'risefall': '5',
#     'changeVal': -210,
#     'changeRate': -1.56,
#     'nav': 13186.0,
#     'threeMonthEarnRate': 9.1166,
#     'quant': 22631,
#     'amonut': 299,
#     'marketSum': 2141},
#    {'itemcode': '228790',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 화장품',
#     'nowVal': 2865,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.35,
#     'nav': 2867.0,
#     'threeMonthEarnRate': -10.2202,
#     'quant': 398430,
#     'amonut': 1139,
#     'marketSum': 2080},
#    {'itemcode': '464540',
#     'etfTabCode': 6,
#     'itemname': 'RISE 25-03 회사채(AA-이상)액티브',
#     'nowVal': 51070,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.03,
#     'nav': 51066.0,
#     'threeMonthEarnRate': 1.0349,
#     'quant': 23,
#     'amonut': 1,
#     'marketSum': 2072},
#    {'itemcode': '479520',
#     'etfTabCode': 6,
#     'itemname': 'RISE KOFR금리액티브(합성)',
#     'nowVal': 101185,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.04,
#     'nav': 101135.0,
#     'threeMonthEarnRate': 0.9179,
#     'quant': 431,
#     'amonut': 43,
#     'marketSum': 2069},
#    {'itemcode': '409820',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100레버리지(합성 H)',
#     'nowVal': 10820,
#     'risefall': '5',
#     'changeVal': -300,
#     'changeRate': -2.7,
#     'nav': 10735.0,
#     'threeMonthEarnRate': 9.6106,
#     'quant': 98492,
#     'amonut': 1065,
#     'marketSum': 2067},
#    {'itemcode': '422420',
#     'etfTabCode': 2,
#     'itemname': 'RISE 2차전지액티브',
#     'nowVal': 8235,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -1.14,
#     'nav': 8240.0,
#     'threeMonthEarnRate': -12.7749,
#     'quant': 24770,
#     'amonut': 204,
#     'marketSum': 2042},
#    {'itemcode': '476690',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌비만치료제TOP2Plus',
#     'nowVal': 11740,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.56,
#     'nav': 11748.0,
#     'threeMonthEarnRate': 6.9432,
#     'quant': 168646,
#     'amonut': 1980,
#     'marketSum': 2037},
#    {'itemcode': '448300',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100TR(H)',
#     'nowVal': 15880,
#     'risefall': '5',
#     'changeVal': -220,
#     'changeRate': -1.37,
#     'nav': 15822.0,
#     'threeMonthEarnRate': 5.4009,
#     'quant': 19265,
#     'amonut': 305,
#     'marketSum': 1914},
#    {'itemcode': '438330',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 투자등급회사채액티브',
#     'nowVal': 112510,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.06,
#     'nav': 112560.0,
#     'threeMonthEarnRate': 2.3129,
#     'quant': 761,
#     'amonut': 85,
#     'marketSum': 1909},
#    {'itemcode': '461460',
#     'etfTabCode': 6,
#     'itemname': 'PLUS 국고채10년액티브',
#     'nowVal': 54505,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -0.23,
#     'nav': 54484.0,
#     'threeMonthEarnRate': 4.7756,
#     'quant': 139,
#     'amonut': 7,
#     'marketSum': 1880},
#    {'itemcode': '332940',
#     'etfTabCode': 1,
#     'itemname': 'HANARO MSCI Korea TR',
#     'nowVal': 15765,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.06,
#     'nav': 15753.0,
#     'threeMonthEarnRate': -0.1901,
#     'quant': 10,
#     'amonut': 0,
#     'marketSum': 1876},
#    {'itemcode': '395270',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn K-반도체',
#     'nowVal': 11200,
#     'risefall': '5',
#     'changeVal': -155,
#     'changeRate': -1.37,
#     'nav': 11201.0,
#     'threeMonthEarnRate': -6.1183,
#     'quant': 22939,
#     'amonut': 257,
#     'marketSum': 1870},
#    {'itemcode': '473330',
#     'etfTabCode': 6,
#     'itemname': 'SOL 미국30년국채커버드콜(합성)',
#     'nowVal': 10150,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 10131.0,
#     'threeMonthEarnRate': 6.1271,
#     'quant': 44687,
#     'amonut': 453,
#     'marketSum': 1852},
#    {'itemcode': '479730',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 인도빌리언컨슈머',
#     'nowVal': 10845,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.46,
#     'nav': 10868.0,
#     'threeMonthEarnRate': 7.2528,
#     'quant': 36556,
#     'amonut': 394,
#     'marketSum': 1822},
#    {'itemcode': '143850',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'nowVal': 61115,
#     'risefall': '5',
#     'changeVal': -405,
#     'changeRate': -0.66,
#     'nav': 61135.0,
#     'threeMonthEarnRate': 4.3596,
#     'quant': 11072,
#     'amonut': 676,
#     'marketSum': 1818},
#    {'itemcode': '480260',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 27-04회사채(A+이상)액티브',
#     'nowVal': 51210,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.06,
#     'nav': 51221.0,
#     'threeMonthEarnRate': 2.1429,
#     'quant': 2816,
#     'amonut': 144,
#     'marketSum': 1801},
#    {'itemcode': '480310',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌온디바이스AI',
#     'nowVal': 9740,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -1.22,
#     'nav': 9702.0,
#     'threeMonthEarnRate': -2.3279,
#     'quant': 13367,
#     'amonut': 130,
#     'marketSum': 1797},
#    {'itemcode': '475080',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 테슬라인컴프리미엄채권혼합액티브',
#     'nowVal': 9360,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.74,
#     'nav': 9318.0,
#     'threeMonthEarnRate': 3.0713,
#     'quant': 75849,
#     'amonut': 710,
#     'marketSum': 1755},
#    {'itemcode': '329650',
#     'etfTabCode': 7,
#     'itemname': 'KODEX TRF3070',
#     'nowVal': 12820,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.31,
#     'nav': 12820.0,
#     'threeMonthEarnRate': 2.5518,
#     'quant': 5433,
#     'amonut': 69,
#     'marketSum': 1718},
#    {'itemcode': '452360',
#     'etfTabCode': 4,
#     'itemname': 'SOL 미국배당다우존스(H)',
#     'nowVal': 11275,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.27,
#     'nav': 11263.0,
#     'threeMonthEarnRate': 4.2415,
#     'quant': 16021,
#     'amonut': 180,
#     'marketSum': 1714},
#    {'itemcode': '487340',
#     'etfTabCode': 6,
#     'itemname': 'ACE CD금리&초단기채권액티브',
#     'nowVal': 100550,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 100563.0,
#     'threeMonthEarnRate': None,
#     'quant': 5709,
#     'amonut': 573,
#     'marketSum': 1694},
#    {'itemcode': '471990',
#     'etfTabCode': 2,
#     'itemname': 'KODEX AI반도체핵심장비',
#     'nowVal': 11105,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.31,
#     'nav': 11125.0,
#     'threeMonthEarnRate': -22.3153,
#     'quant': 139521,
#     'amonut': 1540,
#     'marketSum': 1682},
#    {'itemcode': '365780',
#     'etfTabCode': 6,
#     'itemname': 'ACE 국고채10년',
#     'nowVal': 91490,
#     'risefall': '5',
#     'changeVal': -180,
#     'changeRate': -0.2,
#     'nav': 91491.0,
#     'threeMonthEarnRate': 4.5446,
#     'quant': 1788,
#     'amonut': 163,
#     'marketSum': 1652},
#    {'itemcode': '464930',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌혁신블루칩TOP10',
#     'nowVal': 13535,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.55,
#     'nav': 13562.0,
#     'threeMonthEarnRate': 3.8931,
#     'quant': 7428,
#     'amonut': 100,
#     'marketSum': 1645},
#    {'itemcode': '132030',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물(H)',
#     'nowVal': 15315,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -0.81,
#     'nav': 15314.0,
#     'threeMonthEarnRate': 2.6937,
#     'quant': 23547,
#     'amonut': 360,
#     'marketSum': 1639},
#    {'itemcode': '372330',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나항셍테크',
#     'nowVal': 5130,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 5210.0,
#     'threeMonthEarnRate': -15.1084,
#     'quant': 2811,
#     'amonut': 14,
#     'marketSum': 1629},
#    {'itemcode': '455860',
#     'etfTabCode': 2,
#     'itemname': 'SOL 2차전지소부장Fn',
#     'nowVal': 5440,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -1.63,
#     'nav': 5456.0,
#     'threeMonthEarnRate': -14.3963,
#     'quant': 242811,
#     'amonut': 1325,
#     'marketSum': 1605},
#    {'itemcode': '451530',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국고채30년스트립액티브',
#     'nowVal': 56230,
#     'risefall': '5',
#     'changeVal': -270,
#     'changeRate': -0.48,
#     'nav': 56271.0,
#     'threeMonthEarnRate': 12.259,
#     'quant': 5791,
# ...
#     'quant': 8,
#     'amonut': 0,
#     'marketSum': 46},
#    {'itemcode': '391680',
#     'etfTabCode': 1,
#     'itemname': 'HK 하이볼액티브',
#     'nowVal': 8165,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 8179.0,
#     'threeMonthEarnRate': -2.8555,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 45},
#    {'itemcode': '244660',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 퀄리티Plus',
#     'nowVal': 8680,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 8667.0,
#     'threeMonthEarnRate': -2.0317,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 43},
#    {'itemcode': '306520',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 200선물인버스',
#     'nowVal': 9630,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.26,
#     'nav': 9626.0,
#     'threeMonthEarnRate': 0.3133,
#     'quant': 56,
#     'amonut': 0,
#     'marketSum': 43},
#    {'itemcode': '238670',
#     'etfTabCode': 7,
#     'itemname': 'PLUS 스마트베타Quality채권혼합',
#     'nowVal': 10795,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.14,
#     'nav': 10792.0,
#     'threeMonthEarnRate': 0.3257,
#     'quant': 419,
#     'amonut': 4,
#     'marketSum': 43},
#    {'itemcode': '473380',
#     'etfTabCode': 2,
#     'itemname': 'HANARO K-메디테크',
#     'nowVal': 8595,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.87,
#     'nav': 8681.0,
#     'threeMonthEarnRate': 1.6412,
#     'quant': 41,
#     'amonut': 0,
#     'marketSum': 43},
#    {'itemcode': '427110',
#     'etfTabCode': 2,
#     'itemname': 'RISE 창업투자회사',
#     'nowVal': 6490,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.31,
#     'nav': 6498.0,
#     'threeMonthEarnRate': -18.0101,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 43},
#    {'itemcode': '266390',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 경기소비재',
#     'nowVal': 8215,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.31,
#     'nav': 8208.0,
#     'threeMonthEarnRate': -2.5,
#     'quant': 56,
#     'amonut': 0,
#     'marketSum': 41},
#    {'itemcode': '227550',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 산업재',
#     'nowVal': 6605,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 6583.0,
#     'threeMonthEarnRate': 0.3037,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 41},
#    {'itemcode': '407170',
#     'etfTabCode': 2,
#     'itemname': 'KCGI 스마트커머스액티브',
#     'nowVal': 8120,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.43,
#     'nav': 8140.0,
#     'threeMonthEarnRate': -2.0,
#     'quant': 2,
#     'amonut': 0,
#     'marketSum': 41},
#    {'itemcode': '244670',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 밸류Plus',
#     'nowVal': 8110,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 8151.0,
#     'threeMonthEarnRate': -7.841,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 41},
#    {'itemcode': '277640',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 코스피대형주',
#     'nowVal': 13485,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.26,
#     'nav': 13511.0,
#     'threeMonthEarnRate': 0.5129,
#     'quant': 778,
#     'amonut': 10,
#     'marketSum': 40},
#    {'itemcode': '416090',
#     'etfTabCode': 4,
#     'itemname': 'ACE 중국과창판STAR50',
#     'nowVal': 5055,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.1,
#     'nav': 5091.0,
#     'threeMonthEarnRate': -9.2543,
#     'quant': 327,
#     'amonut': 1,
#     'marketSum': 40},
#    {'itemcode': '448510',
#     'etfTabCode': 4,
#     'itemname': 'HANARO 글로벌신재생에너지MSCI(합성)',
#     'nowVal': 7110,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.14,
#     'nav': 7100.0,
#     'threeMonthEarnRate': -6.9463,
#     'quant': 9,
#     'amonut': 0,
#     'marketSum': 39},
#    {'itemcode': '301400',
#     'etfTabCode': 1,
#     'itemname': 'PLUS 코스닥150',
#     'nowVal': 13030,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.23,
#     'nav': 13081.0,
#     'threeMonthEarnRate': -4.4973,
#     'quant': 19,
#     'amonut': 0,
#     'marketSum': 39},
#    {'itemcode': '269530',
#     'etfTabCode': 4,
#     'itemname': 'PLUS S&P글로벌인프라',
#     'nowVal': 15630,
#     'risefall': '2',
#     'changeVal': 250,
#     'changeRate': 1.63,
#     'nav': 15600.0,
#     'threeMonthEarnRate': 0.6149,
#     'quant': 10,
#     'amonut': 0,
#     'marketSum': 39},
#    {'itemcode': '454180',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 차이나내수소비TOP CSI',
#     'nowVal': 7095,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.64,
#     'nav': 7093.0,
#     'threeMonthEarnRate': -21.5796,
#     'quant': 10,
#     'amonut': 0,
#     'marketSum': 39},
#    {'itemcode': '476000',
#     'etfTabCode': 2,
#     'itemname': 'UNICORN 포스트IPO액티브',
#     'nowVal': 6945,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.57,
#     'nav': 6973.0,
#     'threeMonthEarnRate': -23.8277,
#     'quant': 17,
#     'amonut': 0,
#     'marketSum': 38},
#    {'itemcode': '147970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 모멘텀',
#     'nowVal': 30325,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.31,
#     'nav': 30351.0,
#     'threeMonthEarnRate': 5.6069,
#     'quant': 35,
#     'amonut': 1,
#     'marketSum': 36},
#    {'itemcode': '445930',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 차이나A50커넥트레버리지MSCI(합성H)',
#     'nowVal': 7240,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 7253.0,
#     'threeMonthEarnRate': -14.0653,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 36},
#    {'itemcode': '291620',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물인버스',
#     'nowVal': 6625,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.3,
#     'nav': 6632.0,
#     'threeMonthEarnRate': 1.3036,
#     'quant': 3339,
#     'amonut': 22,
#     'marketSum': 35},
#    {'itemcode': '476260',
#     'etfTabCode': 2,
#     'itemname': 'HANARO 반도체핵심공정주도주',
#     'nowVal': 7790,
#     'risefall': '5',
#     'changeVal': -130,
#     'changeRate': -1.64,
#     'nav': 7806.0,
#     'threeMonthEarnRate': -21.2333,
#     'quant': 940,
#     'amonut': 7,
#     'marketSum': 35},
#    {'itemcode': '438210',
#     'etfTabCode': 4,
#     'itemname': 'PLUS 글로벌AI',
#     'nowVal': 11645,
#     'risefall': '5',
#     'changeVal': -200,
#     'changeRate': -1.69,
#     'nav': 11590.0,
#     'threeMonthEarnRate': -2.9894,
#     'quant': 107,
#     'amonut': 1,
#     'marketSum': 35},
#    {'itemcode': '139310',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 금속선물(H)',
#     'nowVal': 5720,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.95,
#     'nav': 5757.0,
#     'threeMonthEarnRate': -15.136,
#     'quant': 427,
#     'amonut': 2,
#     'marketSum': 34},
#    {'itemcode': '426410',
#     'etfTabCode': 4,
#     'itemname': 'PLUS 미국대체투자Top10',
#     'nowVal': 17080,
#     'risefall': '2',
#     'changeVal': 195,
#     'changeRate': 1.15,
#     'nav': 17036.0,
#     'threeMonthEarnRate': 1.2593,
#     'quant': 24,
#     'amonut': 0,
#     'marketSum': 34},
#    {'itemcode': '413220',
#     'etfTabCode': 4,
#     'itemname': 'SOL 차이나태양광CSI(합성)',
#     'nowVal': 3400,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.29,
#     'nav': 3428.0,
#     'threeMonthEarnRate': -24.4989,
#     'quant': 73,
#     'amonut': 0,
#     'marketSum': 34},
#    {'itemcode': '469790',
#     'etfTabCode': 2,
#     'itemname': 'KOSEF K-테크TOP10',
#     'nowVal': 11330,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.57,
#     'nav': 11340.0,
#     'threeMonthEarnRate': -3.3503,
#     'quant': 9,
#     'amonut': 0,
#     'marketSum': 34},
#    {'itemcode': '098560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 방송통신',
#     'nowVal': 6710,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.75,
#     'nav': 6712.0,
#     'threeMonthEarnRate': -2.1883,
#     'quant': 604,
#     'amonut': 4,
#     'marketSum': 34},
#    {'itemcode': '334700',
#     'etfTabCode': 5,
#     'itemname': 'RISE 팔라듐선물인버스(H)',
#     'nowVal': 6530,
#     'risefall': '2',
#     'changeVal': 170,
#     'changeRate': 2.67,
#     'nav': 6539.0,
#     'threeMonthEarnRate': 5.5601,
#     'quant': 100,
#     'amonut': 0,
#     'marketSum': 33},
#    {'itemcode': '256450',
#     'etfTabCode': 4,
#     'itemname': 'PLUS 심천차이넥스트(합성)',
#     'nowVal': 6495,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 6541.0,
#     'threeMonthEarnRate': -18.3019,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 32},
#    {'itemcode': '456100',
#     'etfTabCode': 6,
#     'itemname': 'HANARO 유로존국채25년플러스(합성 H)',
#     'nowVal': 51820,
#     'risefall': '5',
#     'changeVal': -330,
#     'changeRate': -0.63,
#     'nav': 51828.0,
#     'threeMonthEarnRate': 3.6676,
#     'quant': 1,
#     'amonut': 0,
#     'marketSum': 32},
#    {'itemcode': '266550',
#     'etfTabCode': 2,
#     'itemname': 'PLUS 중형주저변동50',
#     'nowVal': 12570,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 12576.0,
#     'threeMonthEarnRate': -0.1192,
#     'quant': 4,
#     'amonut': 0,
#     'marketSum': 31},
#    {'itemcode': '301410',
#     'etfTabCode': 3,
#     'itemname': 'PLUS 코스닥150선물인버스',
#     'nowVal': 5695,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.8,
#     'nav': 5693.0,
#     'threeMonthEarnRate': 0.713,
#     'quant': 308,
#     'amonut': 1,
#     'marketSum': 31},
#    {'itemcode': '407300',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn골프테마',
#     'nowVal': 5650,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 5684.0,
#     'threeMonthEarnRate': -3.5837,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 31},
#    {'itemcode': '472490',
#     'etfTabCode': 4,
#     'itemname': 'HANARO 미국애그테크',
#     'nowVal': 10340,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.39,
#     'nav': 10361.0,
#     'threeMonthEarnRate': -4.9378,
#     'quant': 102,
#     'amonut': 1,
#     'marketSum': 31},
#    {'itemcode': '427120',
#     'etfTabCode': 2,
#     'itemname': 'RISE 플랫폼테마',
#     'nowVal': 5660,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.61,
#     'nav': 5724.0,
#     'threeMonthEarnRate': -15.1899,
#     'quant': 53,
#     'amonut': 0,
#     'marketSum': 31},
#    {'itemcode': '243890',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200에너지화학레버리지',
#     'nowVal': 4870,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -1.32,
#     'nav': 4904.0,
#     'threeMonthEarnRate': -23.1907,
#     'quant': 6733,
#     'amonut': 32,
#     'marketSum': 30},
#    {'itemcode': '220130',
#     'etfTabCode': 4,
#     'itemname': 'SOL 차이나강소기업CSI500(합성 H)',
#     'nowVal': 3635,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.14,
#     'nav': 3641.0,
#     'threeMonthEarnRate': -14.4536,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 29},
#    {'itemcode': '404470',
#     'etfTabCode': 2,
#     'itemname': 'HANARO KRX기후변화솔루션',
#     'nowVal': 11150,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.31,
#     'nav': 11146.0,
#     'threeMonthEarnRate': -8.1315,
#     'quant': 9,
#     'amonut': 0,
#     'marketSum': 28},
#    {'itemcode': '253240',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 200선물인버스',
#     'nowVal': 5385,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.19,
#     'nav': 5389.0,
#     'threeMonthEarnRate': 0.3734,
#     'quant': 5981,
#     'amonut': 32,
#     'marketSum': 27},
#    {'itemcode': '280940',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물인버스(H)',
#     'nowVal': 5825,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.52,
#     'nav': 5827.0,
#     'threeMonthEarnRate': -2.6869,
#     'quant': 27909,
#     'amonut': 162,
#     'marketSum': 26},
#    {'itemcode': '145670',
#     'etfTabCode': 3,
#     'itemname': 'ACE 인버스',
#     'nowVal': 5185,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.48,
#     'nav': 5179.0,
#     'threeMonthEarnRate': 0.1941,
#     'quant': 2714,
#     'amonut': 14,
#     'marketSum': 26},
#    {'itemcode': '465620',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국빅테크TOP7 Plus인버스(합성)',
#     'nowVal': 12830,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 0.83,
#     'nav': 12918.0,
#     'threeMonthEarnRate': -8.0564,
#     'quant': 1104,
#     'amonut': 14,
#     'marketSum': 26},
#    {'itemcode': '426330',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 미국ETF산업STOXX',
#     'nowVal': 12820,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.16,
#     'nav': 12902.0,
#     'threeMonthEarnRate': 2.1479,
#     'quant': 11,
#     'amonut': 0,
#     'marketSum': 26},
#    {'itemcode': '433860',
#     'etfTabCode': 7,
#     'itemname': 'PLUS TDF2040액티브',
#     'nowVal': 12120,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 12146.0,
#     'threeMonthEarnRate': 3.856,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 25},
#    {'itemcode': '291680',
#     'etfTabCode': 4,
#     'itemname': 'RISE 차이나H선물인버스(H)',
#     'nowVal': 12235,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.53,
#     'nav': 12168.0,
#     'threeMonthEarnRate': 8.7052,
#     'quant': 203,
#     'amonut': 2,
#     'marketSum': 24},
#    {'itemcode': '433850',
#     'etfTabCode': 7,
#     'itemname': 'PLUS TDF2030액티브',
#     'nowVal': 11910,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.51,
#     'nav': 11850.0,
#     'threeMonthEarnRate': 3.0882,
#     'quant': 20,
#     'amonut': 0,
#     'marketSum': 24},
#    {'itemcode': '306530',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 코스닥150선물레버리지',
#     'nowVal': 8980,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.83,
#     'nav': 9066.0,
#     'threeMonthEarnRate': -12.6387,
#     'quant': 131,
#     'amonut': 1,
#     'marketSum': 23},
#    {'itemcode': '433870',
#     'etfTabCode': 7,
#     'itemname': 'PLUS TDF2050액티브',
#     'nowVal': 12880,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.66,
#     'nav': 12862.0,
#     'threeMonthEarnRate': 1.6686,
#     'quant': 14,
#     'amonut': 0,
#     'marketSum': 23},
#    {'itemcode': '291630',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물레버리지',
#     'nowVal': 4495,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.77,
#     'nav': 4503.0,
#     'threeMonthEarnRate': -11.696,
#     'quant': 3681,
#     'amonut': 16,
#     'marketSum': 23},
#    {'itemcode': '275750',
#     'etfTabCode': 3,
#     'itemname': 'RISE 코스닥150선물인버스',
#     'nowVal': 3770,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.27,
#     'nav': 3766.0,
#     'threeMonthEarnRate': 1.0752,
#     'quant': 1039,
#     'amonut': 3,
#     'marketSum': 23},
#    {'itemcode': '415920',
#     'etfTabCode': 5,
#     'itemname': 'PLUS 글로벌희토류&전략자원생산기업',
#     'nowVal': 3665,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -1.87,
#     'nav': 3697.0,
#     'threeMonthEarnRate': -28.5851,
#     'quant': 2102,
#     'amonut': 7,
#     'marketSum': 22},
#    {'itemcode': '333940',
#     'etfTabCode': 2,
#     'itemname': 'PLUS KS로우볼가중TR',
#     'nowVal': 14400,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.21,
#     'nav': 14447.0,
#     'threeMonthEarnRate': 2.3504,
#     'quant': 4,
#     'amonut': 0,
#     'marketSum': 22},
#    {'itemcode': '267450',
#     'etfTabCode': 6,
#     'itemname': 'RISE 미국장기국채선물인버스(H)',
#     'nowVal': 10160,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 10216.0,
#     'threeMonthEarnRate': -5.6639,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 20},
#    {'itemcode': '412560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER BBIG레버리지',
#     'nowVal': 2190,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.45,
#     'nav': 2199.0,
#     'threeMonthEarnRate': 0.9174,
#     'quant': 1411,
#     'amonut': 3,
#     'marketSum': 18},
#    {'itemcode': '333980',
#     'etfTabCode': 2,
#     'itemname': 'PLUS KS퀄리티가중TR',
#     'nowVal': 15230,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.13,
#     'nav': 15266.0,
#     'threeMonthEarnRate': 0.396,
#     'quant': 4,
#     'amonut': 0,
#     'marketSum': 15},
#    {'itemcode': '436180',
#     'etfTabCode': 2,
#     'itemname': 'PLUS K-유니콘투자기업액티브',
#     'nowVal': 9975,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.25,
#     'nav': 9987.0,
#     'threeMonthEarnRate': -3.5853,
#     'quant': 1,
#     'amonut': 0,
#     'marketSum': 10},
#    {'itemcode': '402520',
#     'etfTabCode': 1,
#     'itemname': 'FOCUS 혁신기업액티브',
#     'nowVal': 8795,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 8840.0,
#     'threeMonthEarnRate': -1.4014,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 9}]}}

# %% [markdown]
# ### JSON 타입으로 데이터 받기

# %%
# requests 의 응답을 json 타입으로 받습니다.
etf_json = response.json()

# %%
etf_json["result"]['etfItemList']
# Out:
# [{'itemcode': '459580',
#   'etfTabCode': 6,
#   'itemname': 'KODEX CD금리액티브(합성)',
#   'nowVal': 1046085,
#   'risefall': '2',
#   'changeVal': 230,
#   'changeRate': 0.02,
#   'nav': 1046089.0,
#   'threeMonthEarnRate': 0.8972,
#   'quant': 195638,
#   'amonut': 204654,
#   'marketSum': 93402},
#  {'itemcode': '069500',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 200',
#   'nowVal': 36820,
#   'risefall': '5',
#   'changeVal': -115,
#   'changeRate': -0.31,
#   'nav': 36885.0,
#   'threeMonthEarnRate': -0.4931,
#   'quant': 1101467,
#   'amonut': 40510,
#   'marketSum': 61140},
#  {'itemcode': '357870',
#   'etfTabCode': 6,
#   'itemname': 'TIGER CD금리투자KIS(합성)',
#   'nowVal': 54825,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 54828.0,
#   'threeMonthEarnRate': 0.911,
#   'quant': 25319,
#   'amonut': 1388,
#   'marketSum': 61007},
#  {'itemcode': '423160',
#   'etfTabCode': 6,
#   'itemname': 'KODEX KOFR금리액티브(합성)',
#   'nowVal': 107820,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.03,
#   'nav': 107779.0,
#   'threeMonthEarnRate': 0.8939,
#   'quant': 16807,
#   'amonut': 1812,
#   'marketSum': 45037},
#  {'itemcode': '360750',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500',
#   'nowVal': 18650,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.19,
#   'nav': 18599.0,
#   'threeMonthEarnRate': 3.673,
#   'quant': 4820460,
#   'amonut': 89909,
#   'marketSum': 43184},
#  {'itemcode': '449170',
#   'etfTabCode': 6,
#   'itemname': 'TIGER KOFR금리액티브(합성)',
#   'nowVal': 106345,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.02,
#   'nav': 106309.0,
#   'threeMonthEarnRate': 0.9063,
#   'quant': 12834,
#   'amonut': 1364,
#   'marketSum': 36896},
#  {'itemcode': '133690',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국나스닥100',
#   'nowVal': 116830,
#   'risefall': '5',
#   'changeVal': -1045,
#   'changeRate': -0.89,
#   'nav': 116383.0,
#   'threeMonthEarnRate': 3.8162,
#   'quant': 57140,
#   'amonut': 6677,
#   'marketSum': 36299},
#  {'itemcode': '273130',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 종합채권(AA-이상)액티브',
#   'nowVal': 113760,
#   'risefall': '5',
#   'changeVal': -185,
#   'changeRate': -0.16,
#   'nav': 113765.0,
#   'threeMonthEarnRate': 3.2578,
#   'quant': 2537,
#   'amonut': 288,
#   'marketSum': 28027},
#  {'itemcode': '381180',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국필라델피아반도체나스닥',
#   'nowVal': 18150,
#   'risefall': '5',
#   'changeVal': -450,
#   'changeRate': -2.42,
#   'nav': 18022.0,
#   'threeMonthEarnRate': 1.4619,
#   'quant': 687020,
#   'amonut': 12464,
#   'marketSum': 27506},
#  {'itemcode': '381170',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국테크TOP10 INDXX',
#   'nowVal': 20120,
#   'risefall': '5',
#   'changeVal': -235,
#   'changeRate': -1.15,
#   'nav': 20044.0,
#   'threeMonthEarnRate': 7.6984,
#   'quant': 1040203,
#   'amonut': 20942,
#   'marketSum': 27182},
#  {'itemcode': '278530',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 200TR',
#   'nowVal': 12855,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.31,
#   'nav': 12880.0,
#   'threeMonthEarnRate': -0.54,
#   'quant': 8870,
#   'amonut': 113,
#   'marketSum': 22657},
#  {'itemcode': '122630',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 레버리지',
#   'nowVal': 18745,
#   'risefall': '5',
#   'changeVal': -120,
#   'changeRate': -0.64,
#   'nav': 18902.0,
#   'threeMonthEarnRate': -4.19,
#   'quant': 4098125,
#   'amonut': 76627,
#   'marketSum': 21332},
#  {'itemcode': '465680',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 24-12 은행채(AA+이상)액티브',
#   'nowVal': 10395,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.05,
#   'nav': 10393.0,
#   'threeMonthEarnRate': 0.9227,
#   'quant': 451,
#   'amonut': 4,
#   'marketSum': 21222},
#  {'itemcode': '455890',
#   'etfTabCode': 6,
#   'itemname': 'RISE 머니마켓액티브',
#   'nowVal': 52800,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.01,
#   'nav': 52800.0,
#   'threeMonthEarnRate': 1.0237,
#   'quant': 18609,
#   'amonut': 982,
#   'marketSum': 20194},
#  {'itemcode': '102110',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 200',
#   'nowVal': 36880,
#   'risefall': '5',
#   'changeVal': -110,
#   'changeRate': -0.3,
#   'nav': 36949.0,
#   'threeMonthEarnRate': -0.5325,
#   'quant': 348733,
#   'amonut': 12843,
#   'marketSum': 19712},
#  {'itemcode': '379800',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P500TR',
#   'nowVal': 17040,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.2,
#   'nav': 17000.0,
#   'threeMonthEarnRate': 3.6733,
#   'quant': 1098057,
#   'amonut': 18717,
#   'marketSum': 16733},
#  {'itemcode': '481050',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 1년은행양도성예금증서+액티브(합성)',
#   'nowVal': 1012900,
#   'risefall': '2',
#   'changeVal': 90,
#   'changeRate': 0.01,
#   'nav': 1012905.0,
#   'threeMonthEarnRate': 0.9066,
#   'quant': 5609,
#   'amonut': 5681,
#   'marketSum': 16717},
#  {'itemcode': '470260',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 24-12 금융채(AA-이상)',
#   'nowVal': 51775,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 51776.0,
#   'threeMonthEarnRate': 1.0243,
#   'quant': 63,
#   'amonut': 3,
#   'marketSum': 16199},
#  {'itemcode': '453850',
#   'etfTabCode': 6,
#   'itemname': 'ACE 미국30년국채액티브(H)',
#   'nowVal': 8885,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.73,
#   'nav': 8869.0,
#   'threeMonthEarnRate': 8.4717,
#   'quant': 861121,
#   'amonut': 7656,
#   'marketSum': 15309},
#  {'itemcode': '371460',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나전기차SOLACTIVE',
#   'nowVal': 6525,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 6549.0,
#   'threeMonthEarnRate': -17.6137,
#   'quant': 145736,
#   'amonut': 952,
#   'marketSum': 14666},
#  {'itemcode': '214980',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기채권PLUS',
#   'nowVal': 111670,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.01,
#   'nav': 111671.0,
#   'threeMonthEarnRate': 0.963,
#   'quant': 202218,
#   'amonut': 22580,
#   'marketSum': 14075},
#  {'itemcode': '233740',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 코스닥150레버리지',
#   'nowVal': 9125,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.71,
#   'nav': 9187.0,
#   'threeMonthEarnRate': -12.1415,
#   'quant': 5627739,
#   'amonut': 50934,
#   'marketSum': 13186},
#  {'itemcode': '252670',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 200선물인버스2X',
#   'nowVal': 1989,
#   'risefall': '2',
#   'changeVal': 14,
#   'changeRate': 0.71,
#   'nav': 1991.0,
#   'threeMonthEarnRate': -1.9852,
#   'quant': 70732449,
#   'amonut': 141032,
#   'marketSum': 13054},
#  {'itemcode': '102780',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 삼성그룹',
#   'nowVal': 9530,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.16,
#   'nav': 9553.0,
#   'threeMonthEarnRate': 0.5282,
#   'quant': 74257,
#   'amonut': 706,
#   'marketSum': 12904},
#  {'itemcode': '385540',
#   'etfTabCode': 6,
#   'itemname': 'RISE 종합채권(A-이상)액티브',
#   'nowVal': 105545,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.04,
#   'nav': 105532.0,
#   'threeMonthEarnRate': 3.302,
#   'quant': 13,
#   'amonut': 1,
#   'marketSum': 12555},
#  {'itemcode': '148020',
#   'etfTabCode': 1,
#   'itemname': 'RISE 200',
#   'nowVal': 37075,
#   'risefall': '5',
#   'changeVal': -135,
#   'changeRate': -0.36,
#   'nav': 37139.0,
#   'threeMonthEarnRate': -0.4362,
#   'quant': 112656,
#   'amonut': 4171,
#   'marketSum': 12494},
#  {'itemcode': '458730',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국배당다우존스',
#   'nowVal': 11780,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.26,
#   'nav': 11751.0,
#   'threeMonthEarnRate': 2.8716,
#   'quant': 191332,
#   'amonut': 2253,
#   'marketSum': 12210},
#  {'itemcode': '310970',
#   'etfTabCode': 1,
#   'itemname': 'TIGER MSCI Korea TR',
#   'nowVal': 15755,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.28,
#   'nav': 15788.0,
#   'threeMonthEarnRate': 0.1902,
#   'quant': 12,
#   'amonut': 0,
#   'marketSum': 12179},
#  {'itemcode': '360200',
#   'etfTabCode': 4,
#   'itemname': 'ACE 미국S&P500',
#   'nowVal': 18850,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.21,
#   'nav': 18805.0,
#   'threeMonthEarnRate': 3.6602,
#   'quant': 490701,
#   'amonut': 9256,
#   'marketSum': 12045},
#  {'itemcode': '315930',
#   'etfTabCode': 2,
#   'itemname': 'KODEX Top5PlusTR',
#   'nowVal': 23645,
#   'risefall': '5',
#   'changeVal': -190,
#   'changeRate': -0.8,
#   'nav': 23667.0,
#   'threeMonthEarnRate': -0.2303,
#   'quant': 13806,
#   'amonut': 326,
#   'marketSum': 11917},
#  {'itemcode': '379810',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국나스닥100TR',
#   'nowVal': 17480,
#   'risefall': '5',
#   'changeVal': -155,
#   'changeRate': -0.88,
#   'nav': 17416.0,
#   'threeMonthEarnRate': 3.8269,
#   'quant': 411749,
#   'amonut': 7200,
#   'marketSum': 11729},
#  {'itemcode': '292150',
#   'etfTabCode': 2,
#   'itemname': 'TIGER TOP10',
#   'nowVal': 12260,
#   'risefall': '5',
#   'changeVal': -100,
#   'changeRate': -0.81,
#   'nav': 12273.0,
#   'threeMonthEarnRate': -1.9826,
#   'quant': 10694,
#   'amonut': 130,
#   'marketSum': 11028},
#  {'itemcode': '305720',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 2차전지산업',
#   'nowVal': 16310,
#   'risefall': '5',
#   'changeVal': -195,
#   'changeRate': -1.18,
#   'nav': 16333.0,
#   'threeMonthEarnRate': -12.7874,
#   'quant': 564580,
#   'amonut': 9210,
#   'marketSum': 10960},
#  {'itemcode': '305540',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 2차전지테마',
#   'nowVal': 19310,
#   'risefall': '5',
#   'changeVal': -230,
#   'changeRate': -1.18,
#   'nav': 19342.0,
#   'threeMonthEarnRate': -12.7874,
#   'quant': 208988,
#   'amonut': 4039,
#   'marketSum': 10592},
#  {'itemcode': '475630',
#   'etfTabCode': 7,
#   'itemname': 'TIGER CD1년금리액티브(합성)',
#   'nowVal': 1020570,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.01,
#   'nav': 1020572.0,
#   'threeMonthEarnRate': 0.9162,
#   'quant': 9911,
#   'amonut': 10114,
#   'marketSum': 10259},
#  {'itemcode': '476810',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 25-11 은행채(AA-이상)PLUS액티브',
#   'nowVal': 10250,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.05,
#   'nav': 10245.0,
#   'threeMonthEarnRate': 1.4356,
#   'quant': 12070,
#   'amonut': 123,
#   'marketSum': 10066},
#  {'itemcode': '367380',
#   'etfTabCode': 4,
#   'itemname': 'ACE 미국나스닥100',
#   'nowVal': 20075,
#   'risefall': '5',
#   'changeVal': -175,
#   'changeRate': -0.86,
#   'nav': 19998.0,
#   'threeMonthEarnRate': 3.7876,
#   'quant': 158291,
#   'amonut': 3177,
#   'marketSum': 10017},
#  {'itemcode': '453540',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 25-10 회사채(A+이상)액티브',
#   'nowVal': 53375,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.07,
#   'nav': 53393.0,
#   'threeMonthEarnRate': 1.2511,
#   'quant': 22110,
#   'amonut': 1180,
#   'marketSum': 9490},
#  {'itemcode': '229200',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스닥150',
#   'nowVal': 12870,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.19,
#   'nav': 12932.0,
#   'threeMonthEarnRate': -4.2688,
#   'quant': 979430,
#   'amonut': 12546,
#   'marketSum': 9318},
#  {'itemcode': '356540',
#   'etfTabCode': 6,
#   'itemname': 'ACE 종합채권(AA-이상)KIS액티브',
#   'nowVal': 104105,
#   'risefall': '5',
#   'changeVal': -185,
#   'changeRate': -0.18,
#   'nav': 104130.0,
#   'threeMonthEarnRate': 3.4725,
#   'quant': 3107,
#   'amonut': 323,
#   'marketSum': 8580},
#  {'itemcode': '396500',
#   'etfTabCode': 2,
#   'itemname': 'TIGER Fn반도체TOP10',
#   'nowVal': 11680,
#   'risefall': '5',
#   'changeVal': -155,
#   'changeRate': -1.31,
#   'nav': 11697.0,
#   'threeMonthEarnRate': -11.3151,
#   'quant': 229146,
#   'amonut': 2673,
#   'marketSum': 8036},
#  {'itemcode': '157450',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 단기통안채',
#   'nowVal': 107995,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.01,
#   'nav': 108008.0,
#   'threeMonthEarnRate': 0.9394,
#   'quant': 1273,
#   'amonut': 137,
#   'marketSum': 7778},
#  {'itemcode': '447820',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 24-10 회사채(A+이상)액티브',
#   'nowVal': 55470,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 55475.0,
#   'threeMonthEarnRate': 0.9463,
#   'quant': 7128,
#   'amonut': 395,
#   'marketSum': 7723},
#  {'itemcode': '476550',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국30년국채프리미엄액티브(H)',
#   'nowVal': 9800,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.66,
#   'nav': 9788.0,
#   'threeMonthEarnRate': 7.0072,
#   'quant': 871487,
#   'amonut': 8543,
#   'marketSum': 7580},
#  {'itemcode': '152100',
#   'etfTabCode': 1,
#   'itemname': 'PLUS 200',
#   'nowVal': 37390,
#   'risefall': '5',
#   'changeVal': -115,
#   'changeRate': -0.31,
#   'nav': 37455.0,
#   'threeMonthEarnRate': -0.4328,
#   'quant': 132933,
#   'amonut': 4959,
#   'marketSum': 7441},
#  {'itemcode': '294400',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 200TR',
#   'nowVal': 46740,
#   'risefall': '5',
#   'changeVal': -165,
#   'changeRate': -0.35,
#   'nav': 46821.0,
#   'threeMonthEarnRate': -0.4775,
#   'quant': 63734,
#   'amonut': 2974,
#   'marketSum': 7221},
#  {'itemcode': '153130',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기채권',
#   'nowVal': 110725,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 110729.0,
#   'threeMonthEarnRate': 0.962,
#   'quant': 1203,
#   'amonut': 133,
#   'marketSum': 7217},
#  {'itemcode': '436140',
#   'etfTabCode': 6,
#   'itemname': 'SOL 종합채권(AA-이상)액티브',
#   'nowVal': 110270,
#   'risefall': '5',
#   'changeVal': -135,
#   'changeRate': -0.12,
#   'nav': 110277.0,
#   'threeMonthEarnRate': 3.3464,
#   'quant': 802,
#   'amonut': 88,
#   'marketSum': 7173},
#  {'itemcode': '458760',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국배당+7%프리미엄다우존스',
#   'nowVal': 10280,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.19,
#   'nav': 10262.0,
#   'threeMonthEarnRate': 2.1098,
#   'quant': 73845,
#   'amonut': 759,
#   'marketSum': 7155},
#  {'itemcode': '488770',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 머니마켓액티브',
#   'nowVal': 100260,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.03,
#   'nav': 100260.0,
#   'threeMonthEarnRate': None,
#   'quant': 3621,
#   'amonut': 363,
#   'marketSum': 6717},
#  {'itemcode': '451540',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 종합채권(AA-이상)액티브',
#   'nowVal': 54500,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.06,
#   'nav': 54490.0,
#   'threeMonthEarnRate': 3.3544,
#   'quant': 670,
#   'amonut': 36,
#   'marketSum': 6636},
#  {'itemcode': '139260',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 IT',
#   'nowVal': 32340,
#   'risefall': '5',
#   'changeVal': -490,
#   'changeRate': -1.49,
#   'nav': 32376.0,
#   'threeMonthEarnRate': -6.0094,
#   'quant': 1642,
#   'amonut': 53,
#   'marketSum': 6597},
#  {'itemcode': '453870',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 인도니프티50',
#   'nowVal': 13395,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.26,
#   'nav': 13404.0,
#   'threeMonthEarnRate': 7.292,
#   'quant': 80060,
#   'amonut': 1072,
#   'marketSum': 6476},
#  {'itemcode': '272580',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 단기채권액티브',
#   'nowVal': 54385,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 54391.0,
#   'threeMonthEarnRate': 0.9466,
#   'quant': 1993,
#   'amonut': 108,
#   'marketSum': 6350},
#  {'itemcode': '446720',
#   'etfTabCode': 4,
#   'itemname': 'SOL 미국배당다우존스',
#   'nowVal': 10795,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.19,
#   'nav': 10786.0,
#   'threeMonthEarnRate': 2.7952,
#   'quant': 71046,
#   'amonut': 767,
#   'marketSum': 6088},
#  {'itemcode': '368590',
#   'etfTabCode': 4,
#   'itemname': 'RISE 미국나스닥100',
#   'nowVal': 19445,
#   'risefall': '5',
#   'changeVal': -170,
#   'changeRate': -0.87,
#   'nav': 19369.0,
#   'threeMonthEarnRate': 3.8545,
#   'quant': 54525,
#   'amonut': 1060,
#   'marketSum': 6067},
#  {'itemcode': '114800',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 인버스',
#   'nowVal': 4160,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.36,
#   'nav': 4161.0,
#   'threeMonthEarnRate': 0.2418,
#   'quant': 7432640,
#   'amonut': 30963,
#   'marketSum': 5874},
#  {'itemcode': '196230',
#   'etfTabCode': 6,
#   'itemname': 'RISE 단기통안채',
#   'nowVal': 112645,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 112651.0,
#   'threeMonthEarnRate': 0.9228,
#   'quant': 2556,
#   'amonut': 287,
#   'marketSum': 5772},
#  {'itemcode': '462010',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 2차전지소재Fn',
#   'nowVal': 5740,
#   'risefall': '5',
#   'changeVal': -110,
#   'changeRate': -1.88,
#   'nav': 5743.0,
#   'threeMonthEarnRate': -13.3334,
#   'quant': 679534,
#   'amonut': 3913,
#   'marketSum': 5757},
#  {'itemcode': '390390',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국반도체MV',
#   'nowVal': 22350,
#   'risefall': '5',
#   'changeVal': -565,
#   'changeRate': -2.47,
#   'nav': 22230.0,
#   'threeMonthEarnRate': 4.268,
#   'quant': 223179,
#   'amonut': 4987,
#   'marketSum': 5688},
#  {'itemcode': '314250',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국빅테크10(H)',
#   'nowVal': 39950,
#   'risefall': '5',
#   'changeVal': -985,
#   'changeRate': -2.41,
#   'nav': 39693.0,
#   'threeMonthEarnRate': 7.1316,
#   'quant': 17424,
#   'amonut': 695,
#   'marketSum': 5685},
#  {'itemcode': '329750',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국달러단기채권액티브',
#   'nowVal': 12050,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.46,
#   'nav': 12058.0,
#   'threeMonthEarnRate': -0.5802,
#   'quant': 27810,
#   'amonut': 335,
#   'marketSum': 5635},
#  {'itemcode': '458250',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국30년국채스트립액티브(합성 H)',
#   'nowVal': 47430,
#   'risefall': '5',
#   'changeVal': -570,
#   'changeRate': -1.19,
#   'nav': 47312.0,
#   'threeMonthEarnRate': 12.9013,
#   'quant': 92690,
#   'amonut': 4400,
#   'marketSum': 5564},
#  {'itemcode': '329200',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 리츠부동산인프라',
#   'nowVal': 4700,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.21,
#   'nav': 4701.0,
#   'threeMonthEarnRate': 3.7381,
#   'quant': 220693,
#   'amonut': 1034,
#   'marketSum': 5335},
#  {'itemcode': '091160',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 반도체',
#   'nowVal': 36460,
#   'risefall': '5',
#   'changeVal': -470,
#   'changeRate': -1.27,
#   'nav': 36515.0,
#   'threeMonthEarnRate': -12.2282,
#   'quant': 91481,
#   'amonut': 3335,
#   'marketSum': 5250},
#  {'itemcode': '091180',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 자동차',
#   'nowVal': 19195,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.31,
#   'nav': 19209.0,
#   'threeMonthEarnRate': -10.2907,
#   'quant': 57383,
#   'amonut': 1100,
#   'marketSum': 5240},
#  {'itemcode': '105190',
#   'etfTabCode': 1,
#   'itemname': 'ACE 200',
#   'nowVal': 37220,
#   'risefall': '5',
#   'changeVal': -105,
#   'changeRate': -0.28,
#   'nav': 37274.0,
#   'threeMonthEarnRate': -0.5065,
#   'quant': 9057,
#   'amonut': 336,
#   'marketSum': 5229},
#  {'itemcode': '371160',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나항셍테크',
#   'nowVal': 5160,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.1,
#   'nav': 5237.0,
#   'threeMonthEarnRate': -14.9795,
#   'quant': 130728,
#   'amonut': 674,
#   'marketSum': 5106},
#  {'itemcode': '469830',
#   'etfTabCode': 6,
#   'itemname': 'SOL 초단기채권액티브',
#   'nowVal': 51750,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.01,
#   'nav': 51745.0,
#   'threeMonthEarnRate': 0.9855,
#   'quant': 10785,
#   'amonut': 558,
#   'marketSum': 4925},
#  {'itemcode': '453810',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 인도Nifty50',
#   'nowVal': 13735,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.26,
#   'nav': 13744.0,
#   'threeMonthEarnRate': 7.5184,
#   'quant': 187600,
#   'amonut': 2576,
#   'marketSum': 4869},
#  {'itemcode': '293180',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200',
#   'nowVal': 36880,
#   'risefall': '5',
#   'changeVal': -180,
#   'changeRate': -0.49,
#   'nav': 37003.0,
#   'threeMonthEarnRate': -0.4647,
#   'quant': 1568,
#   'amonut': 57,
#   'marketSum': 4868},
#  {'itemcode': '148070',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 국고채10년',
#   'nowVal': 116335,
#   'risefall': '5',
#   'changeVal': -260,
#   'changeRate': -0.22,
#   'nav': 116395.0,
#   'threeMonthEarnRate': 4.5179,
#   'quant': 6874,
#   'amonut': 799,
#   'marketSum': 4770},
#  {'itemcode': '161510',
#   'etfTabCode': 2,
#   'itemname': 'PLUS 고배당주',
#   'nowVal': 15785,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.41,
#   'nav': 15805.0,
#   'threeMonthEarnRate': 13.5181,
#   'quant': 121031,
#   'amonut': 1905,
#   'marketSum': 4736},
#  {'itemcode': '379780',
#   'etfTabCode': 4,
#   'itemname': 'RISE 미국S&P500',
#   'nowVal': 16315,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.21,
#   'nav': 16280.0,
#   'threeMonthEarnRate': 3.6975,
#   'quant': 29206,
#   'amonut': 476,
#   'marketSum': 4682},
#  {'itemcode': '446770',
#   'etfTabCode': 4,
#   'itemname': 'ACE 글로벌반도체TOP4 Plus SOLACTIVE',
#   'nowVal': 24600,
#   'risefall': '5',
#   'changeVal': -505,
#   'changeRate': -2.01,
#   'nav': 24434.0,
#   'threeMonthEarnRate': 8.1692,
#   'quant': 53925,
#   'amonut': 1324,
#   'marketSum': 4674},
#  {'itemcode': '278540',
#   'etfTabCode': 1,
#   'itemname': 'KODEX MSCI Korea TR',
#   'nowVal': 12565,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.44,
#   'nav': 12563.0,
#   'threeMonthEarnRate': 0.4777,
#   'quant': 5321,
#   'amonut': 66,
#   'marketSum': 4649},
#  {'itemcode': '439870',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국고채30년액티브',
#   'nowVal': 114460,
#   'risefall': '5',
#   'changeVal': -470,
#   'changeRate': -0.41,
#   'nav': 114336.0,
#   'threeMonthEarnRate': 8.4501,
#   'quant': 2653,
#   'amonut': 303,
#   'marketSum': 4569},
#  {'itemcode': '477080',
#   'etfTabCode': 6,
#   'itemname': 'RISE CD금리액티브(합성)',
#   'nowVal': 101505,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 101472.0,
#   'threeMonthEarnRate': 0.8996,
#   'quant': 519,
#   'amonut': 52,
#   'marketSum': 4520},
#  {'itemcode': '091170',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 은행',
#   'nowVal': 8965,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.39,
#   'nav': 8973.0,
#   'threeMonthEarnRate': 10.5243,
#   'quant': 138501,
#   'amonut': 1243,
#   'marketSum': 4353},
#  {'itemcode': '465580',
#   'etfTabCode': 4,
#   'itemname': 'ACE 미국빅테크TOP7 Plus',
#   'nowVal': 14520,
#   'risefall': '5',
#   'changeVal': -205,
#   'changeRate': -1.39,
#   'nav': 14464.0,
#   'threeMonthEarnRate': 6.7028,
#   'quant': 48068,
#   'amonut': 697,
#   'marketSum': 4312},
#  {'itemcode': '467940',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 25-11 회사채(A+이상)액티브',
#   'nowVal': 10580,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 10579.0,
#   'threeMonthEarnRate': 1.244,
#   'quant': 5,
#   'amonut': 0,
#   'marketSum': 4151},
#  {'itemcode': '069660',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 200',
#   'nowVal': 36910,
#   'risefall': '5',
#   'changeVal': -90,
#   'changeRate': -0.24,
#   'nav': 36957.0,
#   'threeMonthEarnRate': -0.5511,
#   'quant': 36352,
#   'amonut': 1339,
#   'marketSum': 4115},
#  {'itemcode': '474220',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국테크TOP10+10%프리미엄',
#   'nowVal': 11950,
#   'risefall': '5',
#   'changeVal': -150,
#   'changeRate': -1.24,
#   'nav': 11913.0,
#   'threeMonthEarnRate': 7.8815,
#   'quant': 85994,
#   'amonut': 1027,
#   'marketSum': 4039},
#  {'itemcode': '451000',
#   'etfTabCode': 6,
#   'itemname': 'PLUS 종합채권(AA-이상)액티브',
#   'nowVal': 110880,
#   'risefall': '5',
#   'changeVal': -230,
#   'changeRate': -0.21,
#   'nav': 110921.0,
#   'threeMonthEarnRate': 3.4447,
#   'quant': 2,
#   'amonut': 0,
#   'marketSum': 3985},
#  {'itemcode': '402970',
#   'etfTabCode': 4,
#   'itemname': 'ACE 미국배당다우존스',
#   'nowVal': 11930,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.13,
#   'nav': 11924.0,
#   'threeMonthEarnRate': 2.9195,
#   'quant': 62904,
#   'amonut': 751,
#   'marketSum': 3913},
#  {'itemcode': '476450',
#   'etfTabCode': 6,
#   'itemname': '히어로즈 머니마켓액티브',
#   'nowVal': 51010,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.01,
#   'nav': 51010.0,
#   'threeMonthEarnRate': 0.99,
#   'quant': 820,
#   'amonut': 41,
#   'marketSum': 3868},
#  {'itemcode': '385560',
#   'etfTabCode': 6,
#   'itemname': 'RISE KIS국고채30년Enhanced',
#   'nowVal': 78755,
#   'risefall': '5',
#   'changeVal': -415,
#   'changeRate': -0.52,
#   'nav': 78689.0,
#   'threeMonthEarnRate': 11.3345,
#   'quant': 9744,
#   'amonut': 767,
#   'marketSum': 3843},
#  {'itemcode': '114260',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국고채3년',
#   'nowVal': 60850,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.09,
#   'nav': 60866.0,
#   'threeMonthEarnRate': 2.2153,
#   'quant': 1385,
#   'amonut': 84,
#   'marketSum': 3827},
#  {'itemcode': '486290',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국나스닥100+15%프리미엄초단기',
#   'nowVal': 9410,
#   'risefall': '5',
#   'changeVal': -80,
#   'changeRate': -0.84,
#   'nav': 9376.0,
#   'threeMonthEarnRate': None,
#   'quant': 210153,
#   'amonut': 1978,
#   'marketSum': 3750},
#  {'itemcode': '456610',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국달러SOFR금리액티브(합성)',
#   'nowVal': 53570,
#   'risefall': '2',
#   'changeVal': 235,
#   'changeRate': 0.44,
#   'nav': 53564.0,
#   'threeMonthEarnRate': -0.5408,
#   'quant': 3454,
#   'amonut': 185,
#   'marketSum': 3711},
#  {'itemcode': '251350',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 선진국MSCI World',
#   'nowVal': 27910,
#   'risefall': '5',
#   'changeVal': -100,
#   'changeRate': -0.36,
#   'nav': 27894.0,
#   'threeMonthEarnRate': 2.6947,
#   'quant': 2811,
#   'amonut': 78,
#   'marketSum': 3684},
#  {'itemcode': '226490',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스피',
#   'nowVal': 27470,
#   'risefall': '5',
#   'changeVal': -60,
#   'changeRate': -0.22,
#   'nav': 27535.0,
#   'threeMonthEarnRate': -0.542,
#   'quant': 13446,
#   'amonut': 368,
#   'marketSum': 3599},
#  {'itemcode': '454780',
#   'etfTabCode': 6,
#   'itemname': '히어로즈 종합채권(AA-이상)액티브',
#   'nowVal': 108075,
#   'risefall': '5',
#   'changeVal': -215,
#   'changeRate': -0.2,
#   'nav': 108070.0,
#   'threeMonthEarnRate': 3.5821,
#   'quant': 2000,
#   'amonut': 216,
#   'marketSum': 3544},
#  {'itemcode': '441680',
#   'etfTabCode': 7,
#   'itemname': 'TIGER 미국나스닥100커버드콜(합성)',
#   'nowVal': 10315,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.15,
#   'nav': 10317.0,
#   'threeMonthEarnRate': 2.2671,
#   'quant': 42536,
#   'amonut': 438,
#   'marketSum': 3538},
#  {'itemcode': '466920',
#   'etfTabCode': 2,
#   'itemname': 'SOL 조선TOP3플러스',
#   'nowVal': 12785,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.12,
#   'nav': 12790.0,
#   'threeMonthEarnRate': 23.322,
#   'quant': 504948,
#   'amonut': 6405,
#   'marketSum': 3522},
#  {'itemcode': '364980',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 2차전지TOP10',
#   'nowVal': 10650,
#   'risefall': '5',
#   'changeVal': -170,
#   'changeRate': -1.57,
#   'nav': 10677.0,
#   'threeMonthEarnRate': -11.2388,
#   'quant': 957838,
#   'amonut': 10224,
#   'marketSum': 3509},
#  {'itemcode': '455030',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 미국달러SOFR금리액티브(합성)',
#   'nowVal': 11075,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.27,
#   'nav': 11095.0,
#   'threeMonthEarnRate': -0.4058,
#   'quant': 27707,
#   'amonut': 306,
#   'marketSum': 3449},
#  {'itemcode': '472870',
#   'etfTabCode': 6,
#   'itemname': 'RISE 미국30년국채엔화노출(합성 H)',
#   'nowVal': 9525,
#   'risefall': '5',
#   'changeVal': -85,
#   'changeRate': -0.88,
#   'nav': 9536.0,
#   'threeMonthEarnRate': 12.7801,
#   'quant': 429934,
#   'amonut': 4094,
#   'marketSum': 3353},
#  {'itemcode': '479080',
#   'etfTabCode': 6,
#   'itemname': '1Q 머니마켓액티브',
#   'nowVal': 50875,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.01,
#   'nav': 50873.0,
#   'threeMonthEarnRate': 1.103,
#   'quant': 7102,
#   'amonut': 361,
#   'marketSum': 3266},
#  {'itemcode': '251340',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 코스닥150선물인버스',
#   'nowVal': 3695,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.41,
#   'nav': 3709.0,
#   'threeMonthEarnRate': 1.798,
#   'quant': 12432953,
#   'amonut': 46131,
#   'marketSum': 3248},
#  {'itemcode': '304660',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 미국30년국채울트라선물(H)',
#   'nowVal': 8395,
#   'risefall': '5',
#   'changeVal': -95,
#   'changeRate': -1.12,
#   'nav': 8402.0,
#   'threeMonthEarnRate': 8.2908,
#   'quant': 89380,
#   'amonut': 751,
#   'marketSum': 3224},
#  {'itemcode': '411060',
#   'etfTabCode': 5,
#   'itemname': 'ACE KRX금현물',
#   'nowVal': 15470,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.06,
#   'nav': 15355.0,
#   'threeMonthEarnRate': 2.1782,
#   'quant': 44266,
#   'amonut': 684,
#   'marketSum': 3202},
#  {'itemcode': '272560',
#   'etfTabCode': 6,
#   'itemname': 'RISE 단기국공채액티브',
#   'nowVal': 110220,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.01,
#   'nav': 110205.0,
#   'threeMonthEarnRate': 1.1008,
#   'quant': 22,
#   'amonut': 2,
#   'marketSum': 3195},
#  {'itemcode': '302190',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 중장기국채',
#   'nowVal': 51800,
#   'risefall': '5',
#   'changeVal': -70,
#   'changeRate': -0.13,
#   'nav': 51806.0,
#   'threeMonthEarnRate': 3.3678,
#   'quant': 4499,
#   'amonut': 233,
#   'marketSum': 3191},
#  {'itemcode': '455850',
#   'etfTabCode': 2,
#   'itemname': 'SOL AI반도체소부장',
#   'nowVal': 12630,
#   'risefall': '5',
#   'changeVal': -155,
#   'changeRate': -1.21,
#   'nav': 12648.0,
#   'threeMonthEarnRate': -20.6148,
#   'quant': 65365,
#   'amonut': 822,
#   'marketSum': 3158},
#  {'itemcode': '457480',
#   'etfTabCode': 4,
#   'itemname': 'ACE 테슬라밸류체인액티브',
#   'nowVal': 10520,
#   'risefall': '5',
#   'changeVal': -380,
#   'changeRate': -3.49,
#   'nav': 10453.0,
#   'threeMonthEarnRate': 5.0602,
#   'quant': 127720,
#   'amonut': 1342,
#   'marketSum': 3151},
#  {'itemcode': '449180',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P500(H)',
#   'nowVal': 13065,
#   'risefall': '5',
#   'changeVal': -90,
#   'changeRate': -0.68,
#   'nav': 13036.0,
#   'threeMonthEarnRate': 5.2315,
#   'quant': 53263,
#   'amonut': 695,
#   'marketSum': 3136},
#  {'itemcode': '241180',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 일본니케이225',
#   'nowVal': 21060,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.19,
#   'nav': 21051.0,
#   'threeMonthEarnRate': 3.33,
#   'quant': 5867,
#   'amonut': 123,
#   'marketSum': 3020},
#  {'itemcode': '481060',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 미국30년국채+12%프리미엄(합성 H)',
#   'nowVal': 10640,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.61,
#   'nav': 10628.0,
#   'threeMonthEarnRate': 6.7404,
#   'quant': 299326,
#   'amonut': 3185,
#   'marketSum': 2867},
#  {'itemcode': '448290',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500TR(H)',
#   'nowVal': 13465,
#   'risefall': '5',
#   'changeVal': -95,
#   'changeRate': -0.7,
#   'nav': 13437.0,
#   'threeMonthEarnRate': 5.2386,
#   'quant': 96448,
#   'amonut': 1298,
#   'marketSum': 2861},
#  {'itemcode': '439860',
#   'etfTabCode': 6,
#   'itemname': 'KODEX ESG종합채권(A-이상)액티브',
#   'nowVal': 111350,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.07,
#   'nav': 111332.0,
#   'threeMonthEarnRate': 1.9935,
#   'quant': 9,
#   'amonut': 1,
#   'marketSum': 2844},
#  {'itemcode': '483280',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국AI테크TOP10+15%프리미엄',
#   'nowVal': 10005,
#   'risefall': '5',
#   'changeVal': -125,
#   'changeRate': -1.23,
#   'nav': 9967.0,
#   'threeMonthEarnRate': None,
#   'quant': 233392,
#   'amonut': 2335,
#   'marketSum': 2821},
#  {'itemcode': '449190',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국나스닥100(H)',
#   'nowVal': 15465,
#   'risefall': '5',
#   'changeVal': -215,
#   'changeRate': -1.37,
#   'nav': 15410.0,
#   'threeMonthEarnRate': 5.3763,
#   'quant': 50898,
#   'amonut': 787,
#   'marketSum': 2761},
#  {'itemcode': '477050',
#   'etfTabCode': 6,
#   'itemname': 'PLUS 머니마켓액티브',
#   'nowVal': 50840,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 50840.0,
#   'threeMonthEarnRate': 1.0333,
#   'quant': 10245,
#   'amonut': 520,
#   'marketSum': 2717},
#  {'itemcode': '245710',
#   'etfTabCode': 4,
#   'itemname': 'ACE 베트남VN30(합성)',
#   'nowVal': 20000,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.22,
#   'nav': 20253.0,
#   'threeMonthEarnRate': 1.3397,
#   'quant': 7098,
#   'amonut': 142,
#   'marketSum': 2660},
#  {'itemcode': '466940',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 은행고배당플러스TOP10',
#   'nowVal': 14595,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.14,
#   'nav': 14612.0,
#   'threeMonthEarnRate': 10.8961,
#   'quant': 97732,
#   'amonut': 1425,
#   'marketSum': 2656},
#  {'itemcode': '394660',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#   'nowVal': 9790,
#   'risefall': '5',
#   'changeVal': -130,
#   'changeRate': -1.31,
#   'nav': 9816.0,
#   'threeMonthEarnRate': -11.3891,
#   'quant': 2816,
#   'amonut': 27,
#   'marketSum': 2655},
#  {'itemcode': '091230',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 반도체',
#   'nowVal': 37740,
#   'risefall': '5',
#   'changeVal': -525,
#   'changeRate': -1.37,
#   'nav': 37778.0,
#   'threeMonthEarnRate': -12.3067,
#   'quant': 21133,
#   'amonut': 796,
#   'marketSum': 2634},
#  {'itemcode': '143860',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 헬스케어',
#   'nowVal': 37310,
#   'risefall': '2',
#   'changeVal': 260,
#   'changeRate': 0.7,
#   'nav': 37430.0,
#   'threeMonthEarnRate': 18.4273,
#   'quant': 34367,
#   'amonut': 1275,
#   'marketSum': 2619},
#  {'itemcode': '388420',
#   'etfTabCode': 2,
#   'itemname': 'RISE 비메모리반도체액티브',
#   'nowVal': 11375,
#   'risefall': '5',
#   'changeVal': -145,
#   'changeRate': -1.26,
#   'nav': 11387.0,
#   'threeMonthEarnRate': -18.7302,
#   'quant': 32280,
#   'amonut': 366,
#   'marketSum': 2603},
#  {'itemcode': '273140',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기변동금리부채권액티브',
#   'nowVal': 111615,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 111657.0,
#   'threeMonthEarnRate': 0.863,
#   'quant': 362,
#   'amonut': 40,
#   'marketSum': 2589},
#  {'itemcode': '361580',
#   'etfTabCode': 1,
#   'itemname': 'RISE 200TR',
#   'nowVal': 20215,
#   'risefall': '5',
#   'changeVal': -90,
#   'changeRate': -0.44,
#   'nav': 20274.0,
#   'threeMonthEarnRate': -0.4657,
#   'quant': 776,
#   'amonut': 15,
#   'marketSum': 2588},
#  {'itemcode': '451600',
#   'etfTabCode': 6,
#   'itemname': 'PLUS 국고채30년액티브',
#   'nowVal': 110240,
#   'risefall': '5',
#   'changeVal': -605,
#   'changeRate': -0.55,
#   'nav': 110173.0,
#   'threeMonthEarnRate': 8.9439,
#   'quant': 61,
#   'amonut': 6,
#   'marketSum': 2485},
#  {'itemcode': '473290',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 26-12 회사채(AA-이상)액티브',
#   'nowVal': 10425,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.05,
#   'nav': 10430.0,
#   'threeMonthEarnRate': 1.6569,
#   'quant': 13372,
#   'amonut': 139,
#   'marketSum': 2470},
#  {'itemcode': '449450',
#   'etfTabCode': 2,
#   'itemname': 'PLUS K방산',
#   'nowVal': 17765,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.42,
#   'nav': 17796.0,
#   'threeMonthEarnRate': 16.6117,
#   'quant': 142387,
#   'amonut': 2528,
#   'marketSum': 2452},
#  {'itemcode': '471230',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국고채10년액티브',
#   'nowVal': 110545,
#   'risefall': '5',
#   'changeVal': -185,
#   'changeRate': -0.17,
#   'nav': 110596.0,
#   'threeMonthEarnRate': 4.6993,
#   'quant': 21495,
#   'amonut': 2376,
#   'marketSum': 2451},
#  {'itemcode': '489250',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국배당다우존스',
#   'nowVal': 10070,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.2,
#   'nav': 10074.0,
#   'threeMonthEarnRate': None,
#   'quant': 336215,
#   'amonut': 3386,
#   'marketSum': 2417},
#  {'itemcode': '200250',
#   'etfTabCode': 4,
#   'itemname': 'KOSEF 인도Nifty50(합성)',
#   'nowVal': 25270,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.14,
#   'nav': 25306.0,
#   'threeMonthEarnRate': 7.0867,
#   'quant': 27487,
#   'amonut': 695,
#   'marketSum': 2363},
#  {'itemcode': '367770',
#   'etfTabCode': 2,
#   'itemname': 'RISE 수소경제테마',
#   'nowVal': 9015,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.22,
#   'nav': 9015.0,
#   'threeMonthEarnRate': -7.3809,
#   'quant': 2736,
#   'amonut': 24,
#   'marketSum': 2353},
#  {'itemcode': '423920',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국필라델피아반도체레버리지(합성)',
#   'nowVal': 23435,
#   'risefall': '5',
#   'changeVal': -1120,
#   'changeRate': -4.56,
#   'nav': 23046.0,
#   'threeMonthEarnRate': -2.8526,
#   'quant': 80014,
#   'amonut': 1873,
#   'marketSum': 2325},
#  {'itemcode': '290130',
#   'etfTabCode': 2,
#   'itemname': 'RISE ESG사회책임투자',
#   'nowVal': 12720,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 12744.0,
#   'threeMonthEarnRate': 2.7463,
#   'quant': 352,
#   'amonut': 4,
#   'marketSum': 2302},
#  {'itemcode': '456600',
#   'etfTabCode': 4,
#   'itemname': 'TIMEFOLIO 글로벌AI인공지능액티브',
#   'nowVal': 19325,
#   'risefall': '5',
#   'changeVal': -325,
#   'changeRate': -1.65,
#   'nav': 19314.0,
#   'threeMonthEarnRate': -0.3803,
#   'quant': 18926,
#   'amonut': 365,
#   'marketSum': 2269},
#  {'itemcode': '463290',
#   'etfTabCode': 6,
#   'itemname': '1Q 단기금융채액티브',
#   'nowVal': 104695,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 104692.0,
#   'threeMonthEarnRate': 1.0716,
#   'quant': 3039,
#   'amonut': 318,
#   'marketSum': 2266},
#  {'itemcode': '448880',
#   'etfTabCode': 6,
#   'itemname': 'ACE 24-12 회사채(AA-이상)액티브',
#   'nowVal': 105390,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 105395.0,
#   'threeMonthEarnRate': 0.9821,
#   'quant': 7,
#   'amonut': 0,
#   'marketSum': 2244},
#  {'itemcode': '394670',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#   'nowVal': 5510,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.81,
#   'nav': 5540.0,
#   'threeMonthEarnRate': -19.0824,
#   'quant': 8211,
#   'amonut': 45,
#   'marketSum': 2237},
#  {'itemcode': '295040',
#   'etfTabCode': 1,
#   'itemname': 'SOL 200TR',
#   'nowVal': 13375,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.34,
#   'nav': 13394.0,
#   'threeMonthEarnRate': -0.4452,
#   'quant': 1721,
#   'amonut': 23,
#   'marketSum': 2207},
#  {'itemcode': '484790',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 미국30년국채액티브(H)',
#   'nowVal': 10295,
#   'risefall': '5',
#   'changeVal': -85,
#   'changeRate': -0.82,
#   'nav': 10285.0,
#   'threeMonthEarnRate': None,
#   'quant': 540906,
#   'amonut': 5570,
#   'marketSum': 2204},
#  {'itemcode': '462330',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 2차전지산업레버리지',
#   'nowVal': 2350,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -2.69,
#   'nav': 2363.0,
#   'threeMonthEarnRate': -28.9706,
#   'quant': 1441541,
#   'amonut': 3391,
#   'marketSum': 2200},
#  {'itemcode': '472160',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국테크TOP10 INDXX(H)',
#   'nowVal': 13255,
#   'risefall': '5',
#   'changeVal': -210,
#   'changeRate': -1.56,
#   'nav': 13186.0,
#   'threeMonthEarnRate': 9.1166,
#   'quant': 22631,
#   'amonut': 299,
#   'marketSum': 2141},
#  {'itemcode': '228790',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 화장품',
#   'nowVal': 2865,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.35,
#   'nav': 2867.0,
#   'threeMonthEarnRate': -10.2202,
#   'quant': 398430,
#   'amonut': 1139,
#   'marketSum': 2080},
#  {'itemcode': '464540',
#   'etfTabCode': 6,
#   'itemname': 'RISE 25-03 회사채(AA-이상)액티브',
#   'nowVal': 51070,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.03,
#   'nav': 51066.0,
#   'threeMonthEarnRate': 1.0349,
#   'quant': 23,
#   'amonut': 1,
#   'marketSum': 2072},
#  {'itemcode': '479520',
#   'etfTabCode': 6,
#   'itemname': 'RISE KOFR금리액티브(합성)',
#   'nowVal': 101185,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.04,
#   'nav': 101135.0,
#   'threeMonthEarnRate': 0.9179,
#   'quant': 431,
#   'amonut': 43,
#   'marketSum': 2069},
#  {'itemcode': '409820',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국나스닥100레버리지(합성 H)',
#   'nowVal': 10820,
#   'risefall': '5',
#   'changeVal': -300,
#   'changeRate': -2.7,
#   'nav': 10735.0,
#   'threeMonthEarnRate': 9.6106,
#   'quant': 98492,
#   'amonut': 1065,
#   'marketSum': 2067},
#  {'itemcode': '422420',
#   'etfTabCode': 2,
#   'itemname': 'RISE 2차전지액티브',
#   'nowVal': 8235,
#   'risefall': '5',
#   'changeVal': -95,
#   'changeRate': -1.14,
#   'nav': 8240.0,
#   'threeMonthEarnRate': -12.7749,
#   'quant': 24770,
#   'amonut': 204,
#   'marketSum': 2042},
#  {'itemcode': '476690',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌비만치료제TOP2Plus',
#   'nowVal': 11740,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.56,
#   'nav': 11748.0,
#   'threeMonthEarnRate': 6.9432,
#   'quant': 168646,
#   'amonut': 1980,
#   'marketSum': 2037},
#  {'itemcode': '448300',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국나스닥100TR(H)',
#   'nowVal': 15880,
#   'risefall': '5',
#   'changeVal': -220,
#   'changeRate': -1.37,
#   'nav': 15822.0,
#   'threeMonthEarnRate': 5.4009,
#   'quant': 19265,
#   'amonut': 305,
#   'marketSum': 1914},
#  {'itemcode': '438330',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 투자등급회사채액티브',
#   'nowVal': 112510,
#   'risefall': '5',
#   'changeVal': -70,
#   'changeRate': -0.06,
#   'nav': 112560.0,
#   'threeMonthEarnRate': 2.3129,
#   'quant': 761,
#   'amonut': 85,
#   'marketSum': 1909},
#  {'itemcode': '461460',
#   'etfTabCode': 6,
#   'itemname': 'PLUS 국고채10년액티브',
#   'nowVal': 54505,
#   'risefall': '5',
#   'changeVal': -125,
#   'changeRate': -0.23,
#   'nav': 54484.0,
#   'threeMonthEarnRate': 4.7756,
#   'quant': 139,
#   'amonut': 7,
#   'marketSum': 1880},
#  {'itemcode': '332940',
#   'etfTabCode': 1,
#   'itemname': 'HANARO MSCI Korea TR',
#   'nowVal': 15765,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.06,
#   'nav': 15753.0,
#   'threeMonthEarnRate': -0.1901,
#   'quant': 10,
#   'amonut': 0,
#   'marketSum': 1876},
#  {'itemcode': '395270',
#   'etfTabCode': 2,
#   'itemname': 'HANARO Fn K-반도체',
#   'nowVal': 11200,
#   'risefall': '5',
#   'changeVal': -155,
#   'changeRate': -1.37,
#   'nav': 11201.0,
#   'threeMonthEarnRate': -6.1183,
#   'quant': 22939,
#   'amonut': 257,
#   'marketSum': 1870},
#  {'itemcode': '473330',
#   'etfTabCode': 6,
#   'itemname': 'SOL 미국30년국채커버드콜(합성)',
#   'nowVal': 10150,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 10131.0,
#   'threeMonthEarnRate': 6.1271,
#   'quant': 44687,
#   'amonut': 453,
#   'marketSum': 1852},
#  {'itemcode': '479730',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 인도빌리언컨슈머',
#   'nowVal': 10845,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.46,
#   'nav': 10868.0,
#   'threeMonthEarnRate': 7.2528,
#   'quant': 36556,
#   'amonut': 394,
#   'marketSum': 1822},
#  {'itemcode': '143850',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500선물(H)',
#   'nowVal': 61115,
#   'risefall': '5',
#   'changeVal': -405,
#   'changeRate': -0.66,
#   'nav': 61135.0,
#   'threeMonthEarnRate': 4.3596,
#   'quant': 11072,
#   'amonut': 676,
#   'marketSum': 1818},
#  {'itemcode': '480260',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 27-04회사채(A+이상)액티브',
#   'nowVal': 51210,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.06,
#   'nav': 51221.0,
#   'threeMonthEarnRate': 2.1429,
#   'quant': 2816,
#   'amonut': 144,
#   'marketSum': 1801},
#  {'itemcode': '480310',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌온디바이스AI',
#   'nowVal': 9740,
#   'risefall': '5',
#   'changeVal': -120,
#   'changeRate': -1.22,
#   'nav': 9702.0,
#   'threeMonthEarnRate': -2.3279,
#   'quant': 13367,
#   'amonut': 130,
#   'marketSum': 1797},
#  {'itemcode': '475080',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 테슬라인컴프리미엄채권혼합액티브',
#   'nowVal': 9360,
#   'risefall': '5',
#   'changeVal': -70,
#   'changeRate': -0.74,
#   'nav': 9318.0,
#   'threeMonthEarnRate': 3.0713,
#   'quant': 75849,
#   'amonut': 710,
#   'marketSum': 1755},
#  {'itemcode': '329650',
#   'etfTabCode': 7,
#   'itemname': 'KODEX TRF3070',
#   'nowVal': 12820,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.31,
#   'nav': 12820.0,
#   'threeMonthEarnRate': 2.5518,
#   'quant': 5433,
#   'amonut': 69,
#   'marketSum': 1718},
#  {'itemcode': '452360',
#   'etfTabCode': 4,
#   'itemname': 'SOL 미국배당다우존스(H)',
#   'nowVal': 11275,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.27,
#   'nav': 11263.0,
#   'threeMonthEarnRate': 4.2415,
#   'quant': 16021,
#   'amonut': 180,
#   'marketSum': 1714},
#  {'itemcode': '487340',
#   'etfTabCode': 6,
#   'itemname': 'ACE CD금리&초단기채권액티브',
#   'nowVal': 100550,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': 0.0,
#   'nav': 100563.0,
#   'threeMonthEarnRate': None,
#   'quant': 5709,
#   'amonut': 573,
#   'marketSum': 1694},
#  {'itemcode': '471990',
#   'etfTabCode': 2,
#   'itemname': 'KODEX AI반도체핵심장비',
#   'nowVal': 11105,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.31,
#   'nav': 11125.0,
#   'threeMonthEarnRate': -22.3153,
#   'quant': 139521,
#   'amonut': 1540,
#   'marketSum': 1682},
#  {'itemcode': '365780',
#   'etfTabCode': 6,
#   'itemname': 'ACE 국고채10년',
#   'nowVal': 91490,
#   'risefall': '5',
#   'changeVal': -180,
#   'changeRate': -0.2,
#   'nav': 91491.0,
#   'threeMonthEarnRate': 4.5446,
#   'quant': 1788,
#   'amonut': 163,
#   'marketSum': 1652},
#  {'itemcode': '464930',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌혁신블루칩TOP10',
#   'nowVal': 13535,
#   'risefall': '5',
#   'changeVal': -75,
#   'changeRate': -0.55,
#   'nav': 13562.0,
#   'threeMonthEarnRate': 3.8931,
#   'quant': 7428,
#   'amonut': 100,
#   'marketSum': 1645},
#  {'itemcode': '132030',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 골드선물(H)',
#   'nowVal': 15315,
#   'risefall': '5',
#   'changeVal': -125,
#   'changeRate': -0.81,
#   'nav': 15314.0,
#   'threeMonthEarnRate': 2.6937,
#   'quant': 23547,
#   'amonut': 360,
#   'marketSum': 1639},
#  {'itemcode': '372330',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 차이나항셍테크',
#   'nowVal': 5130,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 5210.0,
#   'threeMonthEarnRate': -15.1084,
#   'quant': 2811,
#   'amonut': 14,
#   'marketSum': 1629},
#  {'itemcode': '455860',
#   'etfTabCode': 2,
#   'itemname': 'SOL 2차전지소부장Fn',
#   'nowVal': 5440,
#   'risefall': '5',
#   'changeVal': -90,
#   'changeRate': -1.63,
#   'nav': 5456.0,
#   'threeMonthEarnRate': -14.3963,
#   'quant': 242811,
#   'amonut': 1325,
#   'marketSum': 1605},
#  {'itemcode': '451530',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 국고채30년스트립액티브',
#   'nowVal': 56230,
#   'risefall': '5',
#   'changeVal': -270,
#   'changeRate': -0.48,
#   'nav': 56271.0,
#   'threeMonthEarnRate': 12.259,
#   'quant': 5791,
#   'amonut': 325,
#   'marketSum': 1587},
#  {'itemcode': '461950',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 2차전지핵심소재10',
#   'nowVal': 5845,
#   'risefall': '5',
#   'changeVal': -115,
#   'changeRate': -1.93,
#   'nav': 5853.0,
#   'threeMonthEarnRate': -14.1829,
#   'quant': 170776,
#   'amonut': 1001,
#   'marketSum': 1584},
#  {'itemcode': '364960',
#   'etfTabCode': 2,
#   'itemname': 'TIGER BBIG',
#   'nowVal': 6320,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.08,
#   'nav': 6337.0,
#   'threeMonthEarnRate': 1.6908,
#   'quant': 8873,
#   'amonut': 55,
#   'marketSum': 1577},
#  {'itemcode': '480020',
#   'etfTabCode': 4,
#   'itemname': 'ACE 미국빅테크7+ 15%프리미엄분배(합성)',
#   'nowVal': 10680,
#   'risefall': '5',
#   'changeVal': -110,
#   'changeRate': -1.02,
#   'nav': 10647.0,
#   'threeMonthEarnRate': 5.9193,
#   'quant': 23820,
#   'amonut': 254,
#   'marketSum': 1559},
#  {'itemcode': '461270',
#   'etfTabCode': 6,
#   'itemname': 'ACE 26-06 회사채(AA-이상)액티브',
#   'nowVal': 10715,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.05,
#   'nav': 10723.0,
#   'threeMonthEarnRate': 1.5151,
#   'quant': 7992,
#   'amonut': 85,
#   'marketSum': 1554},
#  {'itemcode': '483230',
#   'etfTabCode': 6,
#   'itemname': 'RISE 25-06 은행채(AA+이상)액티브',
#   'nowVal': 50405,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.02,
#   'nav': 50394.0,
#   'threeMonthEarnRate': None,
#   'quant': 120,
#   'amonut': 6,
#   'marketSum': 1535},
#  {'itemcode': '363570',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#   'nowVal': 97590,
#   'risefall': '5',
#   'changeVal': -255,
#   'changeRate': -0.26,
#   'nav': 97551.0,
#   'threeMonthEarnRate': 5.2945,
#   'quant': 22,
#   'amonut': 2,
#   'marketSum': 1529},
#  {'itemcode': '445290',
#   'etfTabCode': 2,
#   'itemname': 'KODEX K-로봇액티브',
#   'nowVal': 12980,
#   'risefall': '5',
#   'changeVal': -70,
#   'changeRate': -0.54,
#   'nav': 12990.0,
#   'threeMonthEarnRate': -8.5815,
#   'quant': 2157,
#   'amonut': 27,
#   'marketSum': 1499},
#  {'itemcode': '328370',
#   'etfTabCode': 1,
#   'itemname': 'PLUS 코스피TR',
#   'nowVal': 14590,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.38,
#   'nav': 14595.0,
#   'threeMonthEarnRate': -0.5096,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 1474},
#  {'itemcode': '447770',
#   'etfTabCode': 7,
#   'itemname': 'TIGER 테슬라채권혼합Fn',
#   'nowVal': 11250,
#   'risefall': '5',
#   'changeVal': -200,
#   'changeRate': -1.75,
#   'nav': 11225.0,
#   'threeMonthEarnRate': 8.644,
#   'quant': 46746,
#   'amonut': 527,
#   'marketSum': 1457},
#  {'itemcode': '482730',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500+10%프리미엄초단기',
#   'nowVal': 10165,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.2,
#   'nav': 10146.0,
#   'threeMonthEarnRate': 3.0036,
#   'quant': 45453,
#   'amonut': 462,
#   'marketSum': 1443},
#  {'itemcode': '326240',
#   'etfTabCode': 2,
#   'itemname': 'RISE IT플러스',
#   'nowVal': 17175,
#   'risefall': '5',
#   'changeVal': -200,
#   'changeRate': -1.15,
#   'nav': 17218.0,
#   'threeMonthEarnRate': -7.1849,
#   'quant': 650,
#   'amonut': 11,
#   'marketSum': 1443},
#  {'itemcode': '451060',
#   'etfTabCode': 1,
#   'itemname': '1Q K200액티브',
#   'nowVal': 11700,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.13,
#   'nav': 11712.0,
#   'threeMonthEarnRate': -0.8884,
#   'quant': 429,
#   'amonut': 5,
#   'marketSum': 1422},
#  {'itemcode': '364970',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 바이오TOP10',
#   'nowVal': 7490,
#   'risefall': '2',
#   'changeVal': 100,
#   'changeRate': 1.35,
#   'nav': 7507.0,
#   'threeMonthEarnRate': 20.653,
#   'quant': 258265,
#   'amonut': 1921,
#   'marketSum': 1416},
#  {'itemcode': '213610',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 삼성그룹밸류',
#   'nowVal': 9120,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.05,
#   'nav': 9134.0,
#   'threeMonthEarnRate': 0.8844,
#   'quant': 277,
#   'amonut': 2,
#   'marketSum': 1414},
#  {'itemcode': '182480',
#   'etfTabCode': 7,
#   'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#   'nowVal': 13350,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.72,
#   'nav': 13304.0,
#   'threeMonthEarnRate': 11.8376,
#   'quant': 4706,
#   'amonut': 62,
#   'marketSum': 1402},
#  {'itemcode': '466950',
#   'etfTabCode': 4,
# ...
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.42,
#   'nav': 11994.0,
#   'threeMonthEarnRate': 0.0831,
#   'quant': 13,
#   'amonut': 0,
#   'marketSum': 48},
#  {'itemcode': '139290',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 경기소비재',
#   'nowVal': 15900,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.16,
#   'nav': 15960.0,
#   'threeMonthEarnRate': -7.5692,
#   'quant': 47,
#   'amonut': 0,
#   'marketSum': 48},
#  {'itemcode': '429870',
#   'etfTabCode': 7,
#   'itemname': '히어로즈 리츠이지스액티브',
#   'nowVal': 7925,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.19,
#   'nav': 7951.0,
#   'threeMonthEarnRate': 6.7204,
#   'quant': 3,
#   'amonut': 0,
#   'marketSum': 48},
#  {'itemcode': '432850',
#   'etfTabCode': 4,
#   'itemname': 'HANARO 글로벌백신치료제MSCI',
#   'nowVal': 11880,
#   'risefall': '2',
#   'changeVal': 145,
#   'changeRate': 1.24,
#   'nav': 11874.0,
#   'threeMonthEarnRate': 0.1707,
#   'quant': 1,
#   'amonut': 0,
#   'marketSum': 48},
#  {'itemcode': '140570',
#   'etfTabCode': 2,
#   'itemname': 'RISE 수출주',
#   'nowVal': 11570,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.22,
#   'nav': 11581.0,
#   'threeMonthEarnRate': 0.0866,
#   'quant': 4,
#   'amonut': 0,
#   'marketSum': 46},
#  {'itemcode': '381570',
#   'etfTabCode': 2,
#   'itemname': 'HANARO Fn친환경에너지',
#   'nowVal': 7585,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.65,
#   'nav': 7593.0,
#   'threeMonthEarnRate': -12.4427,
#   'quant': 8,
#   'amonut': 0,
#   'marketSum': 46},
#  {'itemcode': '391680',
#   'etfTabCode': 1,
#   'itemname': 'HK 하이볼액티브',
#   'nowVal': 8165,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 8179.0,
#   'threeMonthEarnRate': -2.8555,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 45},
#  {'itemcode': '244660',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 퀄리티Plus',
#   'nowVal': 8680,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 8667.0,
#   'threeMonthEarnRate': -2.0317,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 43},
#  {'itemcode': '306520',
#   'etfTabCode': 3,
#   'itemname': 'HANARO 200선물인버스',
#   'nowVal': 9630,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.26,
#   'nav': 9626.0,
#   'threeMonthEarnRate': 0.3133,
#   'quant': 56,
#   'amonut': 0,
#   'marketSum': 43},
#  {'itemcode': '238670',
#   'etfTabCode': 7,
#   'itemname': 'PLUS 스마트베타Quality채권혼합',
#   'nowVal': 10795,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.14,
#   'nav': 10792.0,
#   'threeMonthEarnRate': 0.3257,
#   'quant': 419,
#   'amonut': 4,
#   'marketSum': 43},
#  {'itemcode': '473380',
#   'etfTabCode': 2,
#   'itemname': 'HANARO K-메디테크',
#   'nowVal': 8595,
#   'risefall': '5',
#   'changeVal': -75,
#   'changeRate': -0.87,
#   'nav': 8681.0,
#   'threeMonthEarnRate': 1.6412,
#   'quant': 41,
#   'amonut': 0,
#   'marketSum': 43},
#  {'itemcode': '427110',
#   'etfTabCode': 2,
#   'itemname': 'RISE 창업투자회사',
#   'nowVal': 6490,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.31,
#   'nav': 6498.0,
#   'threeMonthEarnRate': -18.0101,
#   'quant': 5,
#   'amonut': 0,
#   'marketSum': 43},
#  {'itemcode': '266390',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 경기소비재',
#   'nowVal': 8215,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.31,
#   'nav': 8208.0,
#   'threeMonthEarnRate': -2.5,
#   'quant': 56,
#   'amonut': 0,
#   'marketSum': 41},
#  {'itemcode': '227550',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 산업재',
#   'nowVal': 6605,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 6583.0,
#   'threeMonthEarnRate': 0.3037,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 41},
#  {'itemcode': '407170',
#   'etfTabCode': 2,
#   'itemname': 'KCGI 스마트커머스액티브',
#   'nowVal': 8120,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.43,
#   'nav': 8140.0,
#   'threeMonthEarnRate': -2.0,
#   'quant': 2,
#   'amonut': 0,
#   'marketSum': 41},
#  {'itemcode': '244670',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 밸류Plus',
#   'nowVal': 8110,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 8151.0,
#   'threeMonthEarnRate': -7.841,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 41},
#  {'itemcode': '277640',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 코스피대형주',
#   'nowVal': 13485,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.26,
#   'nav': 13511.0,
#   'threeMonthEarnRate': 0.5129,
#   'quant': 778,
#   'amonut': 10,
#   'marketSum': 40},
#  {'itemcode': '416090',
#   'etfTabCode': 4,
#   'itemname': 'ACE 중국과창판STAR50',
#   'nowVal': 5055,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.1,
#   'nav': 5091.0,
#   'threeMonthEarnRate': -9.2543,
#   'quant': 327,
#   'amonut': 1,
#   'marketSum': 40},
#  {'itemcode': '448510',
#   'etfTabCode': 4,
#   'itemname': 'HANARO 글로벌신재생에너지MSCI(합성)',
#   'nowVal': 7110,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.14,
#   'nav': 7100.0,
#   'threeMonthEarnRate': -6.9463,
#   'quant': 9,
#   'amonut': 0,
#   'marketSum': 39},
#  {'itemcode': '301400',
#   'etfTabCode': 1,
#   'itemname': 'PLUS 코스닥150',
#   'nowVal': 13030,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.23,
#   'nav': 13081.0,
#   'threeMonthEarnRate': -4.4973,
#   'quant': 19,
#   'amonut': 0,
#   'marketSum': 39},
#  {'itemcode': '269530',
#   'etfTabCode': 4,
#   'itemname': 'PLUS S&P글로벌인프라',
#   'nowVal': 15630,
#   'risefall': '2',
#   'changeVal': 250,
#   'changeRate': 1.63,
#   'nav': 15600.0,
#   'threeMonthEarnRate': 0.6149,
#   'quant': 10,
#   'amonut': 0,
#   'marketSum': 39},
#  {'itemcode': '454180',
#   'etfTabCode': 4,
#   'itemname': 'KOSEF 차이나내수소비TOP CSI',
#   'nowVal': 7095,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 0.64,
#   'nav': 7093.0,
#   'threeMonthEarnRate': -21.5796,
#   'quant': 10,
#   'amonut': 0,
#   'marketSum': 39},
#  {'itemcode': '476000',
#   'etfTabCode': 2,
#   'itemname': 'UNICORN 포스트IPO액티브',
#   'nowVal': 6945,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.57,
#   'nav': 6973.0,
#   'threeMonthEarnRate': -23.8277,
#   'quant': 17,
#   'amonut': 0,
#   'marketSum': 38},
#  {'itemcode': '147970',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 모멘텀',
#   'nowVal': 30325,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.31,
#   'nav': 30351.0,
#   'threeMonthEarnRate': 5.6069,
#   'quant': 35,
#   'amonut': 1,
#   'marketSum': 36},
#  {'itemcode': '445930',
#   'etfTabCode': 4,
#   'itemname': 'KOSEF 차이나A50커넥트레버리지MSCI(합성H)',
#   'nowVal': 7240,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 7253.0,
#   'threeMonthEarnRate': -14.0653,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 36},
#  {'itemcode': '291620',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 코스닥150선물인버스',
#   'nowVal': 6625,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.3,
#   'nav': 6632.0,
#   'threeMonthEarnRate': 1.3036,
#   'quant': 3339,
#   'amonut': 22,
#   'marketSum': 35},
#  {'itemcode': '476260',
#   'etfTabCode': 2,
#   'itemname': 'HANARO 반도체핵심공정주도주',
#   'nowVal': 7790,
#   'risefall': '5',
#   'changeVal': -130,
#   'changeRate': -1.64,
#   'nav': 7806.0,
#   'threeMonthEarnRate': -21.2333,
#   'quant': 940,
#   'amonut': 7,
#   'marketSum': 35},
#  {'itemcode': '438210',
#   'etfTabCode': 4,
#   'itemname': 'PLUS 글로벌AI',
#   'nowVal': 11645,
#   'risefall': '5',
#   'changeVal': -200,
#   'changeRate': -1.69,
#   'nav': 11590.0,
#   'threeMonthEarnRate': -2.9894,
#   'quant': 107,
#   'amonut': 1,
#   'marketSum': 35},
#  {'itemcode': '139310',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 금속선물(H)',
#   'nowVal': 5720,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.95,
#   'nav': 5757.0,
#   'threeMonthEarnRate': -15.136,
#   'quant': 427,
#   'amonut': 2,
#   'marketSum': 34},
#  {'itemcode': '426410',
#   'etfTabCode': 4,
#   'itemname': 'PLUS 미국대체투자Top10',
#   'nowVal': 17080,
#   'risefall': '2',
#   'changeVal': 195,
#   'changeRate': 1.15,
#   'nav': 17036.0,
#   'threeMonthEarnRate': 1.2593,
#   'quant': 24,
#   'amonut': 0,
#   'marketSum': 34},
#  {'itemcode': '413220',
#   'etfTabCode': 4,
#   'itemname': 'SOL 차이나태양광CSI(합성)',
#   'nowVal': 3400,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.29,
#   'nav': 3428.0,
#   'threeMonthEarnRate': -24.4989,
#   'quant': 73,
#   'amonut': 0,
#   'marketSum': 34},
#  {'itemcode': '469790',
#   'etfTabCode': 2,
#   'itemname': 'KOSEF K-테크TOP10',
#   'nowVal': 11330,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.57,
#   'nav': 11340.0,
#   'threeMonthEarnRate': -3.3503,
#   'quant': 9,
#   'amonut': 0,
#   'marketSum': 34},
#  {'itemcode': '098560',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 방송통신',
#   'nowVal': 6710,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.75,
#   'nav': 6712.0,
#   'threeMonthEarnRate': -2.1883,
#   'quant': 604,
#   'amonut': 4,
#   'marketSum': 34},
#  {'itemcode': '334700',
#   'etfTabCode': 5,
#   'itemname': 'RISE 팔라듐선물인버스(H)',
#   'nowVal': 6530,
#   'risefall': '2',
#   'changeVal': 170,
#   'changeRate': 2.67,
#   'nav': 6539.0,
#   'threeMonthEarnRate': 5.5601,
#   'quant': 100,
#   'amonut': 0,
#   'marketSum': 33},
#  {'itemcode': '256450',
#   'etfTabCode': 4,
#   'itemname': 'PLUS 심천차이넥스트(합성)',
#   'nowVal': 6495,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 6541.0,
#   'threeMonthEarnRate': -18.3019,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 32},
#  {'itemcode': '456100',
#   'etfTabCode': 6,
#   'itemname': 'HANARO 유로존국채25년플러스(합성 H)',
#   'nowVal': 51820,
#   'risefall': '5',
#   'changeVal': -330,
#   'changeRate': -0.63,
#   'nav': 51828.0,
#   'threeMonthEarnRate': 3.6676,
#   'quant': 1,
#   'amonut': 0,
#   'marketSum': 32},
#  {'itemcode': '266550',
#   'etfTabCode': 2,
#   'itemname': 'PLUS 중형주저변동50',
#   'nowVal': 12570,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 12576.0,
#   'threeMonthEarnRate': -0.1192,
#   'quant': 4,
#   'amonut': 0,
#   'marketSum': 31},
#  {'itemcode': '301410',
#   'etfTabCode': 3,
#   'itemname': 'PLUS 코스닥150선물인버스',
#   'nowVal': 5695,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 0.8,
#   'nav': 5693.0,
#   'threeMonthEarnRate': 0.713,
#   'quant': 308,
#   'amonut': 1,
#   'marketSum': 31},
#  {'itemcode': '407300',
#   'etfTabCode': 2,
#   'itemname': 'HANARO Fn골프테마',
#   'nowVal': 5650,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 5684.0,
#   'threeMonthEarnRate': -3.5837,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 31},
#  {'itemcode': '472490',
#   'etfTabCode': 4,
#   'itemname': 'HANARO 미국애그테크',
#   'nowVal': 10340,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.39,
#   'nav': 10361.0,
#   'threeMonthEarnRate': -4.9378,
#   'quant': 102,
#   'amonut': 1,
#   'marketSum': 31},
#  {'itemcode': '427120',
#   'etfTabCode': 2,
#   'itemname': 'RISE 플랫폼테마',
#   'nowVal': 5660,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.61,
#   'nav': 5724.0,
#   'threeMonthEarnRate': -15.1899,
#   'quant': 53,
#   'amonut': 0,
#   'marketSum': 31},
#  {'itemcode': '243890',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200에너지화학레버리지',
#   'nowVal': 4870,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -1.32,
#   'nav': 4904.0,
#   'threeMonthEarnRate': -23.1907,
#   'quant': 6733,
#   'amonut': 32,
#   'marketSum': 30},
#  {'itemcode': '220130',
#   'etfTabCode': 4,
#   'itemname': 'SOL 차이나강소기업CSI500(합성 H)',
#   'nowVal': 3635,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.14,
#   'nav': 3641.0,
#   'threeMonthEarnRate': -14.4536,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 29},
#  {'itemcode': '404470',
#   'etfTabCode': 2,
#   'itemname': 'HANARO KRX기후변화솔루션',
#   'nowVal': 11150,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.31,
#   'nav': 11146.0,
#   'threeMonthEarnRate': -8.1315,
#   'quant': 9,
#   'amonut': 0,
#   'marketSum': 28},
#  {'itemcode': '253240',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 200선물인버스',
#   'nowVal': 5385,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.19,
#   'nav': 5389.0,
#   'threeMonthEarnRate': 0.3734,
#   'quant': 5981,
#   'amonut': 32,
#   'marketSum': 27},
#  {'itemcode': '280940',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 골드선물인버스(H)',
#   'nowVal': 5825,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.52,
#   'nav': 5827.0,
#   'threeMonthEarnRate': -2.6869,
#   'quant': 27909,
#   'amonut': 162,
#   'marketSum': 26},
#  {'itemcode': '145670',
#   'etfTabCode': 3,
#   'itemname': 'ACE 인버스',
#   'nowVal': 5185,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.48,
#   'nav': 5179.0,
#   'threeMonthEarnRate': 0.1941,
#   'quant': 2714,
#   'amonut': 14,
#   'marketSum': 26},
#  {'itemcode': '465620',
#   'etfTabCode': 4,
#   'itemname': 'ACE 미국빅테크TOP7 Plus인버스(합성)',
#   'nowVal': 12830,
#   'risefall': '2',
#   'changeVal': 105,
#   'changeRate': 0.83,
#   'nav': 12918.0,
#   'threeMonthEarnRate': -8.0564,
#   'quant': 1104,
#   'amonut': 14,
#   'marketSum': 26},
#  {'itemcode': '426330',
#   'etfTabCode': 4,
#   'itemname': 'KOSEF 미국ETF산업STOXX',
#   'nowVal': 12820,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.16,
#   'nav': 12902.0,
#   'threeMonthEarnRate': 2.1479,
#   'quant': 11,
#   'amonut': 0,
#   'marketSum': 26},
#  {'itemcode': '433860',
#   'etfTabCode': 7,
#   'itemname': 'PLUS TDF2040액티브',
#   'nowVal': 12120,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 12146.0,
#   'threeMonthEarnRate': 3.856,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 25},
#  {'itemcode': '291680',
#   'etfTabCode': 4,
#   'itemname': 'RISE 차이나H선물인버스(H)',
#   'nowVal': 12235,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.53,
#   'nav': 12168.0,
#   'threeMonthEarnRate': 8.7052,
#   'quant': 203,
#   'amonut': 2,
#   'marketSum': 24},
#  {'itemcode': '433850',
#   'etfTabCode': 7,
#   'itemname': 'PLUS TDF2030액티브',
#   'nowVal': 11910,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.51,
#   'nav': 11850.0,
#   'threeMonthEarnRate': 3.0882,
#   'quant': 20,
#   'amonut': 0,
#   'marketSum': 24},
#  {'itemcode': '306530',
#   'etfTabCode': 3,
#   'itemname': 'HANARO 코스닥150선물레버리지',
#   'nowVal': 8980,
#   'risefall': '5',
#   'changeVal': -75,
#   'changeRate': -0.83,
#   'nav': 9066.0,
#   'threeMonthEarnRate': -12.6387,
#   'quant': 131,
#   'amonut': 1,
#   'marketSum': 23},
#  {'itemcode': '433870',
#   'etfTabCode': 7,
#   'itemname': 'PLUS TDF2050액티브',
#   'nowVal': 12880,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.66,
#   'nav': 12862.0,
#   'threeMonthEarnRate': 1.6686,
#   'quant': 14,
#   'amonut': 0,
#   'marketSum': 23},
#  {'itemcode': '291630',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 코스닥150선물레버리지',
#   'nowVal': 4495,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.77,
#   'nav': 4503.0,
#   'threeMonthEarnRate': -11.696,
#   'quant': 3681,
#   'amonut': 16,
#   'marketSum': 23},
#  {'itemcode': '275750',
#   'etfTabCode': 3,
#   'itemname': 'RISE 코스닥150선물인버스',
#   'nowVal': 3770,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.27,
#   'nav': 3766.0,
#   'threeMonthEarnRate': 1.0752,
#   'quant': 1039,
#   'amonut': 3,
#   'marketSum': 23},
#  {'itemcode': '415920',
#   'etfTabCode': 5,
#   'itemname': 'PLUS 글로벌희토류&전략자원생산기업',
#   'nowVal': 3665,
#   'risefall': '5',
#   'changeVal': -70,
#   'changeRate': -1.87,
#   'nav': 3697.0,
#   'threeMonthEarnRate': -28.5851,
#   'quant': 2102,
#   'amonut': 7,
#   'marketSum': 22},
#  {'itemcode': '333940',
#   'etfTabCode': 2,
#   'itemname': 'PLUS KS로우볼가중TR',
#   'nowVal': 14400,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.21,
#   'nav': 14447.0,
#   'threeMonthEarnRate': 2.3504,
#   'quant': 4,
#   'amonut': 0,
#   'marketSum': 22},
#  {'itemcode': '267450',
#   'etfTabCode': 6,
#   'itemname': 'RISE 미국장기국채선물인버스(H)',
#   'nowVal': 10160,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 10216.0,
#   'threeMonthEarnRate': -5.6639,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 20},
#  {'itemcode': '412560',
#   'etfTabCode': 2,
#   'itemname': 'TIGER BBIG레버리지',
#   'nowVal': 2190,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.45,
#   'nav': 2199.0,
#   'threeMonthEarnRate': 0.9174,
#   'quant': 1411,
#   'amonut': 3,
#   'marketSum': 18},
#  {'itemcode': '333980',
#   'etfTabCode': 2,
#   'itemname': 'PLUS KS퀄리티가중TR',
#   'nowVal': 15230,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.13,
#   'nav': 15266.0,
#   'threeMonthEarnRate': 0.396,
#   'quant': 4,
#   'amonut': 0,
#   'marketSum': 15},
#  {'itemcode': '436180',
#   'etfTabCode': 2,
#   'itemname': 'PLUS K-유니콘투자기업액티브',
#   'nowVal': 9975,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.25,
#   'nav': 9987.0,
#   'threeMonthEarnRate': -3.5853,
#   'quant': 1,
#   'amonut': 0,
#   'marketSum': 10},
#  {'itemcode': '402520',
#   'etfTabCode': 1,
#   'itemname': 'FOCUS 혁신기업액티브',
#   'nowVal': 8795,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 8840.0,
#   'threeMonthEarnRate': -1.4014,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 9}]

# %% [markdown]
# ### JSON 에서 원하는 데이터 찾기

# %%
# result > etfItemList 의 하위 구조로 목록을 찾고자 하는 데이터를 가져옵니다.
etfItemList = etf_json["result"]['etfItemList']
len(etfItemList)
# Out:
# 881

# %% [markdown]
# ### 데이터프레임 변환
# ### JSON 데이터를 pandas 의 데이터프레임 형태로 만들기

# %%
# 키-값 형태의 데이터를 데이터프레임으로 만듭니다.
df = pd.DataFrame(etfItemList)
df.shape
# Out:
# (881, 12)

# %% [markdown]
# ### 데이터 확인

# %%
# 데이터 프레임으로 잘 만들어 졌는지 상단 데이터의 일부만 미리보기 합니다.
df.head()
# Out:
#   itemcode  etfTabCode             itemname   nowVal risefall  changeVal  \
# 0   459580           6    KODEX CD금리액티브(합성)  1046085        2        230
# 1   069500           1            KODEX 200    36820        5       -115
# 2   357870           6  TIGER CD금리투자KIS(합성)    54825        3          0
# 3   423160           6  KODEX KOFR금리액티브(합성)   107820        2         30
# 4   360750           4       TIGER 미국S&P500    18650        5        -35
#
#    changeRate        nav  threeMonthEarnRate    quant  amonut  marketSum
# 0        0.02  1046089.0              0.8972   195638  204654      93402
# 1       -0.31    36885.0             -0.4931  1101467   40510      61140
# 2        0.00    54828.0              0.9110    25319    1388      61007
# 3        0.03   107779.0              0.8939    16807    1812      45037
# 4       -0.19    18599.0              3.6730  4820460   89909      43184

# %%
# 데이터 프레임으로 잘 만들어 졌는지 하단 데이터의 일부만 미리보기 합니다.
df.tail()
# Out:
#     itemcode  etfTabCode             itemname  nowVal risefall  changeVal  \
# 876   267450           6  RISE 미국장기국채선물인버스(H)   10160        3          0
# 877   412560           2       TIGER BBIG레버리지    2190        5        -10
# 878   333980           2       PLUS KS퀄리티가중TR   15230        2         20
# 879   436180           2    PLUS K-유니콘투자기업액티브    9975        2         25
# 880   402520           1        FOCUS 혁신기업액티브    8795        3          0
#
#      changeRate      nav  threeMonthEarnRate  quant  amonut  marketSum
# 876        0.00  10216.0             -5.6639      0       0         20
# 877       -0.45   2199.0              0.9174   1411       3         18
# 878        0.13  15266.0              0.3960      4       0         15
# 879        0.25   9987.0             -3.5853      1       0         10
# 880        0.00   8840.0             -1.4014      0       0          9

# %% [markdown]
# ### 파일 저장
# ### 파일명 만들기

# %%
# 파이썬 표준라이브러리인 datetime을 불러옵니다.
# 날짜를 만들어 저장하기 위해 오늘 날짜를 구합니다.
import datetime

today = datetime.datetime.today()
today = today.strftime("%Y-%m-%d")
today
# Out:
# '2024-08-23'

# %%
# f-string 방식으로 파일명을 만들어 줍니다.
# etf_날짜_raw.csv 형태로 만듭니다.
file_name = f"data/etf_{today}_raw.csv"
file_name
# Out:
# 'data/etf_2024-08-23_raw.csv'

# %% [markdown]
# ### 파일로 저장하고 불러오기

# %%
# csv 형태로 저장합니다. index 가 저장되지 않도록 합니다.
df.to_csv(file_name, index=False)

# %%
# 저장된 csv 파일을 읽어옵니다.
# itemcode 숫자 앞의 0 이 지워진다면 dtype={"itemcode": np.object} 로 타입을 지정해 주면 문자형태로 읽어옵니다.
#pd.read_csv(file_name)
pd.read_csv(file_name, dtype={"itemcode": object})
# Out:
#     itemcode  etfTabCode             itemname   nowVal  risefall  changeVal  \
# 0     459580           6    KODEX CD금리액티브(합성)  1046085         2        230
# 1     069500           1            KODEX 200    36820         5       -115
# 2     357870           6  TIGER CD금리투자KIS(합성)    54825         3          0
# 3     423160           6  KODEX KOFR금리액티브(합성)   107820         2         30
# 4     360750           4       TIGER 미국S&P500    18650         5        -35
# ..       ...         ...                  ...      ...       ...        ...
# 876   267450           6  RISE 미국장기국채선물인버스(H)    10160         3          0
# 877   412560           2       TIGER BBIG레버리지     2190         5        -10
# 878   333980           2       PLUS KS퀄리티가중TR    15230         2         20
# 879   436180           2    PLUS K-유니콘투자기업액티브     9975         2         25
# 880   402520           1        FOCUS 혁신기업액티브     8795         3          0
#
#      changeRate        nav  threeMonthEarnRate    quant  amonut  marketSum
# 0          0.02  1046089.0              0.8972   195638  204654      93402
# 1         -0.31    36885.0             -0.4931  1101467   40510      61140
# 2          0.00    54828.0              0.9110    25319    1388      61007
# 3          0.03   107779.0              0.8939    16807    1812      45037
# 4         -0.19    18599.0              3.6730  4820460   89909      43184
# ..          ...        ...                 ...      ...     ...        ...
# 876        0.00    10216.0             -5.6639        0       0         20
# 877       -0.45     2199.0              0.9174     1411       3         18
# 878        0.13    15266.0              0.3960        4       0         15
# 879        0.25     9987.0             -3.5853        1       0         10
# 880        0.00     8840.0             -1.4014        0       0          9
#
# [881 rows x 12 columns]

# %%
file_name
# Out:
# 'data/etf_2024-08-23_raw.csv'
